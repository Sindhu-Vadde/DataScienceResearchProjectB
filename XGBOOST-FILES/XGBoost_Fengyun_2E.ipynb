# %% [markdown]
# **1. Checking for Assumptions**

# %% [markdown]
# Loading and preparing the dataset

# %%
# --- Imports ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

# --- Global Seed Setup (type this once!) ---
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)

# %%
# STEP 1: Load Libraries and Dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Brouwer Mean Motion from Fengyun-2F CSV
df = pd.read_csv('/content/Fengyun-2E.csv')
df['timestamp'] = pd.to_datetime(df['Unnamed: 0'])
df.set_index('timestamp', inplace=True)

# --- Load and parse ground truth maneuver timestamps ---
truth_df = pd.read_excel("/content/manFY2E_cleaned.xlsx")
ground_truth_timestamps = pd.to_datetime(
    truth_df["Start Date"].astype(str) + " " + truth_df["Start Time"].astype(str)
)

# Select relevant column
bmm_series = df['Brouwer mean motion']

# %% [markdown]
# 2. Checking Regualrity

# %%
# STEP 2: Resample to daily data
bmm_daily = bmm_series.resample('D').mean()

# Check missing values
missing_days = bmm_daily.isnull().sum()
print(f"Missing daily entries: {missing_days}")
# Out:
# Missing daily entries: 405

# %% [markdown]
# 3. Interpolating missing values

# %%
# STEP 3: Fill gaps using linear interpolation
bmm_filled = bmm_daily.interpolate(method='linear')

#Outlier removal using IQR
q1 = bmm_filled.quantile(0.25)
q3 = bmm_filled.quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
bmm_filled1 = bmm_filled[(bmm_filled >= lower_bound) & (bmm_filled <= upper_bound)]

bmm_filled = bmm_filled1 * 1e6

# Confirm fill
print("Any missing after interpolation?", bmm_filled.isnull().any())
# Out:
# Any missing after interpolation? False

# %% [markdown]
# 4. Apply differencing

# %%
bmm_filled = bmm_filled.diff().dropna()
print("Differencing applied. First few values:")
print(bmm_filled.head())
# Out:
# Differencing applied. First few values:
# timestamp
# 2011-03-14   -0.009381
# 2011-03-15   -0.027225
# 2011-03-16   -0.025044
# 2011-03-17   -0.013744
# 2011-03-18    0.547592
# Name: Brouwer mean motion, dtype: float64

# %%
# STEP 6: Check stationarity using ADF test
from statsmodels.tsa.stattools import adfuller

adf_result = adfuller(bmm_filled.dropna())
print("ADF Statistic:", adf_result[0])
print("p-value:", adf_result[1])
if adf_result[1] < 0.05:
    print("✅ The series is stationary (p < 0.05)")
else:
    print("❌ The series is NOT stationary (p ≥ 0.05)")
# Out:
# ADF Statistic: -14.56382646066219
# p-value: 4.7472031493833735e-27
# ✅ The series is stationary (p < 0.05)

# %% [markdown]
# 6. Checking Time gaps

# %%
# Ensure uniform time spacing
time_deltas = bmm_filled.index.to_series().diff().value_counts()
print("Time step distribution:")
print(time_deltas.head())
# Out:
# Time step distribution:
# timestamp
# 1 days     2746
# 27 days       1
# 5 days        1
# Name: count, dtype: int64

# %% [markdown]
# 7. Visualisation

# %%
# STEP 8: Plot raw (interpolated + optionally differenced) BMM
plt.figure(figsize=(12, 4))
plt.plot(bmm_filled.index, bmm_filled.values, color='green')
plt.title("Processed Brouwer Mean Motion")
plt.ylabel("BMM")
plt.xlabel("Date")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **2. Fitting of XGBoost Model**

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.4.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)

# %%
import pandas as pd
import numpy as np
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# --- Utility: Create lagged features ---
def make_lagged_features(series, lag=7):
    df_lagged = pd.DataFrame({'target': series})
    for i in range(1, lag + 1):
        df_lagged[f'lag_{i}'] = series.shift(i)
    df_lagged.dropna(inplace=True)
    return df_lagged

# Dictionary to store Optuna studies and histories for each lag
lag_study_results = {}

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from optuna.samplers import TPESampler

# --- Fix random seed for reproducibility ---
SEED = 42

# Store results for each lag
lag_study_results = {}

# Define lags to evaluate
lag_values = [5,10,15,20]

for LAG in lag_values:
    print(f"\n🚀 Running Optuna for LAG={LAG}")

    # --- Create lagged features ---
    lagged_df = make_lagged_features(bmm_filled, lag=LAG)

    # --- Train-test split ---
    train_size = int(len(lagged_df) * 0.8)
    train_df = lagged_df.iloc[:train_size]
    test_df = lagged_df.iloc[train_size:]

    X_train = train_df.drop('target', axis=1).values
    y_train = train_df['target'].values
    X_test = test_df.drop('target', axis=1).values
    y_test = test_df['target'].values

    # --- Define objective function for Optuna ---
    def objective(trial):
        params = {
            'n_estimators': trial.suggest_int('n_estimators', 50, 300),
            'max_depth': trial.suggest_int('max_depth', 3, 10),
            'learning_rate': trial.suggest_float('learning_rate', 1e-4, 0.3, log=True),
            'subsample': trial.suggest_float('subsample', 0.5, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
            'gamma': trial.suggest_float('gamma', 0, 5),
            'reg_alpha': trial.suggest_float('reg_alpha', 0, 1.0),
            'reg_lambda': trial.suggest_float('reg_lambda', 0, 1.0),
            'random_state': SEED,
            'objective': 'reg:squarederror'
        }
        model = XGBRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        mse = mean_squared_error(y_test, y_pred)
        return mse

    # --- Create and run Optuna study with seeded sampler ---
    sampler = TPESampler(seed=SEED)
    study = optuna.create_study(direction='minimize', sampler=sampler)
    study.optimize(objective, n_trials=50, show_progress_bar=True)

    # --- Store results ---
    lag_study_results[LAG] = {
        "study": study,
        "best_params": study.best_params,
        "best_value": study.best_value
    }
# Out:
# [I 2025-08-03 13:29:33,677] A new study created in memory with name: no-name-ec8b3ba7-f961-488c-bbb0-073537d7ffe5
# 🚀 Running Optuna for LAG=5
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-08-03 13:29:33,956] Trial 0 finished with value: 0.006560058466354786 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.035093904781414616, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132, 'reg_alpha': 0.05808361216819946, 'reg_lambda': 0.8661761457749352}. Best is trial 0 with value: 0.006560058466354786.
# [I 2025-08-03 13:29:34,154] Trial 1 finished with value: 0.006626840494184102 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.00011791655502618509, 'subsample': 0.9849549260809971, 'colsample_bytree': 0.9162213204002109, 'gamma': 1.0616955533913808, 'reg_alpha': 0.18182496720710062, 'reg_lambda': 0.18340450985343382}. Best is trial 0 with value: 0.006560058466354786.
# [I 2025-08-03 13:29:34,419] Trial 2 finished with value: 0.006605882068275539 and parameters: {'n_estimators': 126, 'max_depth': 7, 'learning_rate': 0.0031763269920199078, 'subsample': 0.645614570099021, 'colsample_bytree': 0.8059264473611898, 'gamma': 0.6974693032602092, 'reg_alpha': 0.29214464853521815, 'reg_lambda': 0.3663618432936917}. Best is trial 0 with value: 0.006560058466354786.
# [I 2025-08-03 13:29:34,889] Trial 3 finished with value: 0.006596978689559331 and parameters: {'n_estimators': 164, 'max_depth': 9, 'learning_rate': 0.0004946408182937843, 'subsample': 0.7571172192068059, 'colsample_bytree': 0.7962072844310213, 'gamma': 0.23225206359998862, 'reg_alpha': 0.6075448519014384, 'reg_lambda': 0.17052412368729153}. Best is trial 0 with value: 0.006560058466354786.
# [I 2025-08-03 13:29:35,190] Trial 4 finished with value: 0.006426453283237686 and parameters: {'n_estimators': 66, 'max_depth': 10, 'learning_rate': 0.22783459357466163, 'subsample': 0.9041986740582306, 'colsample_bytree': 0.6523068845866853, 'gamma': 0.48836057003191935, 'reg_alpha': 0.6842330265121569, 'reg_lambda': 0.4401524937396013}. Best is trial 4 with value: 0.006426453283237686.
# [I 2025-08-03 13:29:35,309] Trial 5 finished with value: 0.0066268721652492065 and parameters: {'n_estimators': 80, 'max_depth': 6, 'learning_rate': 0.00013169614353741142, 'subsample': 0.954660201039391, 'colsample_bytree': 0.6293899908000085, 'gamma': 3.31261142176991, 'reg_alpha': 0.31171107608941095, 'reg_lambda': 0.5200680211778108}. Best is trial 4 with value: 0.006426453283237686.
# [I 2025-08-03 13:29:35,909] Trial 6 finished with value: 0.00662833321818621 and parameters: {'n_estimators': 187, 'max_depth': 4, 'learning_rate': 0.23515992740571925, 'subsample': 0.8875664116805573, 'colsample_bytree': 0.9697494707820946, 'gamma': 4.474136752138244, 'reg_alpha': 0.5978999788110851, 'reg_lambda': 0.9218742350231168}. Best is trial 4 with value: 0.006426453283237686.
# [I 2025-08-03 13:29:36,050] Trial 7 finished with value: 0.006626874924608283 and parameters: {'n_estimators': 72, 'max_depth': 4, 'learning_rate': 0.0001436351616738488, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'gamma': 1.3567451588694794, 'reg_alpha': 0.8287375091519293, 'reg_lambda': 0.3567533266935893}. Best is trial 4 with value: 0.006426453283237686.
# [I 2025-08-03 13:29:36,339] Trial 8 finished with value: 0.006626875231025989 and parameters: {'n_estimators': 120, 'max_depth': 7, 'learning_rate': 0.0003090370987350513, 'subsample': 0.9010984903770198, 'colsample_bytree': 0.5372753218398854, 'gamma': 4.9344346830025865, 'reg_alpha': 0.7722447692966574, 'reg_lambda': 0.1987156815341724}. Best is trial 4 with value: 0.006426453283237686.
# [I 2025-08-03 13:29:36,721] Trial 9 finished with value: 0.006400787870998807 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.02869648437859116, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'gamma': 0.3702232586704518, 'reg_alpha': 0.3584657285442726, 'reg_lambda': 0.11586905952512971}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:37,472] Trial 10 finished with value: 0.00662610649725583 and parameters: {'n_estimators': 270, 'max_depth': 6, 'learning_rate': 0.016998787242493218, 'subsample': 0.5089809378074097, 'colsample_bytree': 0.8770690800880656, 'gamma': 2.0963905612410483, 'reg_alpha': 0.9597707459454197, 'reg_lambda': 0.011114384822711307}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:37,612] Trial 11 finished with value: 0.0066259777941466876 and parameters: {'n_estimators': 58, 'max_depth': 10, 'learning_rate': 0.2698540583506237, 'subsample': 0.8406708897311783, 'colsample_bytree': 0.7065034325177559, 'gamma': 2.0482246664498587, 'reg_alpha': 0.42829162619021155, 'reg_lambda': 0.6195339431335992}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:37,986] Trial 12 finished with value: 0.0065465406754603005 and parameters: {'n_estimators': 52, 'max_depth': 9, 'learning_rate': 0.05032216033455566, 'subsample': 0.8875263785117047, 'colsample_bytree': 0.8504769022050217, 'gamma': 0.04270853218288917, 'reg_alpha': 0.48196008860966605, 'reg_lambda': 0.719199831432569}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:38,148] Trial 13 finished with value: 0.006626397939873508 and parameters: {'n_estimators': 101, 'max_depth': 9, 'learning_rate': 0.08128447325774922, 'subsample': 0.6740430636131192, 'colsample_bytree': 0.6565308680637576, 'gamma': 3.304278626461433, 'reg_alpha': 0.6777560454699766, 'reg_lambda': 0.004160533698887123}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:38,785] Trial 14 finished with value: 0.006626705040751902 and parameters: {'n_estimators': 254, 'max_depth': 10, 'learning_rate': 0.006767417487246816, 'subsample': 0.8223368426340427, 'colsample_bytree': 0.7606089868019732, 'gamma': 1.6036122785724412, 'reg_alpha': 0.4621147584011279, 'reg_lambda': 0.3729015078077596}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:39,060] Trial 15 finished with value: 0.006627181856742858 and parameters: {'n_estimators': 98, 'max_depth': 8, 'learning_rate': 0.10997937172759138, 'subsample': 0.9370927225087622, 'colsample_bytree': 0.942147041056541, 'gamma': 3.1235044667826504, 'reg_alpha': 0.344325031190336, 'reg_lambda': 0.2758943128437421}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:39,372] Trial 16 finished with value: 0.006410285170291606 and parameters: {'n_estimators': 233, 'max_depth': 8, 'learning_rate': 0.012062049246814135, 'subsample': 0.7320832480224756, 'colsample_bytree': 0.5050431295870819, 'gamma': 0.4726731378970297, 'reg_alpha': 0.00474011965308907, 'reg_lambda': 0.536155869652098}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:39,755] Trial 17 finished with value: 0.006626788435178714 and parameters: {'n_estimators': 243, 'max_depth': 5, 'learning_rate': 0.002618704266732407, 'subsample': 0.7155722086186211, 'colsample_bytree': 0.5004403902704418, 'gamma': 2.69365680894332, 'reg_alpha': 0.013179214380923399, 'reg_lambda': 0.6697709235831028}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:40,368] Trial 18 finished with value: 0.006626252124987863 and parameters: {'n_estimators': 202, 'max_depth': 8, 'learning_rate': 0.0130449794652797, 'subsample': 0.5979200791759145, 'colsample_bytree': 0.9936839637326778, 'gamma': 1.6016986762895833, 'reg_alpha': 0.09977634105513772, 'reg_lambda': 0.5477316263591968}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:40,910] Trial 19 finished with value: 0.006626793856069934 and parameters: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.0012233232952380834, 'subsample': 0.76638757494605, 'colsample_bytree': 0.8586255128054521, 'gamma': 1.1114826183549307, 'reg_alpha': 0.16122290985985877, 'reg_lambda': 0.8157298373095427}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:41,885] Trial 20 finished with value: 0.006626107611158059 and parameters: {'n_estimators': 222, 'max_depth': 7, 'learning_rate': 0.015918697954028217, 'subsample': 0.6006818104614413, 'colsample_bytree': 0.5837667601145492, 'gamma': 2.0511021129465488, 'reg_alpha': 0.2221723740318011, 'reg_lambda': 0.770147164760745}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:42,065] Trial 21 finished with value: 0.006493506741037636 and parameters: {'n_estimators': 163, 'max_depth': 9, 'learning_rate': 0.028610515787592175, 'subsample': 0.8633258622596898, 'colsample_bytree': 0.7235326783146151, 'gamma': 0.4636321226712756, 'reg_alpha': 0.7480747003167743, 'reg_lambda': 0.4616941106162234}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:42,439] Trial 22 finished with value: 0.006453455104316893 and parameters: {'n_estimators': 84, 'max_depth': 8, 'learning_rate': 0.00700915451936244, 'subsample': 0.7945989117205629, 'colsample_bytree': 0.6403478006046059, 'gamma': 0.04351020610361045, 'reg_alpha': 0.5922408644278182, 'reg_lambda': 0.5845517926261375}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:42,677] Trial 23 finished with value: 0.006596743691651065 and parameters: {'n_estimators': 52, 'max_depth': 10, 'learning_rate': 0.12600616487858607, 'subsample': 0.7210872297236234, 'colsample_bytree': 0.5796220576949027, 'gamma': 0.6804436721280265, 'reg_alpha': 0.9132599638436676, 'reg_lambda': 0.9894612555321148}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:42,953] Trial 24 finished with value: 0.006473378379588966 and parameters: {'n_estimators': 227, 'max_depth': 9, 'learning_rate': 0.06275252376501972, 'subsample': 0.9987349142404867, 'colsample_bytree': 0.5197114692304704, 'gamma': 0.3686818867858442, 'reg_alpha': 0.5417644724594487, 'reg_lambda': 0.436838620674271}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:43,044] Trial 25 finished with value: 0.006626911078674158 and parameters: {'n_estimators': 119, 'max_depth': 8, 'learning_rate': 0.02832228149976101, 'subsample': 0.920635080333836, 'colsample_bytree': 0.751545560767482, 'gamma': 1.0599071525938975, 'reg_alpha': 0.3819996117906488, 'reg_lambda': 0.0826410841529217}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:43,455] Trial 26 finished with value: 0.0066259976421337305 and parameters: {'n_estimators': 292, 'max_depth': 10, 'learning_rate': 0.1625995499112974, 'subsample': 0.8581165320998806, 'colsample_bytree': 0.6721148329848075, 'gamma': 3.9410356550686183, 'reg_alpha': 0.6856973506184783, 'reg_lambda': 0.26459576677349095}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:43,572] Trial 27 finished with value: 0.0066269401633789115 and parameters: {'n_estimators': 143, 'max_depth': 9, 'learning_rate': 0.00292228268777028, 'subsample': 0.7201219900800486, 'colsample_bytree': 0.6200714947944089, 'gamma': 1.5557125409180692, 'reg_alpha': 0.12795852374379058, 'reg_lambda': 0.2720566468757272}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:44,385] Trial 28 finished with value: 0.0064923801886865255 and parameters: {'n_estimators': 97, 'max_depth': 7, 'learning_rate': 0.011139217314053367, 'subsample': 0.8070354551117067, 'colsample_bytree': 0.7988992046172941, 'gamma': 0.5237629865650459, 'reg_alpha': 0.01099666678129696, 'reg_lambda': 0.1004541398592117}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:44,491] Trial 29 finished with value: 0.006604634532922532 and parameters: {'n_estimators': 139, 'max_depth': 10, 'learning_rate': 0.043463568204757295, 'subsample': 0.9552666290667412, 'colsample_bytree': 0.5458393516041208, 'gamma': 0.9092355323689755, 'reg_alpha': 0.24651619983387796, 'reg_lambda': 0.45435077324429085}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:44,553] Trial 30 finished with value: 0.006626785929574669 and parameters: {'n_estimators': 65, 'max_depth': 9, 'learning_rate': 0.029958113611432673, 'subsample': 0.7833049356650842, 'colsample_bytree': 0.8940592932171195, 'gamma': 2.4026618338125476, 'reg_alpha': 0.8317680559927537, 'reg_lambda': 0.6864890368638324}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:44,655] Trial 31 finished with value: 0.0064636708295841205 and parameters: {'n_estimators': 84, 'max_depth': 8, 'learning_rate': 0.0067666139030990455, 'subsample': 0.8015725069720028, 'colsample_bytree': 0.6159825292021817, 'gamma': 0.056502998659856696, 'reg_alpha': 0.5699376920924686, 'reg_lambda': 0.560821088423511}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:44,807] Trial 32 finished with value: 0.00655394967897989 and parameters: {'n_estimators': 81, 'max_depth': 8, 'learning_rate': 0.004360168314957772, 'subsample': 0.831181213356403, 'colsample_bytree': 0.5603202804830811, 'gamma': 0.31303061748141814, 'reg_alpha': 0.6417763904017275, 'reg_lambda': 0.6147145029856553}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:44,876] Trial 33 finished with value: 0.006625360388848079 and parameters: {'n_estimators': 102, 'max_depth': 8, 'learning_rate': 0.001430153464236423, 'subsample': 0.7417645107396472, 'colsample_bytree': 0.6587693548879665, 'gamma': 0.7860200078406712, 'reg_alpha': 0.5292310153705215, 'reg_lambda': 0.6179522848097377}. Best is trial 9 with value: 0.006400787870998807.
# [I 2025-08-03 13:29:45,042] Trial 34 finished with value: 0.006369870321758059 and parameters: {'n_estimators': 72, 'max_depth': 10, 'learning_rate': 0.00997743209477674, 'subsample': 0.8659669407984427, 'colsample_bytree': 0.5984193538905249, 'gamma': 0.006133644532753897, 'reg_alpha': 0.733316062125014, 'reg_lambda': 0.4008657445169628}. Best is trial 34 with value: 0.006369870321758059.
# [I 2025-08-03 13:29:45,235] Trial 35 finished with value: 0.006626809883860751 and parameters: {'n_estimators': 160, 'max_depth': 10, 'learning_rate': 0.0189668823968856, 'subsample': 0.8637795404465379, 'colsample_bytree': 0.597375736187613, 'gamma': 1.2679450531767738, 'reg_alpha': 0.7249984515169232, 'reg_lambda': 0.3930008564569492}. Best is trial 34 with value: 0.006369870321758059.
# [I 2025-08-03 13:29:45,413] Trial 36 finished with value: 0.00661481576925594 and parameters: {'n_estimators': 50, 'max_depth': 9, 'learning_rate': 0.001671014928588992, 'subsample': 0.9709932133815481, 'colsample_bytree': 0.5094128361074167, 'gamma': 0.5791792965142533, 'reg_alpha': 0.8127803301083266, 'reg_lambda': 0.32920637812748205}. Best is trial 34 with value: 0.006369870321758059.
# [I 2025-08-03 13:29:45,481] Trial 37 finished with value: 0.006624274185235304 and parameters: {'n_estimators': 193, 'max_depth': 10, 'learning_rate': 0.010264803097201475, 'subsample': 0.9160160288522907, 'colsample_bytree': 0.5510892232486622, 'gamma': 0.8305964035070006, 'reg_alpha': 0.9058023820824996, 'reg_lambda': 0.4875249000186017}. Best is trial 34 with value: 0.006369870321758059.
# [I 2025-08-03 13:29:45,541] Trial 38 finished with value: 0.006477094924148754 and parameters: {'n_estimators': 69, 'max_depth': 9, 'learning_rate': 0.004734600683035568, 'subsample': 0.878496728651212, 'colsample_bytree': 0.8311554812252513, 'gamma': 0.29223915563648983, 'reg_alpha': 0.281189064875389, 'reg_lambda': 0.191286289996507}. Best is trial 34 with value: 0.006369870321758059.
# [I 2025-08-03 13:29:45,616] Trial 39 finished with value: 0.006626872711544193 and parameters: {'n_estimators': 209, 'max_depth': 6, 'learning_rate': 0.09155611604450152, 'subsample': 0.9204741212201903, 'colsample_bytree': 0.77005602006249, 'gamma': 1.262603633322346, 'reg_alpha': 0.6544064772683617, 'reg_lambda': 0.3121384929349639}. Best is trial 34 with value: 0.006369870321758059.
# [I 2025-08-03 13:29:45,695] Trial 40 finished with value: 0.008052742063980031 and parameters: {'n_estimators': 115, 'max_depth': 10, 'learning_rate': 0.17928407400557606, 'subsample': 0.6899812491407068, 'colsample_bytree': 0.7189009649973954, 'gamma': 0.01710840520133211, 'reg_alpha': 0.0774974821461486, 'reg_lambda': 0.42068709864717413}. Best is trial 34 with value: 0.006369870321758059.
# [I 2025-08-03 13:29:45,755] Trial 41 finished with value: 0.006458573119652098 and parameters: {'n_estimators': 84, 'max_depth': 8, 'learning_rate': 0.0076753806706934295, 'subsample': 0.7846305909701199, 'colsample_bytree': 0.6394469754506417, 'gamma': 0.213238548472139, 'reg_alpha': 0.6105443519032433, 'reg_lambda': 0.5388840574599377}. Best is trial 34 with value: 0.006369870321758059.
# [I 2025-08-03 13:29:45,806] Trial 42 finished with value: 0.00656965165964925 and parameters: {'n_estimators': 69, 'max_depth': 7, 'learning_rate': 0.02104794149816837, 'subsample': 0.8424087207665512, 'colsample_bytree': 0.6849910592477475, 'gamma': 0.6022308008576889, 'reg_alpha': 0.7285813987870831, 'reg_lambda': 0.5032317343751591}. Best is trial 34 with value: 0.006369870321758059.
# [I 2025-08-03 13:29:45,888] Trial 43 finished with value: 0.006342713753635613 and parameters: {'n_estimators': 175, 'max_depth': 9, 'learning_rate': 0.008799606487940563, 'subsample': 0.752530311181107, 'colsample_bytree': 0.6007136865857664, 'gamma': 0.16999286955380144, 'reg_alpha': 0.3863895115972368, 'reg_lambda': 0.5673585647110083}. Best is trial 43 with value: 0.006342713753635613.
# [I 2025-08-03 13:29:45,957] Trial 44 finished with value: 0.006433246543494681 and parameters: {'n_estimators': 172, 'max_depth': 9, 'learning_rate': 0.009848253247713653, 'subsample': 0.6389357165196757, 'colsample_bytree': 0.5920483757108989, 'gamma': 0.30227963531043517, 'reg_alpha': 0.3995728195064937, 'reg_lambda': 0.12627674156626992}. Best is trial 43 with value: 0.006342713753635613.
# [I 2025-08-03 13:29:46,025] Trial 45 finished with value: 0.006626791553724037 and parameters: {'n_estimators': 182, 'max_depth': 10, 'learning_rate': 0.003901880919357726, 'subsample': 0.7714652773166837, 'colsample_bytree': 0.5308042123524264, 'gamma': 1.0356044226644125, 'reg_alpha': 0.33424920924320767, 'reg_lambda': 0.4983944648172866}. Best is trial 43 with value: 0.006342713753635613.
# [I 2025-08-03 13:29:46,102] Trial 46 finished with value: 0.00640954158877056 and parameters: {'n_estimators': 268, 'max_depth': 9, 'learning_rate': 0.2980055839893258, 'subsample': 0.7490104191783584, 'colsample_bytree': 0.9260870090166758, 'gamma': 0.7423490040359891, 'reg_alpha': 0.462074137291183, 'reg_lambda': 0.2299068110339949}. Best is trial 43 with value: 0.006342713753635613.
# [I 2025-08-03 13:29:46,377] A new study created in memory with name: no-name-a58cf125-cfd5-486b-994a-3b3ca0e1b0e0
# [I 2025-08-03 13:29:46,195] Trial 47 finished with value: 0.0066206064078970965 and parameters: {'n_estimators': 272, 'max_depth': 9, 'learning_rate': 0.000546336325815981, 'subsample': 0.7476588522841691, 'colsample_bytree': 0.9083471426777016, 'gamma': 0.738266378284657, 'reg_alpha': 0.4607476482753801, 'reg_lambda': 0.1302829561983507}. Best is trial 43 with value: 0.006342713753635613.
# [I 2025-08-03 13:29:46,284] Trial 48 finished with value: 0.0066267209658415396 and parameters: {'n_estimators': 271, 'max_depth': 9, 'learning_rate': 0.002237126509181729, 'subsample': 0.6840528558742127, 'colsample_bytree': 0.9927727117725482, 'gamma': 1.843683739661964, 'reg_alpha': 0.4204959483416074, 'reg_lambda': 0.2503485629161107}. Best is trial 43 with value: 0.006342713753635613.
# [I 2025-08-03 13:29:46,367] Trial 49 finished with value: 0.006294460824011342 and parameters: {'n_estimators': 251, 'max_depth': 9, 'learning_rate': 0.06187756998698821, 'subsample': 0.64603126013113, 'colsample_bytree': 0.9586817307178935, 'gamma': 0.1642252075494953, 'reg_alpha': 0.3645818654096071, 'reg_lambda': 0.22013932501019706}. Best is trial 49 with value: 0.006294460824011342.
#
# 🚀 Running Optuna for LAG=10
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-08-03 13:29:46,419] Trial 0 finished with value: 0.00658226912631261 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.035093904781414616, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132, 'reg_alpha': 0.05808361216819946, 'reg_lambda': 0.8661761457749352}. Best is trial 0 with value: 0.00658226912631261.
# [I 2025-08-03 13:29:46,454] Trial 1 finished with value: 0.006639154797090016 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.00011791655502618509, 'subsample': 0.9849549260809971, 'colsample_bytree': 0.9162213204002109, 'gamma': 1.0616955533913808, 'reg_alpha': 0.18182496720710062, 'reg_lambda': 0.18340450985343382}. Best is trial 0 with value: 0.00658226912631261.
# [I 2025-08-03 13:29:46,495] Trial 2 finished with value: 0.006624902753316461 and parameters: {'n_estimators': 126, 'max_depth': 7, 'learning_rate': 0.0031763269920199078, 'subsample': 0.645614570099021, 'colsample_bytree': 0.8059264473611898, 'gamma': 0.6974693032602092, 'reg_alpha': 0.29214464853521815, 'reg_lambda': 0.3663618432936917}. Best is trial 0 with value: 0.00658226912631261.
# [I 2025-08-03 13:29:46,553] Trial 3 finished with value: 0.006605213420975991 and parameters: {'n_estimators': 164, 'max_depth': 9, 'learning_rate': 0.0004946408182937843, 'subsample': 0.7571172192068059, 'colsample_bytree': 0.7962072844310213, 'gamma': 0.23225206359998862, 'reg_alpha': 0.6075448519014384, 'reg_lambda': 0.17052412368729153}. Best is trial 0 with value: 0.00658226912631261.
# [I 2025-08-03 13:29:46,569] Trial 4 finished with value: 0.006439113644584339 and parameters: {'n_estimators': 66, 'max_depth': 10, 'learning_rate': 0.22783459357466163, 'subsample': 0.9041986740582306, 'colsample_bytree': 0.6523068845866853, 'gamma': 0.48836057003191935, 'reg_alpha': 0.6842330265121569, 'reg_lambda': 0.4401524937396013}. Best is trial 4 with value: 0.006439113644584339.
# [I 2025-08-03 13:29:46,590] Trial 5 finished with value: 0.006639154015816324 and parameters: {'n_estimators': 80, 'max_depth': 6, 'learning_rate': 0.00013169614353741142, 'subsample': 0.954660201039391, 'colsample_bytree': 0.6293899908000085, 'gamma': 3.31261142176991, 'reg_alpha': 0.31171107608941095, 'reg_lambda': 0.5200680211778108}. Best is trial 4 with value: 0.006439113644584339.
# [I 2025-08-03 13:29:46,628] Trial 6 finished with value: 0.0066383798267468834 and parameters: {'n_estimators': 187, 'max_depth': 4, 'learning_rate': 0.23515992740571925, 'subsample': 0.8875664116805573, 'colsample_bytree': 0.9697494707820946, 'gamma': 4.474136752138244, 'reg_alpha': 0.5978999788110851, 'reg_lambda': 0.9218742350231168}. Best is trial 4 with value: 0.006439113644584339.
# [I 2025-08-03 13:29:46,648] Trial 7 finished with value: 0.006639157374582368 and parameters: {'n_estimators': 72, 'max_depth': 4, 'learning_rate': 0.0001436351616738488, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'gamma': 1.3567451588694794, 'reg_alpha': 0.8287375091519293, 'reg_lambda': 0.3567533266935893}. Best is trial 4 with value: 0.006439113644584339.
# [I 2025-08-03 13:29:46,671] Trial 8 finished with value: 0.006639154969217413 and parameters: {'n_estimators': 120, 'max_depth': 7, 'learning_rate': 0.0003090370987350513, 'subsample': 0.9010984903770198, 'colsample_bytree': 0.5372753218398854, 'gamma': 4.9344346830025865, 'reg_alpha': 0.7722447692966574, 'reg_lambda': 0.1987156815341724}. Best is trial 4 with value: 0.006439113644584339.
# [I 2025-08-03 13:29:46,688] Trial 9 finished with value: 0.00643416729600478 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.02869648437859116, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'gamma': 0.3702232586704518, 'reg_alpha': 0.3584657285442726, 'reg_lambda': 0.11586905952512971}. Best is trial 9 with value: 0.00643416729600478.
# [I 2025-08-03 13:29:46,762] Trial 10 finished with value: 0.006639406154441308 and parameters: {'n_estimators': 270, 'max_depth': 6, 'learning_rate': 0.016998787242493218, 'subsample': 0.5089809378074097, 'colsample_bytree': 0.8770690800880656, 'gamma': 2.0963905612410483, 'reg_alpha': 0.9597707459454197, 'reg_lambda': 0.011114384822711307}. Best is trial 9 with value: 0.00643416729600478.
# [I 2025-08-03 13:29:46,810] Trial 11 finished with value: 0.006639104081434748 and parameters: {'n_estimators': 58, 'max_depth': 10, 'learning_rate': 0.2698540583506237, 'subsample': 0.8406708897311783, 'colsample_bytree': 0.7065034325177559, 'gamma': 2.0482246664498587, 'reg_alpha': 0.42829162619021155, 'reg_lambda': 0.6195339431335992}. Best is trial 9 with value: 0.00643416729600478.
# [I 2025-08-03 13:29:46,883] Trial 12 finished with value: 0.006275676015292823 and parameters: {'n_estimators': 52, 'max_depth': 9, 'learning_rate': 0.05032216033455566, 'subsample': 0.8875263785117047, 'colsample_bytree': 0.8504769022050217, 'gamma': 0.04270853218288917, 'reg_alpha': 0.48196008860966605, 'reg_lambda': 0.719199831432569}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:47,004] Trial 13 finished with value: 0.0063727952321798054 and parameters: {'n_estimators': 105, 'max_depth': 8, 'learning_rate': 0.041631203702173776, 'subsample': 0.6929722841849172, 'colsample_bytree': 0.8553002072218189, 'gamma': 0.01482767219699932, 'reg_alpha': 0.4381301674911343, 'reg_lambda': 0.7388723479770365}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:47,090] Trial 14 finished with value: 0.0063288304260142834 and parameters: {'n_estimators': 104, 'max_depth': 8, 'learning_rate': 0.06531366650489707, 'subsample': 0.683813616290651, 'colsample_bytree': 0.8061578814677635, 'gamma': 0.03312264314708315, 'reg_alpha': 0.5113924370327606, 'reg_lambda': 0.7380983421262324}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:47,160] Trial 15 finished with value: 0.0066394647553616876 and parameters: {'n_estimators': 218, 'max_depth': 8, 'learning_rate': 0.004869477890923847, 'subsample': 0.5827781406926889, 'colsample_bytree': 0.7548572093429927, 'gamma': 3.2951430240448687, 'reg_alpha': 0.5442138262378953, 'reg_lambda': 0.7514892999269548}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:47,213] Trial 16 finished with value: 0.0066394680122891 and parameters: {'n_estimators': 103, 'max_depth': 5, 'learning_rate': 0.08937939657948939, 'subsample': 0.7320832480224756, 'colsample_bytree': 0.9987760703916868, 'gamma': 1.50560967934853, 'reg_alpha': 0.4807099593747105, 'reg_lambda': 0.7007249074349088}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:47,294] Trial 17 finished with value: 0.00663918354401624 and parameters: {'n_estimators': 90, 'max_depth': 9, 'learning_rate': 0.010304741738287996, 'subsample': 0.5965772670814112, 'colsample_bytree': 0.810693617854353, 'gamma': 2.987044029957818, 'reg_alpha': 0.15004044272720002, 'reg_lambda': 0.9725371615694804}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:47,354] Trial 18 finished with value: 0.006639441377113049 and parameters: {'n_estimators': 145, 'max_depth': 3, 'learning_rate': 0.08408326876865087, 'subsample': 0.8132394567758081, 'colsample_bytree': 0.9478668969549889, 'gamma': 1.6016986762895833, 'reg_alpha': 0.7054537062738465, 'reg_lambda': 0.8211787696055182}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:47,439] Trial 19 finished with value: 0.006639244176885648 and parameters: {'n_estimators': 287, 'max_depth': 8, 'learning_rate': 0.002045788358293527, 'subsample': 0.7544175409906753, 'colsample_bytree': 0.7292524739231765, 'gamma': 2.507285077111834, 'reg_alpha': 0.9265817875897115, 'reg_lambda': 0.5997961892856538}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:47,515] Trial 20 finished with value: 0.006638908925280437 and parameters: {'n_estimators': 232, 'max_depth': 7, 'learning_rate': 0.07367942682468255, 'subsample': 0.9426468000574798, 'colsample_bytree': 0.8380549877235325, 'gamma': 4.131544247873544, 'reg_alpha': 0.20822120744146577, 'reg_lambda': 0.632630392762318}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:47,657] Trial 21 finished with value: 0.006466085633585645 and parameters: {'n_estimators': 104, 'max_depth': 8, 'learning_rate': 0.041839372232675406, 'subsample': 0.6933145661944937, 'colsample_bytree': 0.8603839881118781, 'gamma': 0.008319455585231554, 'reg_alpha': 0.4206066847461809, 'reg_lambda': 0.7773732842498771}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:47,785] Trial 22 finished with value: 0.006301721002441534 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.010560714299866, 'subsample': 0.7098148898636488, 'colsample_bytree': 0.7582938560328524, 'gamma': 0.032147000566554326, 'reg_alpha': 0.5170652578909041, 'reg_lambda': 0.7002878332497945}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:47,846] Trial 23 finished with value: 0.006639496848525629 and parameters: {'n_estimators': 136, 'max_depth': 9, 'learning_rate': 0.012265141778581335, 'subsample': 0.6098220391828382, 'colsample_bytree': 0.7665928195277728, 'gamma': 1.0030091995378925, 'reg_alpha': 0.5405354563792806, 'reg_lambda': 0.5402643047262188}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:47,899] Trial 24 finished with value: 0.006627381110814869 and parameters: {'n_estimators': 90, 'max_depth': 9, 'learning_rate': 0.0012637886401969346, 'subsample': 0.7813206776683049, 'colsample_bytree': 0.7836254946001493, 'gamma': 0.5598063886894273, 'reg_alpha': 0.6405301333656301, 'reg_lambda': 0.6680838764928432}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:47,967] Trial 25 finished with value: 0.006639347839261474 and parameters: {'n_estimators': 169, 'max_depth': 10, 'learning_rate': 0.008956240105903325, 'subsample': 0.7072958782974686, 'colsample_bytree': 0.9074136202529427, 'gamma': 1.0952553048451468, 'reg_alpha': 0.5144454199769116, 'reg_lambda': 0.8582109799987773}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:48,037] Trial 26 finished with value: 0.006347119039313141 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.022101999410027124, 'subsample': 0.5434080270689022, 'colsample_bytree': 0.6721148329848075, 'gamma': 0.06143050311283583, 'reg_alpha': 0.3925089956373967, 'reg_lambda': 0.9982330290498187}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:48,095] Trial 27 finished with value: 0.006347686201942097 and parameters: {'n_estimators': 79, 'max_depth': 7, 'learning_rate': 0.12156183152134722, 'subsample': 0.6508255378436929, 'colsample_bytree': 0.8301327639775797, 'gamma': 0.4399976953300124, 'reg_alpha': 0.2825137975289681, 'reg_lambda': 0.5589037875654562}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:48,205] Trial 28 finished with value: 0.006639176773378126 and parameters: {'n_estimators': 111, 'max_depth': 8, 'learning_rate': 0.006753602795183094, 'subsample': 0.8277917424824848, 'colsample_bytree': 0.7348732954194441, 'gamma': 1.7847818851578627, 'reg_alpha': 0.7721386101528903, 'reg_lambda': 0.44393967157843844}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:48,666] Trial 29 finished with value: 0.006610955244003932 and parameters: {'n_estimators': 147, 'max_depth': 10, 'learning_rate': 0.034535863522134454, 'subsample': 0.7244278109981883, 'colsample_bytree': 0.5658975696233719, 'gamma': 0.8214171946236939, 'reg_alpha': 0.47711822407262444, 'reg_lambda': 0.888363027724735}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:48,720] Trial 30 finished with value: 0.00652377727805744 and parameters: {'n_estimators': 87, 'max_depth': 9, 'learning_rate': 0.14195914187745576, 'subsample': 0.788754242045563, 'colsample_bytree': 0.9176194214613463, 'gamma': 0.852960799573473, 'reg_alpha': 0.042745180079641565, 'reg_lambda': 0.698118545055729}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:48,804] Trial 31 finished with value: 0.006404594532205043 and parameters: {'n_estimators': 54, 'max_depth': 9, 'learning_rate': 0.01922533992367384, 'subsample': 0.5167452349389924, 'colsample_bytree': 0.6620891705249411, 'gamma': 0.03534684363929795, 'reg_alpha': 0.3736467147599932, 'reg_lambda': 0.9810873166337492}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:48,855] Trial 32 finished with value: 0.006491198968803299 and parameters: {'n_estimators': 50, 'max_depth': 10, 'learning_rate': 0.020078484525431924, 'subsample': 0.5518638632727146, 'colsample_bytree': 0.7027344958226833, 'gamma': 0.2771028052104443, 'reg_alpha': 0.5559079951434298, 'reg_lambda': 0.7956049990278877}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:48,911] Trial 33 finished with value: 0.006639390751424509 and parameters: {'n_estimators': 69, 'max_depth': 8, 'learning_rate': 0.06509516121103323, 'subsample': 0.6301338653414271, 'colsample_bytree': 0.606831655862651, 'gamma': 1.1662498213359282, 'reg_alpha': 0.35978426053969553, 'reg_lambda': 0.9259906250185643}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:48,971] Trial 34 finished with value: 0.006615920311380789 and parameters: {'n_estimators': 128, 'max_depth': 9, 'learning_rate': 0.004288227887074307, 'subsample': 0.9992483437747104, 'colsample_bytree': 0.6708187243246132, 'gamma': 0.6526688679913594, 'reg_alpha': 0.2477437543559573, 'reg_lambda': 0.8408094544836425}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:49,029] Trial 35 finished with value: 0.0064125718155819515 and parameters: {'n_estimators': 67, 'max_depth': 8, 'learning_rate': 0.04824113268098551, 'subsample': 0.5559463809478201, 'colsample_bytree': 0.7776919233583341, 'gamma': 0.2874759978452555, 'reg_alpha': 0.11501973861169967, 'reg_lambda': 0.32986905899557223}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:49,090] Trial 36 finished with value: 0.006607117394766781 and parameters: {'n_estimators': 152, 'max_depth': 9, 'learning_rate': 0.024113375823604424, 'subsample': 0.6723635306632277, 'colsample_bytree': 0.8137955176691566, 'gamma': 0.7650358570112062, 'reg_alpha': 0.6084294231388191, 'reg_lambda': 0.4434984878479063}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:49,161] Trial 37 finished with value: 0.006571683418840668 and parameters: {'n_estimators': 92, 'max_depth': 10, 'learning_rate': 0.002602669946898981, 'subsample': 0.6285648193826118, 'colsample_bytree': 0.6081665647597969, 'gamma': 0.23299649303848977, 'reg_alpha': 0.6757574580536274, 'reg_lambda': 0.7312888107694168}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:49,212] Trial 38 finished with value: 0.006455063739666334 and parameters: {'n_estimators': 74, 'max_depth': 6, 'learning_rate': 0.13981440531784883, 'subsample': 0.7664003351974712, 'colsample_bytree': 0.7298014523679568, 'gamma': 0.5537171221004406, 'reg_alpha': 0.39517535909345103, 'reg_lambda': 0.915397799240615}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:49,280] Trial 39 finished with value: 0.006639865313935139 and parameters: {'n_estimators': 183, 'max_depth': 7, 'learning_rate': 0.014059927337475188, 'subsample': 0.5572787949357259, 'colsample_bytree': 0.79123944087475, 'gamma': 1.3198546551340211, 'reg_alpha': 0.32488663210390695, 'reg_lambda': 0.9989105372037634}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:49,463] Trial 40 finished with value: 0.006371101015138325 and parameters: {'n_estimators': 116, 'max_depth': 8, 'learning_rate': 0.008624080873168474, 'subsample': 0.9516943256831643, 'colsample_bytree': 0.6760362462246895, 'gamma': 0.006151473511368355, 'reg_alpha': 0.584659346366112, 'reg_lambda': 0.6681334371185682}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:49,522] Trial 41 finished with value: 0.006305443724088112 and parameters: {'n_estimators': 84, 'max_depth': 7, 'learning_rate': 0.15054406897625056, 'subsample': 0.6525060224157996, 'colsample_bytree': 0.8371936228489791, 'gamma': 0.43085391024200875, 'reg_alpha': 0.27498568027979364, 'reg_lambda': 0.5486789458402563}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:49,574] Trial 42 finished with value: 0.006348358484570116 and parameters: {'n_estimators': 65, 'max_depth': 7, 'learning_rate': 0.18056205850324777, 'subsample': 0.67080825267093, 'colsample_bytree': 0.5025685343403373, 'gamma': 0.3732327315631754, 'reg_alpha': 0.4567322168548862, 'reg_lambda': 0.4886901031492971}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:49,632] Trial 43 finished with value: 0.006541225343649626 and parameters: {'n_estimators': 77, 'max_depth': 6, 'learning_rate': 0.06677666642169239, 'subsample': 0.7325982454940688, 'colsample_bytree': 0.8300909469761267, 'gamma': 0.6493171234535442, 'reg_alpha': 0.23351651174385907, 'reg_lambda': 0.5714792158202665}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:49,698] Trial 44 finished with value: 0.006317163721979678 and parameters: {'n_estimators': 61, 'max_depth': 9, 'learning_rate': 0.02569382723992561, 'subsample': 0.7100807257393642, 'colsample_bytree': 0.8805501987119211, 'gamma': 0.1753184201553839, 'reg_alpha': 0.2851348324190779, 'reg_lambda': 0.6550835302714708}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:49,758] Trial 45 finished with value: 0.006586726225870099 and parameters: {'n_estimators': 98, 'max_depth': 9, 'learning_rate': 0.054625375164656535, 'subsample': 0.7094685069015392, 'colsample_bytree': 0.8947037152263274, 'gamma': 0.9354166153521879, 'reg_alpha': 0.10079603919272809, 'reg_lambda': 0.6470872887336562}. Best is trial 12 with value: 0.006275676015292823.
# [I 2025-08-03 13:29:49,819] Trial 46 finished with value: 0.006232951214407473 and parameters: {'n_estimators': 129, 'max_depth': 7, 'learning_rate': 0.29384946356746605, 'subsample': 0.6819373374847123, 'colsample_bytree': 0.9291209499429008, 'gamma': 0.23411562765066524, 'reg_alpha': 0.28379230879937756, 'reg_lambda': 0.5060847656872038}. Best is trial 46 with value: 0.006232951214407473.
# [I 2025-08-03 13:29:49,882] Trial 47 finished with value: 0.006221072923059413 and parameters: {'n_estimators': 120, 'max_depth': 5, 'learning_rate': 0.2909163511717961, 'subsample': 0.6525095024077675, 'colsample_bytree': 0.9561035892739336, 'gamma': 0.4639987653630576, 'reg_alpha': 0.28660929091383, 'reg_lambda': 0.3757982694659491}. Best is trial 47 with value: 0.006221072923059413.
# [I 2025-08-03 13:29:50,025] A new study created in memory with name: no-name-a4395d81-414a-4363-ad03-adee62bc7f40
# [I 2025-08-03 13:29:49,947] Trial 48 finished with value: 0.00630985704610716 and parameters: {'n_estimators': 135, 'max_depth': 5, 'learning_rate': 0.28691301334296676, 'subsample': 0.6379787630359728, 'colsample_bytree': 0.934139957218022, 'gamma': 0.47524317571635577, 'reg_alpha': 0.19074591085839396, 'reg_lambda': 0.26007397079634054}. Best is trial 47 with value: 0.006221072923059413.
# [I 2025-08-03 13:29:50,013] Trial 49 finished with value: 0.006638309336611195 and parameters: {'n_estimators': 121, 'max_depth': 5, 'learning_rate': 0.2119421076234983, 'subsample': 0.6086800652561348, 'colsample_bytree': 0.9737729928207507, 'gamma': 4.00046019068776, 'reg_alpha': 0.3245378111588131, 'reg_lambda': 0.3254766657287884}. Best is trial 47 with value: 0.006221072923059413.
#
# 🚀 Running Optuna for LAG=15
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-08-03 13:29:50,069] Trial 0 finished with value: 0.006588199703404891 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.035093904781414616, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132, 'reg_alpha': 0.05808361216819946, 'reg_lambda': 0.8661761457749352}. Best is trial 0 with value: 0.006588199703404891.
# [I 2025-08-03 13:29:50,115] Trial 1 finished with value: 0.0066510267631970455 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.00011791655502618509, 'subsample': 0.9849549260809971, 'colsample_bytree': 0.9162213204002109, 'gamma': 1.0616955533913808, 'reg_alpha': 0.18182496720710062, 'reg_lambda': 0.18340450985343382}. Best is trial 0 with value: 0.006588199703404891.
# [I 2025-08-03 13:29:50,228] Trial 2 finished with value: 0.006633558357438324 and parameters: {'n_estimators': 126, 'max_depth': 7, 'learning_rate': 0.0031763269920199078, 'subsample': 0.645614570099021, 'colsample_bytree': 0.8059264473611898, 'gamma': 0.6974693032602092, 'reg_alpha': 0.29214464853521815, 'reg_lambda': 0.3663618432936917}. Best is trial 0 with value: 0.006588199703404891.
# [I 2025-08-03 13:29:50,789] Trial 3 finished with value: 0.006616433946423099 and parameters: {'n_estimators': 164, 'max_depth': 9, 'learning_rate': 0.0004946408182937843, 'subsample': 0.7571172192068059, 'colsample_bytree': 0.7962072844310213, 'gamma': 0.23225206359998862, 'reg_alpha': 0.6075448519014384, 'reg_lambda': 0.17052412368729153}. Best is trial 0 with value: 0.006588199703404891.
# [I 2025-08-03 13:29:50,954] Trial 4 finished with value: 0.006449552601847291 and parameters: {'n_estimators': 66, 'max_depth': 10, 'learning_rate': 0.22783459357466163, 'subsample': 0.9041986740582306, 'colsample_bytree': 0.6523068845866853, 'gamma': 0.48836057003191935, 'reg_alpha': 0.6842330265121569, 'reg_lambda': 0.4401524937396013}. Best is trial 4 with value: 0.006449552601847291.
# [I 2025-08-03 13:29:51,039] Trial 5 finished with value: 0.006651024353363819 and parameters: {'n_estimators': 80, 'max_depth': 6, 'learning_rate': 0.00013169614353741142, 'subsample': 0.954660201039391, 'colsample_bytree': 0.6293899908000085, 'gamma': 3.31261142176991, 'reg_alpha': 0.31171107608941095, 'reg_lambda': 0.5200680211778108}. Best is trial 4 with value: 0.006449552601847291.
# [I 2025-08-03 13:29:51,559] Trial 6 finished with value: 0.006650683532178562 and parameters: {'n_estimators': 187, 'max_depth': 4, 'learning_rate': 0.23515992740571925, 'subsample': 0.8875664116805573, 'colsample_bytree': 0.9697494707820946, 'gamma': 4.474136752138244, 'reg_alpha': 0.5978999788110851, 'reg_lambda': 0.9218742350231168}. Best is trial 4 with value: 0.006449552601847291.
# [I 2025-08-03 13:29:51,687] Trial 7 finished with value: 0.006651016220460826 and parameters: {'n_estimators': 72, 'max_depth': 4, 'learning_rate': 0.0001436351616738488, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'gamma': 1.3567451588694794, 'reg_alpha': 0.8287375091519293, 'reg_lambda': 0.3567533266935893}. Best is trial 4 with value: 0.006449552601847291.
# [I 2025-08-03 13:29:51,860] Trial 8 finished with value: 0.006651015972027565 and parameters: {'n_estimators': 120, 'max_depth': 7, 'learning_rate': 0.0003090370987350513, 'subsample': 0.9010984903770198, 'colsample_bytree': 0.5372753218398854, 'gamma': 4.9344346830025865, 'reg_alpha': 0.7722447692966574, 'reg_lambda': 0.1987156815341724}. Best is trial 4 with value: 0.006449552601847291.
# [I 2025-08-03 13:29:52,042] Trial 9 finished with value: 0.006432679104068846 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.02869648437859116, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'gamma': 0.3702232586704518, 'reg_alpha': 0.3584657285442726, 'reg_lambda': 0.11586905952512971}. Best is trial 9 with value: 0.006432679104068846.
# [I 2025-08-03 13:29:52,127] Trial 10 finished with value: 0.006651069566054004 and parameters: {'n_estimators': 270, 'max_depth': 6, 'learning_rate': 0.016998787242493218, 'subsample': 0.5089809378074097, 'colsample_bytree': 0.8770690800880656, 'gamma': 2.0963905612410483, 'reg_alpha': 0.9597707459454197, 'reg_lambda': 0.011114384822711307}. Best is trial 9 with value: 0.006432679104068846.
# [I 2025-08-03 13:29:52,173] Trial 11 finished with value: 0.006649981131208954 and parameters: {'n_estimators': 58, 'max_depth': 10, 'learning_rate': 0.2698540583506237, 'subsample': 0.8406708897311783, 'colsample_bytree': 0.7065034325177559, 'gamma': 2.0482246664498587, 'reg_alpha': 0.42829162619021155, 'reg_lambda': 0.6195339431335992}. Best is trial 9 with value: 0.006432679104068846.
# [I 2025-08-03 13:29:52,260] Trial 12 finished with value: 0.006300939408428155 and parameters: {'n_estimators': 52, 'max_depth': 9, 'learning_rate': 0.05032216033455566, 'subsample': 0.8875263785117047, 'colsample_bytree': 0.8504769022050217, 'gamma': 0.04270853218288917, 'reg_alpha': 0.48196008860966605, 'reg_lambda': 0.719199831432569}. Best is trial 12 with value: 0.006300939408428155.
# [I 2025-08-03 13:29:54,060] Trial 13 finished with value: 0.006301926167268983 and parameters: {'n_estimators': 105, 'max_depth': 8, 'learning_rate': 0.041631203702173776, 'subsample': 0.6929722841849172, 'colsample_bytree': 0.8553002072218189, 'gamma': 0.01482767219699932, 'reg_alpha': 0.4381301674911343, 'reg_lambda': 0.7388723479770365}. Best is trial 12 with value: 0.006300939408428155.
# [I 2025-08-03 13:29:54,158] Trial 14 finished with value: 0.006317897382456836 and parameters: {'n_estimators': 104, 'max_depth': 8, 'learning_rate': 0.06531366650489707, 'subsample': 0.683813616290651, 'colsample_bytree': 0.8061578814677635, 'gamma': 0.03312264314708315, 'reg_alpha': 0.5113924370327606, 'reg_lambda': 0.7380983421262324}. Best is trial 12 with value: 0.006300939408428155.
# [I 2025-08-03 13:29:54,235] Trial 15 finished with value: 0.006650941244360209 and parameters: {'n_estimators': 245, 'max_depth': 8, 'learning_rate': 0.005567406174693454, 'subsample': 0.5827781406926889, 'colsample_bytree': 0.9384223782609153, 'gamma': 3.2951430240448687, 'reg_alpha': 0.4595228024162464, 'reg_lambda': 0.7519855389250322}. Best is trial 12 with value: 0.006300939408428155.
# [I 2025-08-03 13:29:54,294] Trial 16 finished with value: 0.006650618510021224 and parameters: {'n_estimators': 104, 'max_depth': 5, 'learning_rate': 0.005710223577172772, 'subsample': 0.7320832480224756, 'colsample_bytree': 0.9987760703916868, 'gamma': 1.50560967934853, 'reg_alpha': 0.00474011965308907, 'reg_lambda': 0.7012604427751764}. Best is trial 12 with value: 0.006300939408428155.
# [I 2025-08-03 13:29:54,346] Trial 17 finished with value: 0.006651229849690867 and parameters: {'n_estimators': 90, 'max_depth': 9, 'learning_rate': 0.083685407404487, 'subsample': 0.793063224352817, 'colsample_bytree': 0.8389308979684607, 'gamma': 2.987044029957818, 'reg_alpha': 0.15004044272720002, 'reg_lambda': 0.97263823942796}. Best is trial 12 with value: 0.006300939408428155.
# [I 2025-08-03 13:29:54,412] Trial 18 finished with value: 0.006650421860570801 and parameters: {'n_estimators': 157, 'max_depth': 3, 'learning_rate': 0.012293443195622063, 'subsample': 0.5852482777708781, 'colsample_bytree': 0.7476985607045912, 'gamma': 1.6016986762895833, 'reg_alpha': 0.5494323564836533, 'reg_lambda': 0.8211787696055182}. Best is trial 12 with value: 0.006300939408428155.
# [I 2025-08-03 13:29:54,484] Trial 19 finished with value: 0.006650919458140599 and parameters: {'n_estimators': 211, 'max_depth': 8, 'learning_rate': 0.0014543323044061754, 'subsample': 0.7163728055902456, 'colsample_bytree': 0.8543200188143997, 'gamma': 2.507285077111834, 'reg_alpha': 0.209793393871968, 'reg_lambda': 0.5997961892856538}. Best is trial 12 with value: 0.006300939408428155.
# [I 2025-08-03 13:29:54,564] Trial 20 finished with value: 0.006650498250747717 and parameters: {'n_estimators': 132, 'max_depth': 7, 'learning_rate': 0.10328582710435825, 'subsample': 0.8104153164927594, 'colsample_bytree': 0.7602245068458993, 'gamma': 4.131544247873544, 'reg_alpha': 0.3970793217006944, 'reg_lambda': 0.632630392762318}. Best is trial 12 with value: 0.006300939408428155.
# ...
# [I 2025-08-03 13:29:58,556] Trial 10 finished with value: 0.006662957436325643 and parameters: {'n_estimators': 270, 'max_depth': 6, 'learning_rate': 0.016998787242493218, 'subsample': 0.5089809378074097, 'colsample_bytree': 0.8770690800880656, 'gamma': 2.0963905612410483, 'reg_alpha': 0.9597707459454197, 'reg_lambda': 0.011114384822711307}. Best is trial 9 with value: 0.00646392608876589.
# [I 2025-08-03 13:29:58,615] Trial 11 finished with value: 0.006664365178084072 and parameters: {'n_estimators': 58, 'max_depth': 10, 'learning_rate': 0.2698540583506237, 'subsample': 0.8406708897311783, 'colsample_bytree': 0.7065034325177559, 'gamma': 2.0482246664498587, 'reg_alpha': 0.42829162619021155, 'reg_lambda': 0.6195339431335992}. Best is trial 9 with value: 0.00646392608876589.
# [I 2025-08-03 13:29:58,750] Trial 12 finished with value: 0.006262856339708151 and parameters: {'n_estimators': 52, 'max_depth': 9, 'learning_rate': 0.05032216033455566, 'subsample': 0.8875263785117047, 'colsample_bytree': 0.8504769022050217, 'gamma': 0.04270853218288917, 'reg_alpha': 0.48196008860966605, 'reg_lambda': 0.719199831432569}. Best is trial 12 with value: 0.006262856339708151.
# [I 2025-08-03 13:29:58,941] Trial 13 finished with value: 0.006265369333798516 and parameters: {'n_estimators': 105, 'max_depth': 8, 'learning_rate': 0.041631203702173776, 'subsample': 0.6929722841849172, 'colsample_bytree': 0.8553002072218189, 'gamma': 0.01482767219699932, 'reg_alpha': 0.4381301674911343, 'reg_lambda': 0.7388723479770365}. Best is trial 12 with value: 0.006262856339708151.
# [I 2025-08-03 13:29:59,051] Trial 14 finished with value: 0.006172155474459289 and parameters: {'n_estimators': 104, 'max_depth': 8, 'learning_rate': 0.06531366650489707, 'subsample': 0.683813616290651, 'colsample_bytree': 0.8061578814677635, 'gamma': 0.03312264314708315, 'reg_alpha': 0.5113924370327606, 'reg_lambda': 0.7380983421262324}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:29:59,127] Trial 15 finished with value: 0.006662827646522585 and parameters: {'n_estimators': 218, 'max_depth': 8, 'learning_rate': 0.004869477890923847, 'subsample': 0.5827781406926889, 'colsample_bytree': 0.7548572093429927, 'gamma': 3.2951430240448687, 'reg_alpha': 0.5442138262378953, 'reg_lambda': 0.7514892999269548}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:29:59,189] Trial 16 finished with value: 0.0066632025427229465 and parameters: {'n_estimators': 103, 'max_depth': 5, 'learning_rate': 0.08937939657948939, 'subsample': 0.7320832480224756, 'colsample_bytree': 0.9987760703916868, 'gamma': 1.50560967934853, 'reg_alpha': 0.4807099593747105, 'reg_lambda': 0.7007249074349088}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:29:59,243] Trial 17 finished with value: 0.006662720663712305 and parameters: {'n_estimators': 90, 'max_depth': 9, 'learning_rate': 0.010304741738287996, 'subsample': 0.5965772670814112, 'colsample_bytree': 0.810693617854353, 'gamma': 2.987044029957818, 'reg_alpha': 0.15004044272720002, 'reg_lambda': 0.9725371615694804}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:29:59,314] Trial 18 finished with value: 0.0066625329145759025 and parameters: {'n_estimators': 145, 'max_depth': 3, 'learning_rate': 0.08408326876865087, 'subsample': 0.8132394567758081, 'colsample_bytree': 0.9478668969549889, 'gamma': 1.6016986762895833, 'reg_alpha': 0.7054537062738465, 'reg_lambda': 0.8211787696055182}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:29:59,403] Trial 19 finished with value: 0.006662893666482909 and parameters: {'n_estimators': 287, 'max_depth': 8, 'learning_rate': 0.002045788358293527, 'subsample': 0.7544175409906753, 'colsample_bytree': 0.7292524739231765, 'gamma': 2.507285077111834, 'reg_alpha': 0.9265817875897115, 'reg_lambda': 0.5997961892856538}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:29:59,484] Trial 20 finished with value: 0.006663160726820329 and parameters: {'n_estimators': 232, 'max_depth': 7, 'learning_rate': 0.07367942682468255, 'subsample': 0.9426468000574798, 'colsample_bytree': 0.8380549877235325, 'gamma': 4.131544247873544, 'reg_alpha': 0.20822120744146577, 'reg_lambda': 0.632630392762318}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:29:59,677] Trial 21 finished with value: 0.0062314157017312275 and parameters: {'n_estimators': 104, 'max_depth': 8, 'learning_rate': 0.041839372232675406, 'subsample': 0.6933145661944937, 'colsample_bytree': 0.8603839881118781, 'gamma': 0.008319455585231554, 'reg_alpha': 0.4206066847461809, 'reg_lambda': 0.7773732842498771}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:29:59,864] Trial 22 finished with value: 0.0064602573057148055 and parameters: {'n_estimators': 95, 'max_depth': 9, 'learning_rate': 0.011515486719282101, 'subsample': 0.7013976718145156, 'colsample_bytree': 0.7762859398614304, 'gamma': 0.03261525725258489, 'reg_alpha': 0.38217601969640136, 'reg_lambda': 0.8199603518781381}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:29:59,928] Trial 23 finished with value: 0.0066629719204859324 and parameters: {'n_estimators': 127, 'max_depth': 8, 'learning_rate': 0.09632274858376612, 'subsample': 0.6098220391828382, 'colsample_bytree': 0.9312404495902853, 'gamma': 1.0030091995378925, 'reg_alpha': 0.5285058532003568, 'reg_lambda': 0.5420414199764683}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:30:00,000] Trial 24 finished with value: 0.006565614661785706 and parameters: {'n_estimators': 162, 'max_depth': 9, 'learning_rate': 0.02729915434063638, 'subsample': 0.543751215745677, 'colsample_bytree': 0.893684048078114, 'gamma': 0.5598063886894273, 'reg_alpha': 0.6405301333656301, 'reg_lambda': 0.6937545605969989}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:30:00,057] Trial 25 finished with value: 0.006662882989833923 and parameters: {'n_estimators': 83, 'max_depth': 7, 'learning_rate': 0.0015378813981304711, 'subsample': 0.7884122663654135, 'colsample_bytree': 0.838967982769388, 'gamma': 1.0952553048451468, 'reg_alpha': 0.26595117705138516, 'reg_lambda': 0.9994134940876853}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:30:00,120] Trial 26 finished with value: 0.006302065042953759 and parameters: {'n_estimators': 51, 'max_depth': 6, 'learning_rate': 0.1503099768209541, 'subsample': 0.6533429221449959, 'colsample_bytree': 0.7646649782238025, 'gamma': 0.06030603737496811, 'reg_alpha': 0.519373353932616, 'reg_lambda': 0.7982421402162245}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:30:00,186] Trial 27 finished with value: 0.006431989610702484 and parameters: {'n_estimators': 111, 'max_depth': 8, 'learning_rate': 0.06038464144673314, 'subsample': 0.7140170404054523, 'colsample_bytree': 0.8364173367413742, 'gamma': 0.43348117302547323, 'reg_alpha': 0.39442420456951016, 'reg_lambda': 0.882003953693224}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:30:00,255] Trial 28 finished with value: 0.006662679905254675 and parameters: {'n_estimators': 146, 'max_depth': 10, 'learning_rate': 0.018946994169175425, 'subsample': 0.6707744594084097, 'colsample_bytree': 0.9073514900326972, 'gamma': 1.7847818851578627, 'reg_alpha': 0.46960290061321075, 'reg_lambda': 0.44393967157843844}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:30:00,318] Trial 29 finished with value: 0.006652744769007199 and parameters: {'n_estimators': 137, 'max_depth': 9, 'learning_rate': 0.009931691974992779, 'subsample': 0.7855641214367867, 'colsample_bytree': 0.867722983190018, 'gamma': 0.8112997198739815, 'reg_alpha': 0.5591724660609125, 'reg_lambda': 0.89133424079528}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:30:00,375] Trial 30 finished with value: 0.006641840091311909 and parameters: {'n_estimators': 82, 'max_depth': 10, 'learning_rate': 0.04075908532968516, 'subsample': 0.8259166108361521, 'colsample_bytree': 0.727645998790876, 'gamma': 0.852960799573473, 'reg_alpha': 0.042745180079641565, 'reg_lambda': 0.6864890368638324}. Best is trial 14 with value: 0.006172155474459289.
# [I 2025-08-03 13:30:00,499] Trial 31 finished with value: 0.0061425936155359755 and parameters: {'n_estimators': 108, 'max_depth': 8, 'learning_rate': 0.047333624497498526, 'subsample': 0.6934233036770566, 'colsample_bytree': 0.8487699201744954, 'gamma': 0.035379587852154296, 'reg_alpha': 0.4451563061521754, 'reg_lambda': 0.7522427035473951}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:00,570] Trial 32 finished with value: 0.0062906773603735085 and parameters: {'n_estimators': 110, 'max_depth': 8, 'learning_rate': 0.14613260974541753, 'subsample': 0.6228296231572935, 'colsample_bytree': 0.8121037154346977, 'gamma': 0.30525575631852175, 'reg_alpha': 0.34481458089961303, 'reg_lambda': 0.7876777343770691}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:00,625] Trial 33 finished with value: 0.006546164511418928 and parameters: {'n_estimators': 68, 'max_depth': 7, 'learning_rate': 0.04554066098739177, 'subsample': 0.728218659340689, 'colsample_bytree': 0.782637449374022, 'gamma': 0.6817777843214679, 'reg_alpha': 0.2569397331071626, 'reg_lambda': 0.6022234632768382}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:00,703] Trial 34 finished with value: 0.006662950649213059 and parameters: {'n_estimators': 164, 'max_depth': 9, 'learning_rate': 0.13721157312829985, 'subsample': 0.9992483437747104, 'colsample_bytree': 0.926074127850352, 'gamma': 1.1133709290967047, 'reg_alpha': 0.12231542722209077, 'reg_lambda': 0.8479525041746763}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:00,775] Trial 35 finished with value: 0.006380560315704824 and parameters: {'n_estimators': 129, 'max_depth': 8, 'learning_rate': 0.01757280174521474, 'subsample': 0.7703347328258917, 'colsample_bytree': 0.8156367309350179, 'gamma': 0.282102129110473, 'reg_alpha': 0.4545190299936503, 'reg_lambda': 0.7364420271173002}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:00,953] Trial 36 finished with value: 0.0064273010824812534 and parameters: {'n_estimators': 96, 'max_depth': 7, 'learning_rate': 0.006850686926086856, 'subsample': 0.6856999054193891, 'colsample_bytree': 0.8608728221458501, 'gamma': 0.012684058070773285, 'reg_alpha': 0.610161722049085, 'reg_lambda': 0.9324008222196442}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:01,027] Trial 37 finished with value: 0.006571109134290702 and parameters: {'n_estimators': 197, 'max_depth': 9, 'learning_rate': 0.05484889544579998, 'subsample': 0.747170160666685, 'colsample_bytree': 0.6640253143746593, 'gamma': 0.6598786052013831, 'reg_alpha': 0.7020688818562868, 'reg_lambda': 0.5397310804669194}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:01,088] Trial 38 finished with value: 0.00647521883925849 and parameters: {'n_estimators': 71, 'max_depth': 10, 'learning_rate': 0.027635316735581148, 'subsample': 0.6297278877015927, 'colsample_bytree': 0.791376475597982, 'gamma': 0.4675037459656868, 'reg_alpha': 0.33564904328498707, 'reg_lambda': 0.6531691328422862}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:01,166] Trial 39 finished with value: 0.006662746241565418 and parameters: {'n_estimators': 173, 'max_depth': 6, 'learning_rate': 0.12298078270272872, 'subsample': 0.5572787949357259, 'colsample_bytree': 0.9582664347831222, 'gamma': 1.2949151745045464, 'reg_alpha': 0.5853120150996272, 'reg_lambda': 0.4455578941354553}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:01,232] Trial 40 finished with value: 0.006329971995052628 and parameters: {'n_estimators': 117, 'max_depth': 7, 'learning_rate': 0.21442369156225974, 'subsample': 0.9516943256831643, 'colsample_bytree': 0.5861746909439679, 'gamma': 0.24475223086731726, 'reg_alpha': 0.6467499020066545, 'reg_lambda': 0.34286633719230064}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:01,344] Trial 41 finished with value: 0.006211208909090898 and parameters: {'n_estimators': 153, 'max_depth': 8, 'learning_rate': 0.040703649136061455, 'subsample': 0.6930634977059028, 'colsample_bytree': 0.8640658780572427, 'gamma': 0.06749853299711986, 'reg_alpha': 0.4213462982933589, 'reg_lambda': 0.7465915123933438}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:01,425] Trial 42 finished with value: 0.006321162549690872 and parameters: {'n_estimators': 156, 'max_depth': 8, 'learning_rate': 0.027016846954245378, 'subsample': 0.6446511275191649, 'colsample_bytree': 0.8356143205280474, 'gamma': 0.27367955978326647, 'reg_alpha': 0.41043017752994654, 'reg_lambda': 0.7755578535451436}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:01,502] Trial 43 finished with value: 0.0065374500052886465 and parameters: {'n_estimators': 183, 'max_depth': 8, 'learning_rate': 0.06277873528659798, 'subsample': 0.6785703642675246, 'colsample_bytree': 0.9037304266627941, 'gamma': 0.6373903414662616, 'reg_alpha': 0.4935541297281312, 'reg_lambda': 0.7126545201264745}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:01,603] Trial 44 finished with value: 0.006297818176093079 and parameters: {'n_estimators': 134, 'max_depth': 9, 'learning_rate': 0.019805303129192653, 'subsample': 0.7175091218326057, 'colsample_bytree': 0.8805501987119211, 'gamma': 0.170835876054645, 'reg_alpha': 0.29332885987174045, 'reg_lambda': 0.8549403566418013}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:01,668] Trial 45 finished with value: 0.0066495437067074946 and parameters: {'n_estimators': 121, 'max_depth': 8, 'learning_rate': 0.04367550360047574, 'subsample': 0.6467113201568951, 'colsample_bytree': 0.8220893763949403, 'gamma': 0.9042815346010866, 'reg_alpha': 0.4150759577325473, 'reg_lambda': 0.5696285745624432}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:01,734] Trial 46 finished with value: 0.006474818007724281 and parameters: {'n_estimators': 82, 'max_depth': 9, 'learning_rate': 0.1834080504574076, 'subsample': 0.7016214543334248, 'colsample_bytree': 0.8584466718627229, 'gamma': 0.5582449383536544, 'reg_alpha': 0.5041888841818506, 'reg_lambda': 0.6581420232265716}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:01,791] Trial 47 finished with value: 0.006501707811550796 and parameters: {'n_estimators': 61, 'max_depth': 7, 'learning_rate': 0.03338371477786829, 'subsample': 0.8827511053116963, 'colsample_bytree': 0.7954899669177083, 'gamma': 0.3917206188552349, 'reg_alpha': 0.766167925264151, 'reg_lambda': 0.9372977398644292}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:01,852] Trial 48 finished with value: 0.006662831914073086 and parameters: {'n_estimators': 101, 'max_depth': 8, 'learning_rate': 0.004497682604243661, 'subsample': 0.7700336342921523, 'colsample_bytree': 0.8888692602085908, 'gamma': 3.8316046365407663, 'reg_alpha': 0.37196264175443683, 'reg_lambda': 0.7608742277359258}. Best is trial 31 with value: 0.0061425936155359755.
# [I 2025-08-03 13:30:01,921] Trial 49 finished with value: 0.0066626384363083335 and parameters: {'n_estimators': 149, 'max_depth': 7, 'learning_rate': 0.014502407785021602, 'subsample': 0.7444452474866176, 'colsample_bytree': 0.7359767350948349, 'gamma': 1.2882999286024106, 'reg_alpha': 0.45577108123976845, 'reg_lambda': 0.3079471818072155}. Best is trial 31 with value: 0.0061425936155359755.

# %%
print("\n📘 Summary of Optuna Results by Lag:\n")

for lag_val, result in lag_study_results.items():
    print(f"\n🌀 LAG = {lag_val}")
    print(f"Best MSE: {result['best_value']:.6f}")
    print("Best Parameters:")
    for k, v in result['best_params'].items():
        print(f"  {k}: {v}")
# Out:
# 📘 Summary of Optuna Results by Lag:
#
#
# 🌀 LAG = 5
# Best MSE: 0.006294
# Best Parameters:
#   n_estimators: 251
#   max_depth: 9
#   learning_rate: 0.06187756998698821
#   subsample: 0.64603126013113
#   colsample_bytree: 0.9586817307178935
#   gamma: 0.1642252075494953
#   reg_alpha: 0.3645818654096071
#   reg_lambda: 0.22013932501019706
#
# 🌀 LAG = 10
# Best MSE: 0.006221
# Best Parameters:
#   n_estimators: 120
#   max_depth: 5
#   learning_rate: 0.2909163511717961
#   subsample: 0.6525095024077675
#   colsample_bytree: 0.9561035892739336
#   gamma: 0.4639987653630576
#   reg_alpha: 0.28660929091383
#   reg_lambda: 0.3757982694659491
#
# 🌀 LAG = 15
# Best MSE: 0.006132
# Best Parameters:
#   n_estimators: 102
#   max_depth: 9
#   learning_rate: 0.045926489815532684
#   subsample: 0.6207056512173402
#   colsample_bytree: 0.9156725604557071
#   gamma: 0.032147000566554326
#   reg_alpha: 0.4894879087737348
#   reg_lambda: 0.7002878332497945
#
# 🌀 LAG = 20
# Best MSE: 0.006143
# Best Parameters:
#   n_estimators: 108
#   max_depth: 8
#   learning_rate: 0.047333624497498526
#   subsample: 0.6934233036770566
#   colsample_bytree: 0.8487699201744954
#   gamma: 0.035379587852154296
#   reg_alpha: 0.4451563061521754
#   reg_lambda: 0.7522427035473951

# %%
from xgboost import XGBRegressor

# --- Storage for final models and residuals ---
final_models = {}
residuals_per_lag = {}

# --- Loop over each lag from tuning history ---
for LAG, result in lag_study_results.items():
    print(f"\n📦 Retraining model on full data for LAG = {LAG}...")

    # Step 1: Recreate lagged dataframe
    lagged_df = pd.DataFrame({'target': bmm_filled})
    for i in range(1, LAG + 1):
        lagged_df[f'lag_{i}'] = bmm_filled.shift(i)
    lagged_df.dropna(inplace=True)

    # Step 2: Prepare full dataset
    X_full = lagged_df.drop("target", axis=1).values
    y_full = lagged_df["target"].values

    # Step 3: Load best parameters and create model
    best_params = result["best_params"].copy()
    best_params.update({
        "objective": "reg:squarederror",
        "random_state": SEED
    })

    model = XGBRegressor(**best_params)
    model.fit(X_full, y_full)

    # Step 4: Store model and residuals
    final_models[LAG] = model
    y_pred = model.predict(X_full)
    residuals = y_full - y_pred
    residuals_per_lag[LAG] = pd.Series(residuals, index=lagged_df.index)

    print(f"✅ Model trained and residuals saved for LAG = {LAG}")
# Out:
# 📦 Retraining model on full data for LAG = 5...
# ✅ Model trained and residuals saved for LAG = 5
#
# 📦 Retraining model on full data for LAG = 10...
# ✅ Model trained and residuals saved for LAG = 10
#
# 📦 Retraining model on full data for LAG = 15...
# ✅ Model trained and residuals saved for LAG = 15
#
# 📦 Retraining model on full data for LAG = 20...
# ✅ Model trained and residuals saved for LAG = 20

# %% [markdown]
# **3. Qulaitative Analysis**

# %%
import matplotlib.pyplot as plt

def plot_residuals_for_lag(lag):
    """
    Plots residuals for a given lag using a fixed time window.

    Parameters:
        lag (int): The lag value whose residuals one want to visualize.
    """
    if lag not in residuals_per_lag:
        print(f"❌ Lag {lag} not found in residuals_per_lag.")
        return

    # Fixed time window
    start_date = "2019-01-01"
    end_date = "2019-06-01"

    # Get residuals and slice to window
    residual_series = residuals_per_lag[lag]
    residual_window = residual_series.loc[start_date:end_date]

    # Plot
    plt.figure(figsize=(12, 4))
    plt.plot(residual_window.index, residual_window.values, color="red")
    plt.axhline(0, color="black", linestyle="--", linewidth=1)
    plt.title(f"Residuals for LAG = {lag} ({start_date} to {end_date})")
    plt.xlabel("Date")
    plt.ylabel("Residual")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
plot_residuals_for_lag(10)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# --- Load and parse ground truth maneuver timestamps ---
truth_df = pd.read_excel("/content/manFY2E_cleaned.xlsx")
ground_truth_timestamps = pd.to_datetime(
    truth_df["Start Date"].astype(str) + " " + truth_df["Start Time"].astype(str)
)

# --- Define plot function for a given lag ---
def plot_residuals_with_gt_for_lag(lag):
    """
    Plot residuals with ground truth maneuver overlay for a given lag.
    Uses fixed time window from 2013-01-01 to 2013-03-01.
    """
    if lag not in residuals_per_lag:
        print(f"❌ Residuals not found for lag {lag}")
        return

    # Fixed time window
    start_date = "2013-01-01"
    end_date = "2013-06-01"

    # Get residuals for the specified lag
    residual_series = residuals_per_lag[lag]
    residual_window = residual_series.loc[start_date:end_date]

    # Filter ground truth maneuvers to the window
    gt_in_window = ground_truth_timestamps[
        (ground_truth_timestamps >= pd.to_datetime(start_date)) &
        (ground_truth_timestamps <= pd.to_datetime(end_date))
    ]

    # Plot
    plt.figure(figsize=(14, 5))
    plt.plot(residual_window.index, residual_window.values, color='red', label='Residuals')
    plt.axhline(0, color='black', linestyle='--', linewidth=1)

    for ts in gt_in_window:
        plt.axvline(ts, color='blue', linestyle='--', alpha=0.7)

    plt.title(f"Residuals with Ground Truth Maneuvers (Lag={lag})\n{start_date} to {end_date}")
    plt.xlabel("Date")
    plt.ylabel("Residual")
    plt.grid(True)
    plt.legend(["Residuals", "Ground Truth Maneuvers"])
    plt.tight_layout()
    plt.show()

# --- Example usage ---
plot_residuals_with_gt_for_lag(10)

# %% [markdown]
# **4. Quantitative Analysis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- Precision / Recall / F1 Computation ---
def compute_prf_simple(
    residual_series: pd.Series,
    ground_truth_timestamps: pd.Series,
    threshold: float,
    matching_window_days: float = 3.0
):
    detections = residual_series[residual_series > threshold]
    detection_times = detections.index.sort_values()

    TP, FP, matched_gt = 0, 0, set()
    for det_time in detection_times:
        for i, gt_time in enumerate(ground_truth_timestamps):
            if i in matched_gt:
                continue
            if abs(det_time - gt_time) <= pd.Timedelta(days=matching_window_days):
                TP += 1
                matched_gt.add(i)
                break
        else:
            FP += 1

    FN = len(ground_truth_timestamps) - len(matched_gt)

    precision = TP / (TP + FP) if (TP + FP) else 0
    recall = TP / (TP + FN) if (TP + FN) else 0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) else 0

    return precision, recall, f1, TP, FP, FN


# --- Evaluation and PR Plot ---
summary_rows = []
lag_metrics_dfs = {}  # Store metrics per lag for later scenario analysis
plt.figure(figsize=(10, 6))
matching_window_days = 3.0

for lag, residual_series in residuals_per_lag.items():
    abs_resid = residual_series.abs()

    # FULL RANGE sweep from min to max
    thresholds = np.linspace(
        abs_resid.min(),
        abs_resid.max(),
        150
    )

    pr_points = []
    metrics = []

    for threshold in thresholds:
        precision, recall, f1, TP, FP, FN = compute_prf_simple(
            abs_resid,
            ground_truth_timestamps,
            threshold,
            matching_window_days=matching_window_days
        )
        pr_points.append((recall, precision))
        metrics.append((threshold, precision, recall, f1, TP, FP, FN))

    # Convert to DataFrame to extract best row
    metrics_df = pd.DataFrame(metrics, columns=["Threshold", "Precision", "Recall", "F1", "TP", "FP", "FN"])
    best_idx = metrics_df["F1"].idxmax()
    best_row = metrics_df.loc[best_idx]

    # Compute AUC using trapezoidal rule
    pr_points_arr = np.array(pr_points)
    sorted_idx = np.argsort(pr_points_arr[:, 0])  # sort by recall
    auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall

    # Add to summary table
    summary_rows.append({
        "Lag": lag,
        "Best Threshold": best_row["Threshold"],
        "Precision": best_row["Precision"],
        "Recall": best_row["Recall"],
        "F1 Score": best_row["F1"],
        "TP": int(best_row["TP"]),
        "FP": int(best_row["FP"]),
        "FN": int(best_row["FN"]),
        "PR AUC": auc_pr
    })

    # Save full metrics for this lag
    lag_metrics_dfs[lag] = metrics_df.copy()

    # Plot PR curve
    plt.plot(pr_points_arr[:, 0], pr_points_arr[:, 1], label=f"Lag {lag}", linewidth=2)

# --- PR Curve Plot ---
plt.xlabel("Recall", fontsize=13)
plt.ylabel("Precision", fontsize=13)
plt.title("Precision–Recall Curves for Multiple Lags (Full Threshold Sweep)", fontsize=15)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title="Lag", fontsize=10)
plt.tight_layout()
plt.show()

# --- Summary Table ---
summary_df = pd.DataFrame(summary_rows)
summary_df = summary_df.sort_values("F1 Score", ascending=False).reset_index(drop=True)

from IPython.display import display
display(summary_df)
# Out:
# /tmp/ipython-input-2546430860.py:73: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall
# /tmp/ipython-input-2546430860.py:73: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall
# /tmp/ipython-input-2546430860.py:73: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall
# /tmp/ipython-input-2546430860.py:73: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall
#    Lag  Best Threshold  Precision    Recall  F1 Score  TP  FP  FN    PR AUC
# 0   20        0.277089   0.800000  0.833333  0.816327  40  10   8  0.802431
# 1   15        0.259584   0.769231  0.833333  0.800000  40  12   8  0.810064
# 2    5        0.282762   0.694915  0.854167  0.766355  41  18   7  0.815525
# 3   10        0.293861   0.655738  0.833333  0.733945  40  21   8  0.797821
