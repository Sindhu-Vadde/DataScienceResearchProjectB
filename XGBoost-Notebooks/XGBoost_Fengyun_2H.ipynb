# %% [markdown]
# **1. Checking for Assumptions**

# %% [markdown]
# Loading and preparing the dataset

# %%
# --- Imports ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

# --- Global Seed Setup (type this once!) ---
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)

# %%
# STEP 1: Load Libraries and Dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Brouwer Mean Motion from Fengyun-2F CSV
df = pd.read_csv('/content/Fengyun-2H.csv')
df['timestamp'] = pd.to_datetime(df['Unnamed: 0'])
df.set_index('timestamp', inplace=True)

# --- Load and parse ground truth maneuver timestamps ---
truth_df = pd.read_excel("/content/manFY2H_cleaned.xlsx")
ground_truth_timestamps = pd.to_datetime(
    truth_df["Start Date"].astype(str) + " " + truth_df["Start Time"].astype(str)
)

# Select relevant column
bmm_series = df['Brouwer mean motion']

# %% [markdown]
# 2. Checking Regualrity

# %%
# STEP 2: Resample to daily data
bmm_daily = bmm_series.resample('D').mean()

# Check missing values
missing_days = bmm_daily.isnull().sum()
print(f"Missing daily entries: {missing_days}")
# Out:
# Missing daily entries: 55

# %% [markdown]
# 3. Interpolating missing values

# %%
# STEP 3: Fill gaps using linear interpolation
bmm_filled = bmm_daily.interpolate(method='linear')

bmm_filled = bmm_filled * 1e6

# Confirm fill
print("Any missing after interpolation?", bmm_filled.isnull().any())
# Out:
# Any missing after interpolation? False

# %% [markdown]
# 4. Apply differencing

# %%
bmm_filled = bmm_filled.diff().dropna()
print("Differencing applied. First few values:")
print(bmm_filled.head())
# Out:
# Differencing applied. First few values:
# timestamp
# 2019-01-14    0.000043
# 2019-01-15   -0.001789
# 2019-01-16   -0.000829
# 2019-01-17   -0.003491
# 2019-01-18   -0.002575
# Freq: D, Name: Brouwer mean motion, dtype: float64

# %%
# STEP 6: Check stationarity using ADF test
from statsmodels.tsa.stattools import adfuller

adf_result = adfuller(bmm_filled.dropna())
print("ADF Statistic:", adf_result[0])
print("p-value:", adf_result[1])
if adf_result[1] < 0.05:
    print("✅ The series is stationary (p < 0.05)")
else:
    print("❌ The series is NOT stationary (p ≥ 0.05)")
# Out:
# ADF Statistic: -21.528055752290378
# p-value: 0.0
# ✅ The series is stationary (p < 0.05)

# %% [markdown]
# 6. Checking Time gaps

# %%
# Ensure uniform time spacing
time_deltas = bmm_filled.index.to_series().diff().value_counts()
print("Time step distribution:")
print(time_deltas.head())
# Out:
# Time step distribution:
# timestamp
# 1 days    1106
# Name: count, dtype: int64

# %% [markdown]
# 7. Visualisation

# %%
# STEP 8: Plot raw (interpolated + optionally differenced) BMM
plt.figure(figsize=(12, 4))
plt.plot(bmm_filled.index, bmm_filled.values, color='green')
plt.title("Processed Brouwer Mean Motion")
plt.ylabel("BMM")
plt.xlabel("Date")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **2. Fitting of XGBoost model**

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.4.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)

# %%
import pandas as pd
import numpy as np
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# --- Utility: Create lagged features ---
def make_lagged_features(series, lag=7):
    df_lagged = pd.DataFrame({'target': series})
    for i in range(1, lag + 1):
        df_lagged[f'lag_{i}'] = series.shift(i)
    df_lagged.dropna(inplace=True)
    return df_lagged

# Dictionary to store Optuna studies and histories for each lag
lag_study_results = {}

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from optuna.samplers import TPESampler

# --- Fix random seed for reproducibility ---
SEED = 42

# Store results for each lag
lag_study_results = {}

# Define lags to evaluate
lag_values = [5,10,15,20]

for LAG in lag_values:
    print(f"\n🚀 Running Optuna for LAG={LAG}")

    # --- Create lagged features ---
    lagged_df = make_lagged_features(bmm_filled, lag=LAG)

    # --- Train-test split ---
    train_size = int(len(lagged_df) * 0.8)
    train_df = lagged_df.iloc[:train_size]
    test_df = lagged_df.iloc[train_size:]

    X_train = train_df.drop('target', axis=1).values
    y_train = train_df['target'].values
    X_test = test_df.drop('target', axis=1).values
    y_test = test_df['target'].values

    # --- Define objective function for Optuna ---
    def objective(trial):
        params = {
            'n_estimators': trial.suggest_int('n_estimators', 50, 300),
            'max_depth': trial.suggest_int('max_depth', 3, 10),
            'learning_rate': trial.suggest_float('learning_rate', 1e-4, 0.3, log=True),
            'subsample': trial.suggest_float('subsample', 0.5, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
            'gamma': trial.suggest_float('gamma', 0, 5),
            'reg_alpha': trial.suggest_float('reg_alpha', 0, 1.0),
            'reg_lambda': trial.suggest_float('reg_lambda', 0, 1.0),
            'random_state': SEED,
            'objective': 'reg:squarederror'
        }
        model = XGBRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        mse = mean_squared_error(y_test, y_pred)
        return mse

    # --- Create and run Optuna study with seeded sampler ---
    sampler = TPESampler(seed=SEED)
    study = optuna.create_study(direction='minimize', sampler=sampler)
    study.optimize(objective, n_trials=50, show_progress_bar=True)

    # --- Store results ---
    lag_study_results[LAG] = {
        "study": study,
        "best_params": study.best_params,
        "best_value": study.best_value
    }
# Out:
# [I 2025-08-03 13:15:22,720] A new study created in memory with name: no-name-00e222ae-9bb2-4b53-8b04-e56a7ea354aa
# 🚀 Running Optuna for LAG=5
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-08-03 13:15:22,857] Trial 0 finished with value: 0.0016289632787996216 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.035093904781414616, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132, 'reg_alpha': 0.05808361216819946, 'reg_lambda': 0.8661761457749352}. Best is trial 0 with value: 0.0016289632787996216.
# [I 2025-08-03 13:15:22,891] Trial 1 finished with value: 0.0016289527176160403 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.00011791655502618509, 'subsample': 0.9849549260809971, 'colsample_bytree': 0.9162213204002109, 'gamma': 1.0616955533913808, 'reg_alpha': 0.18182496720710062, 'reg_lambda': 0.18340450985343382}. Best is trial 1 with value: 0.0016289527176160403.
# [I 2025-08-03 13:15:22,912] Trial 2 finished with value: 0.0016289478735310467 and parameters: {'n_estimators': 126, 'max_depth': 7, 'learning_rate': 0.0031763269920199078, 'subsample': 0.645614570099021, 'colsample_bytree': 0.8059264473611898, 'gamma': 0.6974693032602092, 'reg_alpha': 0.29214464853521815, 'reg_lambda': 0.3663618432936917}. Best is trial 2 with value: 0.0016289478735310467.
# [I 2025-08-03 13:15:22,941] Trial 3 finished with value: 0.0016289524648175416 and parameters: {'n_estimators': 164, 'max_depth': 9, 'learning_rate': 0.0004946408182937843, 'subsample': 0.7571172192068059, 'colsample_bytree': 0.7962072844310213, 'gamma': 0.23225206359998862, 'reg_alpha': 0.6075448519014384, 'reg_lambda': 0.17052412368729153}. Best is trial 2 with value: 0.0016289478735310467.
# [I 2025-08-03 13:15:22,974] Trial 4 finished with value: 0.0016289327082336911 and parameters: {'n_estimators': 66, 'max_depth': 10, 'learning_rate': 0.22783459357466163, 'subsample': 0.9041986740582306, 'colsample_bytree': 0.6523068845866853, 'gamma': 0.48836057003191935, 'reg_alpha': 0.6842330265121569, 'reg_lambda': 0.4401524937396013}. Best is trial 4 with value: 0.0016289327082336911.
# [I 2025-08-03 13:15:22,997] Trial 5 finished with value: 0.0016289527103599795 and parameters: {'n_estimators': 80, 'max_depth': 6, 'learning_rate': 0.00013169614353741142, 'subsample': 0.954660201039391, 'colsample_bytree': 0.6293899908000085, 'gamma': 3.31261142176991, 'reg_alpha': 0.31171107608941095, 'reg_lambda': 0.5200680211778108}. Best is trial 4 with value: 0.0016289327082336911.
# [I 2025-08-03 13:15:23,032] Trial 6 finished with value: 0.0016288976905296526 and parameters: {'n_estimators': 187, 'max_depth': 4, 'learning_rate': 0.23515992740571925, 'subsample': 0.8875664116805573, 'colsample_bytree': 0.9697494707820946, 'gamma': 4.474136752138244, 'reg_alpha': 0.5978999788110851, 'reg_lambda': 0.9218742350231168}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:23,163] Trial 7 finished with value: 0.0016289528467756762 and parameters: {'n_estimators': 72, 'max_depth': 4, 'learning_rate': 0.0001436351616738488, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'gamma': 1.3567451588694794, 'reg_alpha': 0.8287375091519293, 'reg_lambda': 0.3567533266935893}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:23,263] Trial 8 finished with value: 0.0016289528543416193 and parameters: {'n_estimators': 120, 'max_depth': 7, 'learning_rate': 0.0003090370987350513, 'subsample': 0.9010984903770198, 'colsample_bytree': 0.5372753218398854, 'gamma': 4.9344346830025865, 'reg_alpha': 0.7722447692966574, 'reg_lambda': 0.1987156815341724}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:23,275] Trial 9 finished with value: 0.0016289403528047914 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.02869648437859116, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'gamma': 0.3702232586704518, 'reg_alpha': 0.3584657285442726, 'reg_lambda': 0.11586905952512971}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:23,340] Trial 10 finished with value: 0.001628925371874804 and parameters: {'n_estimators': 268, 'max_depth': 3, 'learning_rate': 0.2350704805592213, 'subsample': 0.5089809378074097, 'colsample_bytree': 0.9919371080730972, 'gamma': 4.538323976412588, 'reg_alpha': 0.9597707459454197, 'reg_lambda': 0.9767678566447309}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:23,611] Trial 11 finished with value: 0.0016290188776812494 and parameters: {'n_estimators': 280, 'max_depth': 3, 'learning_rate': 0.28229917543521604, 'subsample': 0.5085930751344794, 'colsample_bytree': 0.9869601043141658, 'gamma': 4.9590897198452195, 'reg_alpha': 0.9864784358968458, 'reg_lambda': 0.9684931462441533}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:23,682] Trial 12 finished with value: 0.0016289313590465387 and parameters: {'n_estimators': 235, 'max_depth': 5, 'learning_rate': 0.05974247210815623, 'subsample': 0.5032835609396511, 'colsample_bytree': 0.9851573881769599, 'gamma': 3.8560881041683777, 'reg_alpha': 0.9956480943653735, 'reg_lambda': 0.7370941173278516}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:23,885] Trial 13 finished with value: 0.0016289396969982857 and parameters: {'n_estimators': 297, 'max_depth': 3, 'learning_rate': 0.0075903017270806524, 'subsample': 0.6135695058254392, 'colsample_bytree': 0.8892241488241991, 'gamma': 3.9358850181018528, 'reg_alpha': 0.4807956566040567, 'reg_lambda': 0.7043498594782563}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:24,087] Trial 14 finished with value: 0.0016289070367424717 and parameters: {'n_estimators': 236, 'max_depth': 5, 'learning_rate': 0.09855710471728665, 'subsample': 0.8223368426340427, 'colsample_bytree': 0.9360069719526356, 'gamma': 2.5824265837817775, 'reg_alpha': 0.56927992141491, 'reg_lambda': 0.9960169893612132}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:24,266] Trial 15 finished with value: 0.0016288984742691035 and parameters: {'n_estimators': 208, 'max_depth': 5, 'learning_rate': 0.08053964182088158, 'subsample': 0.8204486323996709, 'colsample_bytree': 0.8363473249845736, 'gamma': 2.1279473218191445, 'reg_alpha': 0.5722617399218572, 'reg_lambda': 0.7702528984593182}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:25,005] Trial 16 finished with value: 0.0016289322641498722 and parameters: {'n_estimators': 198, 'max_depth': 5, 'learning_rate': 0.008664977086700928, 'subsample': 0.7320832480224756, 'colsample_bytree': 0.8352725713024431, 'gamma': 2.03046260981977, 'reg_alpha': 0.4770170533510715, 'reg_lambda': 0.6967758493926123}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:25,584] Trial 17 finished with value: 0.0016289388358860098 and parameters: {'n_estimators': 208, 'max_depth': 4, 'learning_rate': 0.01943570265559091, 'subsample': 0.8329745812221149, 'colsample_bytree': 0.7285744661299374, 'gamma': 2.785760385593672, 'reg_alpha': 0.7060618011889843, 'reg_lambda': 0.8162818694143862}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:25,978] Trial 18 finished with value: 0.001628908475154966 and parameters: {'n_estimators': 239, 'max_depth': 6, 'learning_rate': 0.09137538131035124, 'subsample': 0.7530127550415489, 'colsample_bytree': 0.8364025323130282, 'gamma': 1.9575049039661034, 'reg_alpha': 0.8477611203294718, 'reg_lambda': 0.589537449893698}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:26,132] Trial 19 finished with value: 0.0016289523957655593 and parameters: {'n_estimators': 181, 'max_depth': 4, 'learning_rate': 0.002045788358293527, 'subsample': 0.9346526485595684, 'colsample_bytree': 0.7481865994962198, 'gamma': 3.2802191721076817, 'reg_alpha': 0.5639746990214329, 'reg_lambda': 0.8737010566894581}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:26,326] Trial 20 finished with value: 0.0016289495256707695 and parameters: {'n_estimators': 163, 'max_depth': 6, 'learning_rate': 0.11700483921979753, 'subsample': 0.8673124161735792, 'colsample_bytree': 0.9292066062055611, 'gamma': 1.7015382563154549, 'reg_alpha': 0.41624167226275216, 'reg_lambda': 0.632630392762318}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:26,576] Trial 21 finished with value: 0.001628907472976054 and parameters: {'n_estimators': 226, 'max_depth': 5, 'learning_rate': 0.09846476326518765, 'subsample': 0.8082428769576032, 'colsample_bytree': 0.9388528685765388, 'gamma': 2.600860573717432, 'reg_alpha': 0.6243825865093144, 'reg_lambda': 0.9912494078235897}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:26,956] Trial 22 finished with value: 0.0016289360902074941 and parameters: {'n_estimators': 254, 'max_depth': 5, 'learning_rate': 0.015859932945718528, 'subsample': 0.7040454034931706, 'colsample_bytree': 0.8659584713914403, 'gamma': 3.105246671633729, 'reg_alpha': 0.5414609952461361, 'reg_lambda': 0.8119273545456753}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:27,622] Trial 23 finished with value: 0.0016289187390851495 and parameters: {'n_estimators': 216, 'max_depth': 4, 'learning_rate': 0.04778994713765326, 'subsample': 0.8443639583115559, 'colsample_bytree': 0.9507858451191732, 'gamma': 2.3531546120911706, 'reg_alpha': 0.6495845433346886, 'reg_lambda': 0.8983057503089027}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:27,908] Trial 24 finished with value: 0.0016289172728697603 and parameters: {'n_estimators': 183, 'max_depth': 5, 'learning_rate': 0.1366386074111242, 'subsample': 0.8106452018417596, 'colsample_bytree': 0.7778534357816259, 'gamma': 3.9195598078221137, 'reg_alpha': 0.4249646534566054, 'reg_lambda': 0.7748665666734106}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:28,143] Trial 25 finished with value: 0.0016289449911340908 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.061473908467861944, 'subsample': 0.8961917611429133, 'colsample_bytree': 0.8480721199747833, 'gamma': 1.4582009715558515, 'reg_alpha': 0.7132746245617673, 'reg_lambda': 0.9143841546421919}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:28,753] Trial 26 finished with value: 0.0016289309541846302 and parameters: {'n_estimators': 266, 'max_depth': 6, 'learning_rate': 0.15669576629481613, 'subsample': 0.7827871778522967, 'colsample_bytree': 0.9034029602516258, 'gamma': 2.2563702743223617, 'reg_alpha': 0.5270496965332079, 'reg_lambda': 0.999492563837494}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:29,229] Trial 27 finished with value: 0.0016289524643794547 and parameters: {'n_estimators': 143, 'max_depth': 7, 'learning_rate': 0.01441686176615793, 'subsample': 0.9432797573413253, 'colsample_bytree': 0.967408681959862, 'gamma': 2.860765592306551, 'reg_alpha': 0.8204600746102122, 'reg_lambda': 0.8376565847885017}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:29,397] Trial 28 finished with value: 0.0016289532653543757 and parameters: {'n_estimators': 222, 'max_depth': 5, 'learning_rate': 0.0022255855086000583, 'subsample': 0.7101486032531933, 'colsample_bytree': 0.9411840287528962, 'gamma': 4.433715356745329, 'reg_alpha': 0.23527616803035378, 'reg_lambda': 0.6449870274018659}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:29,559] Trial 29 finished with value: 0.0016289172288836817 and parameters: {'n_estimators': 189, 'max_depth': 3, 'learning_rate': 0.032547312437601165, 'subsample': 0.7846876537008887, 'colsample_bytree': 0.8637697002197832, 'gamma': 3.6401269378330303, 'reg_alpha': 0.16482620337310028, 'reg_lambda': 0.9161218763140198}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:30,145] Trial 30 finished with value: 0.0016289479861277263 and parameters: {'n_estimators': 162, 'max_depth': 4, 'learning_rate': 0.07234721953822615, 'subsample': 0.87019115896224, 'colsample_bytree': 0.9099344799579273, 'gamma': 1.0460486116306331, 'reg_alpha': 0.042745180079641565, 'reg_lambda': 0.7669387831774515}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:31,774] Trial 31 finished with value: 0.0016288982443092262 and parameters: {'n_estimators': 227, 'max_depth': 5, 'learning_rate': 0.15649822322506995, 'subsample': 0.8165281701860047, 'colsample_bytree': 0.9537043186469502, 'gamma': 2.768798249312558, 'reg_alpha': 0.6110910234351346, 'reg_lambda': 0.9323023086242419}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:32,101] Trial 32 finished with value: 0.0016289528604723096 and parameters: {'n_estimators': 205, 'max_depth': 6, 'learning_rate': 0.13946441350905273, 'subsample': 0.9924277794302462, 'colsample_bytree': 0.9606664388071757, 'gamma': 1.9511102270084066, 'reg_alpha': 0.6058801963817024, 'reg_lambda': 0.9146033211978134}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:32,438] Trial 33 finished with value: 0.0016289268391438596 and parameters: {'n_estimators': 226, 'max_depth': 5, 'learning_rate': 0.04133634929868152, 'subsample': 0.8309387810922239, 'colsample_bytree': 0.9173322915671444, 'gamma': 2.5338603408537956, 'reg_alpha': 0.7466848541582354, 'reg_lambda': 0.8535625251972754}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:32,916] Trial 34 finished with value: 0.0016290356672885049 and parameters: {'n_estimators': 254, 'max_depth': 4, 'learning_rate': 0.2959055260423502, 'subsample': 0.7776729326302909, 'colsample_bytree': 0.8107371168752, 'gamma': 4.321675883617617, 'reg_alpha': 0.4234827255840296, 'reg_lambda': 0.9397414913804224}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:33,281] Trial 35 finished with value: 0.0016358998930519105 and parameters: {'n_estimators': 197, 'max_depth': 7, 'learning_rate': 0.18405793140968743, 'subsample': 0.9161014003137196, 'colsample_bytree': 0.9960366513494483, 'gamma': 0.027292876886564343, 'reg_alpha': 0.5734088414919158, 'reg_lambda': 0.8730246361262743}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:33,340] Trial 36 finished with value: 0.0016289466611656123 and parameters: {'n_estimators': 143, 'max_depth': 8, 'learning_rate': 0.07296239240341618, 'subsample': 0.968518919458279, 'colsample_bytree': 0.8885306435455986, 'gamma': 2.9702094556956085, 'reg_alpha': 0.6606500733732268, 'reg_lambda': 0.8132673519085033}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:33,391] Trial 37 finished with value: 0.001628952217850909 and parameters: {'n_estimators': 111, 'max_depth': 5, 'learning_rate': 0.0009474741469568635, 'subsample': 0.8145114669216423, 'colsample_bytree': 0.8068636152883478, 'gamma': 3.4708166612913187, 'reg_alpha': 0.48098647736041245, 'reg_lambda': 0.9339010106064363}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:33,451] Trial 38 finished with value: 0.0016289528604723096 and parameters: {'n_estimators': 168, 'max_depth': 6, 'learning_rate': 0.024907707699493006, 'subsample': 0.8818309390999945, 'colsample_bytree': 0.964045066919537, 'gamma': 1.277993576462392, 'reg_alpha': 0.8990114165913381, 'reg_lambda': 0.5667705790618774}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:33,514] Trial 39 finished with value: 0.0016289001177395195 and parameters: {'n_estimators': 209, 'max_depth': 4, 'learning_rate': 0.16582126103267172, 'subsample': 0.8496624359423329, 'colsample_bytree': 0.6406089351880103, 'gamma': 2.2140635860437357, 'reg_alpha': 0.7560385188097458, 'reg_lambda': 0.3467052702713051}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:33,574] Trial 40 finished with value: 0.001628938175377659 and parameters: {'n_estimators': 154, 'max_depth': 3, 'learning_rate': 0.1828042253050392, 'subsample': 0.8510604615945643, 'colsample_bytree': 0.6292815720275478, 'gamma': 0.8856959748731252, 'reg_alpha': 0.7886511772270013, 'reg_lambda': 0.3047581524848173}. Best is trial 6 with value: 0.0016288976905296526.
# [I 2025-08-03 13:15:33,638] Trial 41 finished with value: 0.001628888727716891 and parameters: {'n_estimators': 214, 'max_depth': 4, 'learning_rate': 0.10593876139776817, 'subsample': 0.8286979989120671, 'colsample_bytree': 0.569223193977957, 'gamma': 1.6904506856907093, 'reg_alpha': 0.6006820142631755, 'reg_lambda': 0.4471653601663506}. Best is trial 41 with value: 0.001628888727716891.
# [I 2025-08-03 13:15:33,705] Trial 42 finished with value: 0.0016289284289977269 and parameters: {'n_estimators': 194, 'max_depth': 4, 'learning_rate': 0.20938703716112408, 'subsample': 0.8856982237128183, 'colsample_bytree': 0.5006759681012419, 'gamma': 1.818954721252041, 'reg_alpha': 0.7298722714801977, 'reg_lambda': 0.431198247973408}. Best is trial 41 with value: 0.001628888727716891.
# [I 2025-08-03 13:15:33,767] Trial 43 finished with value: 0.001628940874107935 and parameters: {'n_estimators': 207, 'max_depth': 4, 'learning_rate': 0.1296061514968621, 'subsample': 0.9296009503753222, 'colsample_bytree': 0.596594315225099, 'gamma': 1.474015690425432, 'reg_alpha': 0.6719701713100003, 'reg_lambda': 0.2840639521996117}. Best is trial 41 with value: 0.001628888727716891.
# [I 2025-08-03 13:15:33,835] Trial 44 finished with value: 0.0016288946288433206 and parameters: {'n_estimators': 212, 'max_depth': 3, 'learning_rate': 0.2971210801621129, 'subsample': 0.7685003979725674, 'colsample_bytree': 0.5683895133536226, 'gamma': 2.2029038380180688, 'reg_alpha': 0.6152940197424024, 'reg_lambda': 0.4661507578546722}. Best is trial 41 with value: 0.001628888727716891.
# [I 2025-08-03 13:15:33,898] Trial 45 finished with value: 0.0016289468027832093 and parameters: {'n_estimators': 219, 'max_depth': 3, 'learning_rate': 0.2867333706999433, 'subsample': 0.7669790236327675, 'colsample_bytree': 0.5602230517788936, 'gamma': 0.5824039482660692, 'reg_alpha': 0.6081223602279373, 'reg_lambda': 0.46205889206335965}. Best is trial 41 with value: 0.001628888727716891.
# [I 2025-08-03 13:15:33,968] Trial 46 finished with value: 0.00162889718699987 and parameters: {'n_estimators': 180, 'max_depth': 3, 'learning_rate': 0.08529878047327001, 'subsample': 0.7246348937777258, 'colsample_bytree': 0.69125177423766, 'gamma': 1.647135107778115, 'reg_alpha': 0.5033904716259701, 'reg_lambda': 0.45968940434628924}. Best is trial 41 with value: 0.001628888727716891.
# [I 2025-08-03 13:15:34,168] A new study created in memory with name: no-name-d83874f9-839c-459e-a263-704bd9551093
# [I 2025-08-03 13:15:34,030] Trial 47 finished with value: 0.0016288828421796178 and parameters: {'n_estimators': 185, 'max_depth': 3, 'learning_rate': 0.04775283991453705, 'subsample': 0.6525095024077675, 'colsample_bytree': 0.6771291535654584, 'gamma': 1.6509170050658604, 'reg_alpha': 0.35612529736792115, 'reg_lambda': 0.5209579953143052}. Best is trial 47 with value: 0.0016288828421796178.
# [I 2025-08-03 13:15:34,095] Trial 48 finished with value: 0.0016288886245658318 and parameters: {'n_estimators': 173, 'max_depth': 3, 'learning_rate': 0.05168283229888119, 'subsample': 0.6467284537654775, 'colsample_bytree': 0.6820539306604672, 'gamma': 1.667389843166858, 'reg_alpha': 0.35177879970485787, 'reg_lambda': 0.5138602891030077}. Best is trial 47 with value: 0.0016288828421796178.
# [I 2025-08-03 13:15:34,156] Trial 49 finished with value: 0.0016289278858568736 and parameters: {'n_estimators': 173, 'max_depth': 3, 'learning_rate': 0.010704025174975044, 'subsample': 0.6118363528465347, 'colsample_bytree': 0.6902034665329203, 'gamma': 1.6381147596605712, 'reg_alpha': 0.3497400518245252, 'reg_lambda': 0.5246081961971691}. Best is trial 47 with value: 0.0016288828421796178.
#
# 🚀 Running Optuna for LAG=10
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-08-03 13:15:34,219] Trial 0 finished with value: 0.0016360862000233641 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.035093904781414616, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132, 'reg_alpha': 0.05808361216819946, 'reg_lambda': 0.8661761457749352}. Best is trial 0 with value: 0.0016360862000233641.
# [I 2025-08-03 13:15:34,253] Trial 1 finished with value: 0.0016360860467070854 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.00011791655502618509, 'subsample': 0.9849549260809971, 'colsample_bytree': 0.9162213204002109, 'gamma': 1.0616955533913808, 'reg_alpha': 0.18182496720710062, 'reg_lambda': 0.18340450985343382}. Best is trial 1 with value: 0.0016360860467070854.
# [I 2025-08-03 13:15:34,282] Trial 2 finished with value: 0.0016360860503913497 and parameters: {'n_estimators': 126, 'max_depth': 7, 'learning_rate': 0.0031763269920199078, 'subsample': 0.645614570099021, 'colsample_bytree': 0.8059264473611898, 'gamma': 0.6974693032602092, 'reg_alpha': 0.29214464853521815, 'reg_lambda': 0.3663618432936917}. Best is trial 1 with value: 0.0016360860467070854.
# [I 2025-08-03 13:15:34,314] Trial 3 finished with value: 0.0016360860455153245 and parameters: {'n_estimators': 164, 'max_depth': 9, 'learning_rate': 0.0004946408182937843, 'subsample': 0.7571172192068059, 'colsample_bytree': 0.7962072844310213, 'gamma': 0.23225206359998862, 'reg_alpha': 0.6075448519014384, 'reg_lambda': 0.17052412368729153}. Best is trial 3 with value: 0.0016360860455153245.
# [I 2025-08-03 13:15:34,329] Trial 4 finished with value: 0.0016360864028449394 and parameters: {'n_estimators': 66, 'max_depth': 10, 'learning_rate': 0.22783459357466163, 'subsample': 0.9041986740582306, 'colsample_bytree': 0.6523068845866853, 'gamma': 0.48836057003191935, 'reg_alpha': 0.6842330265121569, 'reg_lambda': 0.4401524937396013}. Best is trial 3 with value: 0.0016360860455153245.
# [I 2025-08-03 13:15:34,345] Trial 5 finished with value: 0.0016360860457859889 and parameters: {'n_estimators': 80, 'max_depth': 6, 'learning_rate': 0.00013169614353741142, 'subsample': 0.954660201039391, 'colsample_bytree': 0.6293899908000085, 'gamma': 3.31261142176991, 'reg_alpha': 0.31171107608941095, 'reg_lambda': 0.5200680211778108}. Best is trial 3 with value: 0.0016360860455153245.
# [I 2025-08-03 13:15:34,374] Trial 6 finished with value: 0.001636088745447987 and parameters: {'n_estimators': 187, 'max_depth': 4, 'learning_rate': 0.23515992740571925, 'subsample': 0.8875664116805573, 'colsample_bytree': 0.9697494707820946, 'gamma': 4.474136752138244, 'reg_alpha': 0.5978999788110851, 'reg_lambda': 0.9218742350231168}. Best is trial 3 with value: 0.0016360860455153245.
# [I 2025-08-03 13:15:34,390] Trial 7 finished with value: 0.0016360860456720633 and parameters: {'n_estimators': 72, 'max_depth': 4, 'learning_rate': 0.0001436351616738488, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'gamma': 1.3567451588694794, 'reg_alpha': 0.8287375091519293, 'reg_lambda': 0.3567533266935893}. Best is trial 3 with value: 0.0016360860455153245.
# [I 2025-08-03 13:15:34,412] Trial 8 finished with value: 0.00163608604510302 and parameters: {'n_estimators': 120, 'max_depth': 7, 'learning_rate': 0.0003090370987350513, 'subsample': 0.9010984903770198, 'colsample_bytree': 0.5372753218398854, 'gamma': 4.9344346830025865, 'reg_alpha': 0.7722447692966574, 'reg_lambda': 0.1987156815341724}. Best is trial 8 with value: 0.00163608604510302.
# [I 2025-08-03 13:15:34,429] Trial 9 finished with value: 0.0016360861542040145 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.02869648437859116, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'gamma': 0.3702232586704518, 'reg_alpha': 0.3584657285442726, 'reg_lambda': 0.11586905952512971}. Best is trial 8 with value: 0.00163608604510302.
# [I 2025-08-03 13:15:34,496] Trial 10 finished with value: 0.001636086044136159 and parameters: {'n_estimators': 287, 'max_depth': 6, 'learning_rate': 0.0011746002328160427, 'subsample': 0.5089809378074097, 'colsample_bytree': 0.5072835039169765, 'gamma': 4.538323976412588, 'reg_alpha': 0.9657999152312998, 'reg_lambda': 0.6764178475687505}. Best is trial 10 with value: 0.001636086044136159.
# [I 2025-08-03 13:15:34,566] Trial 11 finished with value: 0.0016360860440834371 and parameters: {'n_estimators': 287, 'max_depth': 6, 'learning_rate': 0.0013343387255799009, 'subsample': 0.5085930751344794, 'colsample_bytree': 0.5117573877987993, 'gamma': 4.9779709030838, 'reg_alpha': 0.9923480895289144, 'reg_lambda': 0.6656934168979671}. Best is trial 11 with value: 0.0016360860440834371.
# [I 2025-08-03 13:15:34,636] Trial 12 finished with value: 0.0016360860402405426 and parameters: {'n_estimators': 299, 'max_depth': 5, 'learning_rate': 0.0022455377871602594, 'subsample': 0.5018203726540555, 'colsample_bytree': 0.52247020987727, 'gamma': 3.823453444239005, 'reg_alpha': 0.9971646149932867, 'reg_lambda': 0.6910098394398291}. Best is trial 12 with value: 0.0016360860402405426.
# [I 2025-08-03 13:15:34,711] Trial 13 finished with value: 0.0016360860385850205 and parameters: {'n_estimators': 298, 'max_depth': 5, 'learning_rate': 0.004715181869011494, 'subsample': 0.5048579886309473, 'colsample_bytree': 0.5872625990747572, 'gamma': 3.482741304273752, 'reg_alpha': 0.999362438641551, 'reg_lambda': 0.7195127050992635}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:34,774] Trial 14 finished with value: 0.0016360863426108606 and parameters: {'n_estimators': 242, 'max_depth': 3, 'learning_rate': 0.011841499472837698, 'subsample': 0.5868583137133783, 'colsample_bytree': 0.5882366621416945, 'gamma': 3.2263553013726978, 'reg_alpha': 0.8647743466919985, 'reg_lambda': 0.7421630723514321}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:34,840] Trial 15 finished with value: 0.0016360874231422513 and parameters: {'n_estimators': 245, 'max_depth': 5, 'learning_rate': 0.005929794314511605, 'subsample': 0.5840870224066259, 'colsample_bytree': 0.7261631564388041, 'gamma': 3.4454801289499595, 'reg_alpha': 0.4541519768015846, 'reg_lambda': 0.7946453641120887}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:34,950] Trial 16 finished with value: 0.001636086086031075 and parameters: {'n_estimators': 249, 'max_depth': 5, 'learning_rate': 0.0027646798837571806, 'subsample': 0.5837292260147117, 'colsample_bytree': 0.6062595428019726, 'gamma': 2.4426539530952667, 'reg_alpha': 0.9054286728935996, 'reg_lambda': 0.5705726322139155}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,021] Trial 17 finished with value: 0.0016360882602870688 and parameters: {'n_estimators': 297, 'max_depth': 3, 'learning_rate': 0.015425955736511733, 'subsample': 0.6899453780841301, 'colsample_bytree': 0.6754572978088687, 'gamma': 2.1706826038003486, 'reg_alpha': 0.7338778192612955, 'reg_lambda': 0.9699607788793954}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,089] Trial 18 finished with value: 0.001636088071264695 and parameters: {'n_estimators': 226, 'max_depth': 5, 'learning_rate': 0.09137538131035124, 'subsample': 0.5428274365617971, 'colsample_bytree': 0.5635909985031541, 'gamma': 3.8050320261928468, 'reg_alpha': 0.9993378078922299, 'reg_lambda': 0.6064328079751506}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,165] Trial 19 finished with value: 0.001636086064583901 and parameters: {'n_estimators': 269, 'max_depth': 4, 'learning_rate': 0.0009601093392772599, 'subsample': 0.7163728055902456, 'colsample_bytree': 0.7462334789800918, 'gamma': 1.7928938616788712, 'reg_alpha': 0.5421643350890488, 'reg_lambda': 0.8157298373095427}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,227] Trial 20 finished with value: 0.001636086277344317 and parameters: {'n_estimators': 221, 'max_depth': 5, 'learning_rate': 0.005948692513214112, 'subsample': 0.627853850646286, 'colsample_bytree': 0.5586729887566603, 'gamma': 2.842966467834257, 'reg_alpha': 0.8244551170015085, 'reg_lambda': 0.7213660364122115}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,304] Trial 21 finished with value: 0.0016360860413138884 and parameters: {'n_estimators': 272, 'max_depth': 6, 'learning_rate': 0.0016211418674796554, 'subsample': 0.5012506584368223, 'colsample_bytree': 0.5185653941095283, 'gamma': 3.970721187156205, 'reg_alpha': 0.9992333867696249, 'reg_lambda': 0.6373308055214431}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,371] Trial 22 finished with value: 0.001636086038738222 and parameters: {'n_estimators': 267, 'max_depth': 7, 'learning_rate': 0.003566010571235876, 'subsample': 0.5000756938399544, 'colsample_bytree': 0.506481979316594, 'gamma': 3.9649739976798553, 'reg_alpha': 0.9329400783631242, 'reg_lambda': 0.6166908421257199}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,442] Trial 23 finished with value: 0.0016360861003275183 and parameters: {'n_estimators': 268, 'max_depth': 7, 'learning_rate': 0.003894893059509449, 'subsample': 0.551275575467659, 'colsample_bytree': 0.6181594819125978, 'gamma': 4.0946805522335765, 'reg_alpha': 0.8985687371129871, 'reg_lambda': 0.4634439066340712}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,518] Trial 24 finished with value: 0.0016360862367994263 and parameters: {'n_estimators': 299, 'max_depth': 8, 'learning_rate': 0.00850555651087659, 'subsample': 0.5508571889869552, 'colsample_bytree': 0.5059879451523751, 'gamma': 2.8879573326934764, 'reg_alpha': 0.9102822485634203, 'reg_lambda': 0.5425273508029074}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,595] Trial 25 finished with value: 0.0016360860639339518 and parameters: {'n_estimators': 270, 'max_depth': 8, 'learning_rate': 0.00066884876614684, 'subsample': 0.6204832747473, 'colsample_bytree': 0.5442754324717722, 'gamma': 3.6866506671179478, 'reg_alpha': 0.7663959100947739, 'reg_lambda': 0.7710348686569799}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,658] Trial 26 finished with value: 0.00163608612962354 and parameters: {'n_estimators': 210, 'max_depth': 4, 'learning_rate': 0.0023686251927996613, 'subsample': 0.5434080270689022, 'colsample_bytree': 0.6489806651711495, 'gamma': 4.328916309884811, 'reg_alpha': 0.686174452572716, 'reg_lambda': 0.8721988028461511}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,729] Trial 27 finished with value: 0.0016360868629907556 and parameters: {'n_estimators': 256, 'max_depth': 5, 'learning_rate': 0.0207487712715219, 'subsample': 0.5966357583174033, 'colsample_bytree': 0.5866928764939245, 'gamma': 2.948564837966306, 'reg_alpha': 0.9039210857552294, 'reg_lambda': 0.38800844734378825}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,800] Trial 28 finished with value: 0.0016360863272842539 and parameters: {'n_estimators': 283, 'max_depth': 7, 'learning_rate': 0.04782067001213712, 'subsample': 0.5011494451163763, 'colsample_bytree': 0.5498925831508625, 'gamma': 3.505184452953917, 'reg_alpha': 0.8082982914237301, 'reg_lambda': 0.6960202642958033}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,867] Trial 29 finished with value: 0.001636086318380981 and parameters: {'n_estimators': 233, 'max_depth': 6, 'learning_rate': 0.009259594767187978, 'subsample': 0.7311858094597686, 'colsample_bytree': 0.5848418654093792, 'gamma': 4.054592898943994, 'reg_alpha': 0.16482620337310028, 'reg_lambda': 0.8723504669374758}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:35,961] Trial 30 finished with value: 0.0016360860453923513 and parameters: {'n_estimators': 162, 'max_depth': 9, 'learning_rate': 0.0003142903860389023, 'subsample': 0.8112271899455036, 'colsample_bytree': 0.7072155962269836, 'gamma': 2.4060598762493166, 'reg_alpha': 0.042745180079641565, 'reg_lambda': 0.26471719980467895}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:36,034] Trial 31 finished with value: 0.0016360860534016242 and parameters: {'n_estimators': 266, 'max_depth': 6, 'learning_rate': 0.002136809222586783, 'subsample': 0.5231996277547294, 'colsample_bytree': 0.5023498060022009, 'gamma': 3.954731700270526, 'reg_alpha': 0.9546936473335608, 'reg_lambda': 0.6491055872274547}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:36,107] Trial 32 finished with value: 0.0016360860587115726 and parameters: {'n_estimators': 299, 'max_depth': 5, 'learning_rate': 0.001745121626405349, 'subsample': 0.5570119626019695, 'colsample_bytree': 0.5311876118795322, 'gamma': 4.29290974790395, 'reg_alpha': 0.9944871939063389, 'reg_lambda': 0.626256199982679}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:36,183] Trial 33 finished with value: 0.001636086048893703 and parameters: {'n_estimators': 279, 'max_depth': 7, 'learning_rate': 0.004003215111066759, 'subsample': 0.5294615647429751, 'colsample_bytree': 0.5723913552307657, 'gamma': 4.664817239733302, 'reg_alpha': 0.9213841099965316, 'reg_lambda': 0.025356598439426725}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:36,257] Trial 34 finished with value: 0.0016360860445705874 and parameters: {'n_estimators': 258, 'max_depth': 6, 'learning_rate': 0.0007217479223746083, 'subsample': 0.5008617255335637, 'colsample_bytree': 0.8107371168752, 'gamma': 3.64257346445538, 'reg_alpha': 0.8481434922646098, 'reg_lambda': 0.5866129153213765}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:36,327] Trial 35 finished with value: 0.0016360862819392436 and parameters: {'n_estimators': 201, 'max_depth': 8, 'learning_rate': 0.004687522541454568, 'subsample': 0.6124812039410541, 'colsample_bytree': 0.5273937728619118, 'gamma': 3.127013197663756, 'reg_alpha': 0.7186517933000406, 'reg_lambda': 0.4848973292554207}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:36,400] Trial 36 finished with value: 0.0016360860712499963 and parameters: {'n_estimators': 280, 'max_depth': 7, 'learning_rate': 0.001545632267001644, 'subsample': 0.572595974507661, 'colsample_bytree': 0.6437750630119861, 'gamma': 3.8597904674345243, 'reg_alpha': 0.9410461230178568, 'reg_lambda': 0.8268383619427795}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:36,459] Trial 37 finished with value: 0.0016360860461167625 and parameters: {'n_estimators': 111, 'max_depth': 4, 'learning_rate': 0.00041501887837568676, 'subsample': 0.786371656057562, 'colsample_bytree': 0.6078495692607642, 'gamma': 4.190412457342028, 'reg_alpha': 0.8708329219300793, 'reg_lambda': 0.729388756258763}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:36,528] Trial 38 finished with value: 0.0016365699874831049 and parameters: {'n_estimators': 241, 'max_depth': 6, 'learning_rate': 0.002940260108461645, 'subsample': 0.5333749637164829, 'colsample_bytree': 0.7833003135765791, 'gamma': 0.01333980638640675, 'reg_alpha': 0.6250033926545076, 'reg_lambda': 0.5421338467646986}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:36,592] Trial 39 finished with value: 0.0016360862166405294 and parameters: {'n_estimators': 183, 'max_depth': 5, 'learning_rate': 0.0058403657778800105, 'subsample': 0.6606172027999846, 'colsample_bytree': 0.8753398828078675, 'gamma': 4.748358635725604, 'reg_alpha': 0.7917416871212737, 'reg_lambda': 0.4279444223486758}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:36,661] Trial 40 finished with value: 0.0016360860551687872 and parameters: {'n_estimators': 258, 'max_depth': 7, 'learning_rate': 0.0008645514755423602, 'subsample': 0.9927183168733702, 'colsample_bytree': 0.5301744903283709, 'gamma': 2.694991858329774, 'reg_alpha': 0.1267725459337925, 'reg_lambda': 0.9300221400297695}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:36,735] Trial 41 finished with value: 0.0016360860467871713 and parameters: {'n_estimators': 289, 'max_depth': 6, 'learning_rate': 0.0013785865895788786, 'subsample': 0.5193484363258452, 'colsample_bytree': 0.5168613013433551, 'gamma': 4.926976063641403, 'reg_alpha': 0.9985694473854184, 'reg_lambda': 0.6728308867001704}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:36,808] Trial 42 finished with value: 0.001636086080733958 and parameters: {'n_estimators': 277, 'max_depth': 6, 'learning_rate': 0.002046741583511228, 'subsample': 0.5639524588439304, 'colsample_bytree': 0.5001342751126729, 'gamma': 4.4504366388535574, 'reg_alpha': 0.9378296880819166, 'reg_lambda': 0.6377062999170583}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:36,888] Trial 43 finished with value: 0.0016360860457736456 and parameters: {'n_estimators': 291, 'max_depth': 5, 'learning_rate': 0.0005322483680033934, 'subsample': 0.5191580138683846, 'colsample_bytree': 0.5566403547984045, 'gamma': 3.4130978352524353, 'reg_alpha': 0.9629494344363287, 'reg_lambda': 0.7697806060096857}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:37,002] Trial 44 finished with value: 0.0016360860425362798 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.001230966027760633, 'subsample': 0.5042342133755153, 'colsample_bytree': 0.5366074542407144, 'gamma': 3.6349669096042696, 'reg_alpha': 0.8595888176088404, 'reg_lambda': 0.6924243069549174}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:37,079] Trial 45 finished with value: 0.0016360860409919318 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.008205476851595027, 'subsample': 0.5016144766863609, 'colsample_bytree': 0.5924266482905284, 'gamma': 3.224829884218984, 'reg_alpha': 0.8620916597095807, 'reg_lambda': 0.518655877076439}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:37,153] Trial 46 finished with value: 0.0016360865177199929 and parameters: {'n_estimators': 273, 'max_depth': 8, 'learning_rate': 0.008872243736292822, 'subsample': 0.9554137385604626, 'colsample_bytree': 0.6645084110467803, 'gamma': 3.078092603624744, 'reg_alpha': 0.4157276946532801, 'reg_lambda': 0.5038835197135603}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:37,227] Trial 47 finished with value: 0.0016360865921853744 and parameters: {'n_estimators': 257, 'max_depth': 7, 'learning_rate': 0.014005835183306451, 'subsample': 0.6004554450208099, 'colsample_bytree': 0.6289621258898165, 'gamma': 3.361696213232344, 'reg_alpha': 0.8785051652814972, 'reg_lambda': 0.56337608942473}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:37,283] Trial 48 finished with value: 0.0016360872482483772 and parameters: {'n_estimators': 138, 'max_depth': 7, 'learning_rate': 0.0450964467941061, 'subsample': 0.644068290560768, 'colsample_bytree': 0.5959370069416681, 'gamma': 3.8983146768240005, 'reg_alpha': 0.9512130433826893, 'reg_lambda': 0.3386834920498384}. Best is trial 13 with value: 0.0016360860385850205.
# [I 2025-08-03 13:15:37,375] A new study created in memory with name: no-name-637d0b74-1931-4631-b911-38ff77dc0a3b
# [I 2025-08-03 13:15:37,362] Trial 49 finished with value: 0.0016360956352740217 and parameters: {'n_estimators': 288, 'max_depth': 9, 'learning_rate': 0.020266740243960548, 'subsample': 0.5739036994037299, 'colsample_bytree': 0.573753215504106, 'gamma': 0.985740086544475, 'reg_alpha': 0.27316983852176946, 'reg_lambda': 0.6017487468005924}. Best is trial 13 with value: 0.0016360860385850205.
#
# 🚀 Running Optuna for LAG=15
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-08-03 13:15:37,413] Trial 0 finished with value: 0.0016427720772942877 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.035093904781414616, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132, 'reg_alpha': 0.05808361216819946, 'reg_lambda': 0.8661761457749352}. Best is trial 0 with value: 0.0016427720772942877.
# [I 2025-08-03 13:15:37,447] Trial 1 finished with value: 0.0016427634389119795 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.00011791655502618509, 'subsample': 0.9849549260809971, 'colsample_bytree': 0.9162213204002109, 'gamma': 1.0616955533913808, 'reg_alpha': 0.18182496720710062, 'reg_lambda': 0.18340450985343382}. Best is trial 1 with value: 0.0016427634389119795.
# [I 2025-08-03 13:15:37,482] Trial 2 finished with value: 0.001642766612311338 and parameters: {'n_estimators': 126, 'max_depth': 7, 'learning_rate': 0.0031763269920199078, 'subsample': 0.645614570099021, 'colsample_bytree': 0.8059264473611898, 'gamma': 0.6974693032602092, 'reg_alpha': 0.29214464853521815, 'reg_lambda': 0.3663618432936917}. Best is trial 1 with value: 0.0016427634389119795.
# [I 2025-08-03 13:15:37,513] Trial 3 finished with value: 0.001642763509015604 and parameters: {'n_estimators': 164, 'max_depth': 9, 'learning_rate': 0.0004946408182937843, 'subsample': 0.7571172192068059, 'colsample_bytree': 0.7962072844310213, 'gamma': 0.23225206359998862, 'reg_alpha': 0.6075448519014384, 'reg_lambda': 0.17052412368729153}. Best is trial 1 with value: 0.0016427634389119795.
# [I 2025-08-03 13:15:37,528] Trial 4 finished with value: 0.0016427864620828232 and parameters: {'n_estimators': 66, 'max_depth': 10, 'learning_rate': 0.22783459357466163, 'subsample': 0.9041986740582306, 'colsample_bytree': 0.6523068845866853, 'gamma': 0.48836057003191935, 'reg_alpha': 0.6842330265121569, 'reg_lambda': 0.4401524937396013}. Best is trial 1 with value: 0.0016427634389119795.
# [I 2025-08-03 13:15:37,545] Trial 5 finished with value: 0.0016427634321607534 and parameters: {'n_estimators': 80, 'max_depth': 6, 'learning_rate': 0.00013169614353741142, 'subsample': 0.954660201039391, 'colsample_bytree': 0.6293899908000085, 'gamma': 3.31261142176991, 'reg_alpha': 0.31171107608941095, 'reg_lambda': 0.5200680211778108}. Best is trial 5 with value: 0.0016427634321607534.
# [I 2025-08-03 13:15:37,582] Trial 6 finished with value: 0.0016428256462695829 and parameters: {'n_estimators': 187, 'max_depth': 4, 'learning_rate': 0.23515992740571925, 'subsample': 0.8875664116805573, 'colsample_bytree': 0.9697494707820946, 'gamma': 4.474136752138244, 'reg_alpha': 0.5978999788110851, 'reg_lambda': 0.9218742350231168}. Best is trial 5 with value: 0.0016427634321607534.
# [I 2025-08-03 13:15:37,597] Trial 7 finished with value: 0.001642763423812769 and parameters: {'n_estimators': 72, 'max_depth': 4, 'learning_rate': 0.0001436351616738488, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'gamma': 1.3567451588694794, 'reg_alpha': 0.8287375091519293, 'reg_lambda': 0.3567533266935893}. Best is trial 7 with value: 0.001642763423812769.
# [I 2025-08-03 13:15:37,628] Trial 8 finished with value: 0.001642763410389705 and parameters: {'n_estimators': 120, 'max_depth': 7, 'learning_rate': 0.0003090370987350513, 'subsample': 0.9010984903770198, 'colsample_bytree': 0.5372753218398854, 'gamma': 4.9344346830025865, 'reg_alpha': 0.7722447692966574, 'reg_lambda': 0.1987156815341724}. Best is trial 8 with value: 0.001642763410389705.
# [I 2025-08-03 13:15:37,641] Trial 9 finished with value: 0.0016427667547499753 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.02869648437859116, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'gamma': 0.3702232586704518, 'reg_alpha': 0.3584657285442726, 'reg_lambda': 0.11586905952512971}. Best is trial 8 with value: 0.001642763410389705.
# [I 2025-08-03 13:15:37,714] Trial 10 finished with value: 0.0016427632550201651 and parameters: {'n_estimators': 287, 'max_depth': 6, 'learning_rate': 0.0011746002328160427, 'subsample': 0.5089809378074097, 'colsample_bytree': 0.5072835039169765, 'gamma': 4.538323976412588, 'reg_alpha': 0.9657999152312998, 'reg_lambda': 0.6764178475687505}. Best is trial 10 with value: 0.0016427632550201651.
# [I 2025-08-03 13:15:37,785] Trial 11 finished with value: 0.0016427632703403725 and parameters: {'n_estimators': 287, 'max_depth': 6, 'learning_rate': 0.0013343387255799009, 'subsample': 0.5085930751344794, 'colsample_bytree': 0.5117573877987993, 'gamma': 4.9779709030838, 'reg_alpha': 0.9923480895289144, 'reg_lambda': 0.6656934168979671}. Best is trial 10 with value: 0.0016427632550201651.
# [I 2025-08-03 13:15:37,860] Trial 12 finished with value: 0.0016427630259813976 and parameters: {'n_estimators': 299, 'max_depth': 5, 'learning_rate': 0.0022455377871602594, 'subsample': 0.5018203726540555, 'colsample_bytree': 0.52247020987727, 'gamma': 3.823453444239005, 'reg_alpha': 0.9971646149932867, 'reg_lambda': 0.6910098394398291}. Best is trial 12 with value: 0.0016427630259813976.
# [I 2025-08-03 13:15:37,933] Trial 13 finished with value: 0.0016427625371444481 and parameters: {'n_estimators': 298, 'max_depth': 5, 'learning_rate': 0.007010406495725488, 'subsample': 0.5048579886309473, 'colsample_bytree': 0.5856019492388042, 'gamma': 3.482741304273752, 'reg_alpha': 0.999362438641551, 'reg_lambda': 0.7195127050992635}. Best is trial 13 with value: 0.0016427625371444481.
# [I 2025-08-03 13:15:38,037] Trial 14 finished with value: 0.0016427631899558184 and parameters: {'n_estimators': 242, 'max_depth': 3, 'learning_rate': 0.01100602622989014, 'subsample': 0.5868583137133783, 'colsample_bytree': 0.5882366621416945, 'gamma': 3.2263553013726978, 'reg_alpha': 0.8647743466919985, 'reg_lambda': 0.7421630723514321}. Best is trial 13 with value: 0.0016427625371444481.
# [I 2025-08-03 13:15:38,115] Trial 15 finished with value: 0.0016427650104694387 and parameters: {'n_estimators': 245, 'max_depth': 5, 'learning_rate': 0.007221514188459061, 'subsample': 0.5840870224066259, 'colsample_bytree': 0.7261631564388041, 'gamma': 3.4454801289499595, 'reg_alpha': 0.4541519768015846, 'reg_lambda': 0.7946453641120887}. Best is trial 13 with value: 0.0016427625371444481.
# [I 2025-08-03 13:15:38,184] Trial 16 finished with value: 0.0016427634338700638 and parameters: {'n_estimators': 249, 'max_depth': 5, 'learning_rate': 0.003120635116162347, 'subsample': 0.5837292260147117, 'colsample_bytree': 0.6061882665609473, 'gamma': 2.4426539530952667, 'reg_alpha': 0.9054286728935996, 'reg_lambda': 0.5705726322139155}. Best is trial 13 with value: 0.0016427625371444481.
# [I 2025-08-03 13:15:38,263] Trial 17 finished with value: 0.0016427727103422362 and parameters: {'n_estimators': 297, 'max_depth': 3, 'learning_rate': 0.019814525582639086, 'subsample': 0.6899453780841301, 'colsample_bytree': 0.6754572978088687, 'gamma': 2.1706826038003486, 'reg_alpha': 0.7338778192612955, 'reg_lambda': 0.9699607788793954}. Best is trial 13 with value: 0.0016427625371444481.
# [I 2025-08-03 13:15:38,334] Trial 18 finished with value: 0.0016427597936477616 and parameters: {'n_estimators': 226, 'max_depth': 5, 'learning_rate': 0.09137538131035124, 'subsample': 0.5428274365617971, 'colsample_bytree': 0.5635909985031541, 'gamma': 3.8050320261928468, 'reg_alpha': 0.9993378078922299, 'reg_lambda': 0.6064328079751506}. Best is trial 18 with value: 0.0016427597936477616.
# [I 2025-08-03 13:15:38,402] Trial 19 finished with value: 0.0016427597014658105 and parameters: {'n_estimators': 261, 'max_depth': 4, 'learning_rate': 0.06624679148661687, 'subsample': 0.5706587648401881, 'colsample_bytree': 0.7606949049418953, 'gamma': 1.7455198366464988, 'reg_alpha': 0.5400449337006843, 'reg_lambda': 0.5774122250732455}. Best is trial 19 with value: 0.0016427597014658105.
# ...
# [I 2025-08-03 13:15:41,598] Trial 10 finished with value: 0.0016500821505462011 and parameters: {'n_estimators': 267, 'max_depth': 6, 'learning_rate': 0.0019147613513840517, 'subsample': 0.5089809378074097, 'colsample_bytree': 0.7846562513261506, 'gamma': 2.215398984003511, 'reg_alpha': 0.9597707459454197, 'reg_lambda': 0.6668582750825782}. Best is trial 10 with value: 0.0016500821505462011.
# [I 2025-08-03 13:15:41,677] Trial 11 finished with value: 0.0016500823994315115 and parameters: {'n_estimators': 287, 'max_depth': 6, 'learning_rate': 0.0019461077414884933, 'subsample': 0.5051915649537512, 'colsample_bytree': 0.7930679183446125, 'gamma': 2.171781358782056, 'reg_alpha': 0.9580055402844473, 'reg_lambda': 0.6584088996754022}. Best is trial 10 with value: 0.0016500821505462011.
# [I 2025-08-03 13:15:41,757] Trial 12 finished with value: 0.0016500823575557866 and parameters: {'n_estimators': 294, 'max_depth': 5, 'learning_rate': 0.00248227591312355, 'subsample': 0.5017806615504058, 'colsample_bytree': 0.7447014489005493, 'gamma': 2.3727358231785987, 'reg_alpha': 0.9947256188755302, 'reg_lambda': 0.6855552024887765}. Best is trial 10 with value: 0.0016500821505462011.
# [I 2025-08-03 13:15:41,836] Trial 13 finished with value: 0.0016500825012023535 and parameters: {'n_estimators': 298, 'max_depth': 5, 'learning_rate': 0.000994906803741089, 'subsample': 0.5048567793367932, 'colsample_bytree': 0.7258663225811013, 'gamma': 2.5748520701047153, 'reg_alpha': 0.999362438641551, 'reg_lambda': 0.7156471649639458}. Best is trial 10 with value: 0.0016500821505462011.
# [I 2025-08-03 13:15:41,906] Trial 14 finished with value: 0.0016500817608455667 and parameters: {'n_estimators': 244, 'max_depth': 3, 'learning_rate': 0.010334523828488505, 'subsample': 0.5797654491534233, 'colsample_bytree': 0.8649174147658507, 'gamma': 1.9006075930560278, 'reg_alpha': 0.866252789149356, 'reg_lambda': 0.7188343654689756}. Best is trial 14 with value: 0.0016500817608455667.
# [I 2025-08-03 13:15:42,024] Trial 15 finished with value: 0.0016500843204019934 and parameters: {'n_estimators': 240, 'max_depth': 3, 'learning_rate': 0.011545835971609249, 'subsample': 0.6041073859028396, 'colsample_bytree': 0.8705765955899738, 'gamma': 3.2951430240448687, 'reg_alpha': 0.8445635058713601, 'reg_lambda': 0.7946453641120887}. Best is trial 14 with value: 0.0016500817608455667.
# [I 2025-08-03 13:15:42,102] Trial 16 finished with value: 0.0016500810043737785 and parameters: {'n_estimators': 251, 'max_depth': 3, 'learning_rate': 0.008638481149517731, 'subsample': 0.5820816961472802, 'colsample_bytree': 0.9972051753265123, 'gamma': 1.8259665674047345, 'reg_alpha': 0.531422981763773, 'reg_lambda': 0.5700391640753497}. Best is trial 16 with value: 0.0016500810043737785.
# [I 2025-08-03 13:15:42,294] Trial 17 finished with value: 0.0016500797137465402 and parameters: {'n_estimators': 222, 'max_depth': 3, 'learning_rate': 0.009034942879426435, 'subsample': 0.5915165014252202, 'colsample_bytree': 0.9974474580178315, 'gamma': 1.5832840002240232, 'reg_alpha': 0.45119336743673594, 'reg_lambda': 0.5501157335581602}. Best is trial 17 with value: 0.0016500797137465402.
# [I 2025-08-03 13:15:43,101] Trial 18 finished with value: 0.0016500753362506048 and parameters: {'n_estimators': 233, 'max_depth': 4, 'learning_rate': 0.05733334092382903, 'subsample': 0.7152885753970237, 'colsample_bytree': 0.99955133629538, 'gamma': 1.5286062523255588, 'reg_alpha': 0.4176643404969957, 'reg_lambda': 0.5596794183244352}. Best is trial 18 with value: 0.0016500753362506048.
# [I 2025-08-03 13:15:43,256] Trial 19 finished with value: 0.001650073298541812 and parameters: {'n_estimators': 226, 'max_depth': 4, 'learning_rate': 0.06559964396779505, 'subsample': 0.7159741024129841, 'colsample_bytree': 0.9401413919487746, 'gamma': 2.957588354978628, 'reg_alpha': 0.43646463776392824, 'reg_lambda': 0.350692177849529}. Best is trial 19 with value: 0.001650073298541812.
# [I 2025-08-03 13:15:43,354] Trial 20 finished with value: 0.0016500854669140134 and parameters: {'n_estimators': 211, 'max_depth': 4, 'learning_rate': 0.07367942682468255, 'subsample': 0.7004831188261247, 'colsample_bytree': 0.9348809951500217, 'gamma': 2.985061943499071, 'reg_alpha': 0.4463220084500361, 'reg_lambda': 0.2800209857628172}. Best is trial 19 with value: 0.001650073298541812.
# [I 2025-08-03 13:15:43,483] Trial 21 finished with value: 0.0016500731233746052 and parameters: {'n_estimators': 221, 'max_depth': 5, 'learning_rate': 0.07066938393562779, 'subsample': 0.7311564794740517, 'colsample_bytree': 0.9981126922026227, 'gamma': 1.4173154552980267, 'reg_alpha': 0.41699159494237353, 'reg_lambda': 0.45759779445632676}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:43,605] Trial 22 finished with value: 0.001650076140108273 and parameters: {'n_estimators': 225, 'max_depth': 5, 'learning_rate': 0.10048204234929159, 'subsample': 0.7313602110152428, 'colsample_bytree': 0.9396259977881556, 'gamma': 3.9649739976798553, 'reg_alpha': 0.3940568747914607, 'reg_lambda': 0.0020921981657096578}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:43,682] Trial 23 finished with value: 0.0016500749835265038 and parameters: {'n_estimators': 172, 'max_depth': 4, 'learning_rate': 0.030232709828279213, 'subsample': 0.80596175731618, 'colsample_bytree': 0.9481545518065158, 'gamma': 1.209445177426239, 'reg_alpha': 0.16206852947364703, 'reg_lambda': 0.4517132755083898}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:43,788] Trial 24 finished with value: 0.0016500789484943843 and parameters: {'n_estimators': 171, 'max_depth': 5, 'learning_rate': 0.02729915434063638, 'subsample': 0.8106452018417596, 'colsample_bytree': 0.8422623780969773, 'gamma': 2.8495273781487014, 'reg_alpha': 0.19768900895771815, 'reg_lambda': 0.42311461538241385}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:43,967] Trial 25 finished with value: 0.0016500817476433666 and parameters: {'n_estimators': 187, 'max_depth': 4, 'learning_rate': 0.1574020110308881, 'subsample': 0.7637644324926671, 'colsample_bytree': 0.9074136202529427, 'gamma': 1.1902389088951473, 'reg_alpha': 0.02287437210526344, 'reg_lambda': 0.3069009624725318}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:44,153] Trial 26 finished with value: 0.0016500823222713426 and parameters: {'n_estimators': 199, 'max_depth': 5, 'learning_rate': 0.019300760898739534, 'subsample': 0.8211338116630436, 'colsample_bytree': 0.956047722721412, 'gamma': 3.7706340033960357, 'reg_alpha': 0.2015173948173569, 'reg_lambda': 0.45813136173989955}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:44,254] Trial 27 finished with value: 0.0016534952109504872 and parameters: {'n_estimators': 153, 'max_depth': 4, 'learning_rate': 0.1103623071337147, 'subsample': 0.6813686805135717, 'colsample_bytree': 0.8364173367413742, 'gamma': 0.06948779089508239, 'reg_alpha': 0.11539994931393777, 'reg_lambda': 0.27003445426356454}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:44,334] Trial 28 finished with value: 0.0016501181396671677 and parameters: {'n_estimators': 265, 'max_depth': 6, 'learning_rate': 0.04667785766858004, 'subsample': 0.7888739370495879, 'colsample_bytree': 0.964493450030778, 'gamma': 1.084078890184682, 'reg_alpha': 0.5254147605287485, 'reg_lambda': 0.3624774195180892}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:44,393] Trial 29 finished with value: 0.0016500947680553905 and parameters: {'n_estimators': 136, 'max_depth': 5, 'learning_rate': 0.021462149067917387, 'subsample': 0.8402472912607482, 'colsample_bytree': 0.8921995434834321, 'gamma': 0.777684561526653, 'reg_alpha': 0.09370208002451048, 'reg_lambda': 0.599594842809447}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:44,450] Trial 30 finished with value: 0.0016500889899654894 and parameters: {'n_estimators': 108, 'max_depth': 3, 'learning_rate': 0.04898149717274035, 'subsample': 0.7832018381017467, 'colsample_bytree': 0.9235235342814312, 'gamma': 1.7946931450961692, 'reg_alpha': 0.2823691152917879, 'reg_lambda': 0.48142393321499316}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:44,521] Trial 31 finished with value: 0.0016500757086167586 and parameters: {'n_estimators': 228, 'max_depth': 4, 'learning_rate': 0.056214746992552196, 'subsample': 0.7347315733427126, 'colsample_bytree': 0.9944340152885692, 'gamma': 1.5250224188352446, 'reg_alpha': 0.40529778676634953, 'reg_lambda': 0.4185596767122951}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:44,595] Trial 32 finished with value: 0.0016500999574258835 and parameters: {'n_estimators': 212, 'max_depth': 4, 'learning_rate': 0.09306937620465339, 'subsample': 0.7068213766370692, 'colsample_bytree': 0.9685483850821179, 'gamma': 1.005878157375893, 'reg_alpha': 0.6112613268292487, 'reg_lambda': 0.5950051127398943}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:44,659] Trial 33 finished with value: 0.0016500785453525783 and parameters: {'n_estimators': 191, 'max_depth': 4, 'learning_rate': 0.03825452430223099, 'subsample': 0.7153776038665929, 'colsample_bytree': 0.9226221738975879, 'gamma': 2.633301624697989, 'reg_alpha': 0.2459119545138485, 'reg_lambda': 0.49989275224385854}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:44,746] Trial 34 finished with value: 0.0016500859678934738 and parameters: {'n_estimators': 274, 'max_depth': 7, 'learning_rate': 0.00508757623129844, 'subsample': 0.636154206078621, 'colsample_bytree': 0.954824556993265, 'gamma': 1.9425924556797605, 'reg_alpha': 0.3373245653807717, 'reg_lambda': 0.35293060523550046}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:44,809] Trial 35 finished with value: 0.0016500875809912585 and parameters: {'n_estimators': 160, 'max_depth': 5, 'learning_rate': 0.14735913633059555, 'subsample': 0.7582494183944154, 'colsample_bytree': 0.9995231700351286, 'gamma': 0.6638990559916962, 'reg_alpha': 0.4821182268511925, 'reg_lambda': 0.8286434732689755}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:44,882] Trial 36 finished with value: 0.0016500877715113918 and parameters: {'n_estimators': 178, 'max_depth': 3, 'learning_rate': 0.01464816381409216, 'subsample': 0.6364807869345732, 'colsample_bytree': 0.848986971736275, 'gamma': 1.466591451088066, 'reg_alpha': 0.6748407157149368, 'reg_lambda': 0.21780419851521166}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:44,966] Trial 37 finished with value: 0.0016500850727524936 and parameters: {'n_estimators': 252, 'max_depth': 8, 'learning_rate': 0.0701717616442985, 'subsample': 0.6801690633947688, 'colsample_bytree': 0.9039726714864929, 'gamma': 0.9760419223328181, 'reg_alpha': 0.25916495258801475, 'reg_lambda': 0.4049683282748494}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:45,038] Trial 38 finished with value: 0.001650075574067817 and parameters: {'n_estimators': 208, 'max_depth': 6, 'learning_rate': 0.20112703969384593, 'subsample': 0.7791942274888841, 'colsample_bytree': 0.5996992834390151, 'gamma': 3.3215487634881953, 'reg_alpha': 0.13839732839958407, 'reg_lambda': 0.5294847201873581}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:45,110] Trial 39 finished with value: 0.0016501100252142306 and parameters: {'n_estimators': 234, 'max_depth': 4, 'learning_rate': 0.1387736676421408, 'subsample': 0.9370329711460863, 'colsample_bytree': 0.9734783637630557, 'gamma': 1.2605540000631446, 'reg_alpha': 0.5468266599555769, 'reg_lambda': 0.991526718580894}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:45,184] Trial 40 finished with value: 0.0016501133841508658 and parameters: {'n_estimators': 201, 'max_depth': 5, 'learning_rate': 0.2967533377698411, 'subsample': 0.8370836951796632, 'colsample_bytree': 0.9391599284486426, 'gamma': 0.5683909760466901, 'reg_alpha': 0.344708478941634, 'reg_lambda': 0.12039821331868661}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:45,286] Trial 41 finished with value: 0.0016500745293863282 and parameters: {'n_estimators': 217, 'max_depth': 6, 'learning_rate': 0.07167705960781443, 'subsample': 0.7876912566999286, 'colsample_bytree': 0.6041193357146948, 'gamma': 3.502221529339803, 'reg_alpha': 0.15856594149488018, 'reg_lambda': 0.5126739853499055}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:45,360] Trial 42 finished with value: 0.0016500742125877444 and parameters: {'n_estimators': 218, 'max_depth': 6, 'learning_rate': 0.07338455695786328, 'subsample': 0.7344756653074821, 'colsample_bytree': 0.5057103314124921, 'gamma': 3.5873303370938054, 'reg_alpha': 0.018726060010258866, 'reg_lambda': 0.46850091596081966}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:45,425] Trial 43 finished with value: 0.001650093517204872 and parameters: {'n_estimators': 177, 'max_depth': 7, 'learning_rate': 0.03153387528810576, 'subsample': 0.7456560550189325, 'colsample_bytree': 0.5135170281089521, 'gamma': 3.7993707536963357, 'reg_alpha': 0.008589091074666056, 'reg_lambda': 0.3235367755980523}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:45,503] Trial 44 finished with value: 0.001650079215549372 and parameters: {'n_estimators': 219, 'max_depth': 6, 'learning_rate': 0.07481522783948201, 'subsample': 0.8560925715916634, 'colsample_bytree': 0.5551609394787808, 'gamma': 4.234887411699992, 'reg_alpha': 0.07703805921950663, 'reg_lambda': 0.4610558375319198}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:45,572] Trial 45 finished with value: 0.0016500735596984835 and parameters: {'n_estimators': 195, 'max_depth': 8, 'learning_rate': 0.03772186160132808, 'subsample': 0.8046939163354864, 'colsample_bytree': 0.6608583747057708, 'gamma': 3.1453210433661107, 'reg_alpha': 0.04263526162706123, 'reg_lambda': 0.39880959200308697}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:45,651] Trial 46 finished with value: 0.0016500838840063153 and parameters: {'n_estimators': 196, 'max_depth': 8, 'learning_rate': 0.19832805223597577, 'subsample': 0.7694058798175596, 'colsample_bytree': 0.6710986269665875, 'gamma': 3.476516457227455, 'reg_alpha': 0.03524612332521085, 'reg_lambda': 0.38458041643947294}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:45,724] Trial 47 finished with value: 0.0016500778941781163 and parameters: {'n_estimators': 256, 'max_depth': 9, 'learning_rate': 0.018289350559060693, 'subsample': 0.8827511053116963, 'colsample_bytree': 0.6090911796754421, 'gamma': 3.0206498968622517, 'reg_alpha': 0.064239070496243, 'reg_lambda': 0.6187428182651099}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:45,795] Trial 48 finished with value: 0.001650084826782237 and parameters: {'n_estimators': 213, 'max_depth': 7, 'learning_rate': 0.005768399798355232, 'subsample': 0.6796452724084786, 'colsample_bytree': 0.6419113140226802, 'gamma': 3.415130013559467, 'reg_alpha': 0.13110665699074364, 'reg_lambda': 0.510137606428499}. Best is trial 21 with value: 0.0016500731233746052.
# [I 2025-08-03 13:15:45,871] Trial 49 finished with value: 0.0016500972924369352 and parameters: {'n_estimators': 244, 'max_depth': 8, 'learning_rate': 0.11052397554145955, 'subsample': 0.7364307347733828, 'colsample_bytree': 0.5742727480448717, 'gamma': 4.59763116281364, 'reg_alpha': 0.2169621434027368, 'reg_lambda': 0.2646692086640928}. Best is trial 21 with value: 0.0016500731233746052.

# %%
print("\n📘 Summary of Optuna Results by Lag:\n")

for lag_val, result in lag_study_results.items():
    print(f"\n🌀 LAG = {lag_val}")
    print(f"Best MSE: {result['best_value']:.6f}")
    print("Best Parameters:")
    for k, v in result['best_params'].items():
        print(f"  {k}: {v}")
# Out:
# 📘 Summary of Optuna Results by Lag:
#
#
# 🌀 LAG = 5
# Best MSE: 0.001629
# Best Parameters:
#   n_estimators: 185
#   max_depth: 3
#   learning_rate: 0.04775283991453705
#   subsample: 0.6525095024077675
#   colsample_bytree: 0.6771291535654584
#   gamma: 1.6509170050658604
#   reg_alpha: 0.35612529736792115
#   reg_lambda: 0.5209579953143052
#
# 🌀 LAG = 10
# Best MSE: 0.001636
# Best Parameters:
#   n_estimators: 298
#   max_depth: 5
#   learning_rate: 0.004715181869011494
#   subsample: 0.5048579886309473
#   colsample_bytree: 0.5872625990747572
#   gamma: 3.482741304273752
#   reg_alpha: 0.999362438641551
#   reg_lambda: 0.7195127050992635
#
# 🌀 LAG = 15
# Best MSE: 0.001643
# Best Parameters:
#   n_estimators: 258
#   max_depth: 6
#   learning_rate: 0.04797561242674334
#   subsample: 0.6296611342466492
#   colsample_bytree: 0.9527979513972848
#   gamma: 4.213267191008484
#   reg_alpha: 0.50670338242554
#   reg_lambda: 0.5431754995258256
#
# 🌀 LAG = 20
# Best MSE: 0.001650
# Best Parameters:
#   n_estimators: 221
#   max_depth: 5
#   learning_rate: 0.07066938393562779
#   subsample: 0.7311564794740517
#   colsample_bytree: 0.9981126922026227
#   gamma: 1.4173154552980267
#   reg_alpha: 0.41699159494237353
#   reg_lambda: 0.45759779445632676

# %%
from xgboost import XGBRegressor

# --- Storage for final models and residuals ---
final_models = {}
residuals_per_lag = {}

# --- Loop over each lag from tuning history ---
for LAG, result in lag_study_results.items():
    print(f"\n📦 Retraining model on full data for LAG = {LAG}...")

    # Step 1: Recreate lagged dataframe
    lagged_df = pd.DataFrame({'target': bmm_filled})
    for i in range(1, LAG + 1):
        lagged_df[f'lag_{i}'] = bmm_filled.shift(i)
    lagged_df.dropna(inplace=True)

    # Step 2: Prepare full dataset
    X_full = lagged_df.drop("target", axis=1).values
    y_full = lagged_df["target"].values

    # Step 3: Load best parameters and create model
    best_params = result["best_params"].copy()
    best_params.update({
        "objective": "reg:squarederror",
        "random_state": SEED
    })

    model = XGBRegressor(**best_params)
    model.fit(X_full, y_full)

    # Step 4: Store model and residuals
    final_models[LAG] = model
    y_pred = model.predict(X_full)
    residuals = y_full - y_pred
    residuals_per_lag[LAG] = pd.Series(residuals, index=lagged_df.index)

    print(f"✅ Model trained and residuals saved for LAG = {LAG}")
# Out:
# 📦 Retraining model on full data for LAG = 5...
# ✅ Model trained and residuals saved for LAG = 5
#
# 📦 Retraining model on full data for LAG = 10...
# ✅ Model trained and residuals saved for LAG = 10
#
# 📦 Retraining model on full data for LAG = 15...
# ✅ Model trained and residuals saved for LAG = 15
#
# 📦 Retraining model on full data for LAG = 20...
# ✅ Model trained and residuals saved for LAG = 20

# %% [markdown]
# **3. Qualitative Analysis**

# %%
import matplotlib.pyplot as plt

def plot_residuals_for_lag(lag):
    """
    Plots residuals for a given lag using a fixed time window.

    Parameters:
        lag (int): The lag value whose residuals you want to visualize.
    """
    if lag not in residuals_per_lag:
        print(f"❌ Lag {lag} not found in residuals_per_lag.")
        return

    # Fixed time window
    start_date = "2019-01-01"
    end_date = "2019-06-01"

    # Get residuals and slice to window
    residual_series = residuals_per_lag[lag]
    residual_window = residual_series.loc[start_date:end_date]

    # Plot
    plt.figure(figsize=(12, 4))
    plt.plot(residual_window.index, residual_window.values, color="red")
    plt.axhline(0, color="black", linestyle="--", linewidth=1)
    plt.title(f"Residuals for LAG = {lag} ({start_date} to {end_date})")
    plt.xlabel("Date")
    plt.ylabel("Residual")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
plot_residuals_for_lag(10)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# --- Load and parse ground truth maneuver timestamps ---
truth_df = pd.read_excel("/content/manFY2H_cleaned.xlsx")
ground_truth_timestamps = pd.to_datetime(
    truth_df["Start Date"].astype(str) + " " + truth_df["Start Time"].astype(str)
)

# --- Define plot function for a given lag ---
def plot_residuals_with_gt_for_lag(lag):
    """
    Plot residuals with ground truth maneuver overlay for a given lag.
    Uses fixed time window from 2013-01-01 to 2013-03-01.
    """
    if lag not in residuals_per_lag:
        print(f"❌ Residuals not found for lag {lag}")
        return

    # Fixed time window
    start_date = "2019-01-01"
    end_date = "2022-06-01"

    # Get residuals for the specified lag
    residual_series = residuals_per_lag[lag]
    residual_window = residual_series.loc[start_date:end_date]

    # Filter ground truth maneuvers to the window
    gt_in_window = ground_truth_timestamps[
        (ground_truth_timestamps >= pd.to_datetime(start_date)) &
        (ground_truth_timestamps <= pd.to_datetime(end_date))
    ]

    # Plot
    plt.figure(figsize=(14, 5))
    plt.plot(residual_window.index, residual_window.values, color='red', label='Residuals')
    plt.axhline(0, color='black', linestyle='--', linewidth=1)

    for ts in gt_in_window:
        plt.axvline(ts, color='blue', linestyle='--', alpha=0.7)

    plt.title(f"Residuals with Ground Truth Maneuvers (Lag={lag})\n{start_date} to {end_date}")
    plt.xlabel("Date")
    plt.ylabel("Residual")
    plt.grid(True)
    plt.legend(["Residuals", "Ground Truth Maneuvers"])
    plt.tight_layout()
    plt.show()

# --- Example usage ---
plot_residuals_with_gt_for_lag(10)

# %% [markdown]
# **4. Quanitative Analysis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- Precision / Recall / F1 Computation ---
def compute_prf_simple(
    residual_series: pd.Series,
    ground_truth_timestamps: pd.Series,
    threshold: float,
    matching_window_days: float = 3.0
):
    detections = residual_series[residual_series > threshold]
    detection_times = detections.index.sort_values()

    TP, FP, matched_gt = 0, 0, set()
    for det_time in detection_times:
        for i, gt_time in enumerate(ground_truth_timestamps):
            if i in matched_gt:
                continue
            if abs(det_time - gt_time) <= pd.Timedelta(days=matching_window_days):
                TP += 1
                matched_gt.add(i)
                break
        else:
            FP += 1

    FN = len(ground_truth_timestamps) - len(matched_gt)

    precision = TP / (TP + FP) if (TP + FP) else 0
    recall = TP / (TP + FN) if (TP + FN) else 0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) else 0

    return precision, recall, f1, TP, FP, FN


# --- Evaluation and PR Plot ---
summary_rows = []
lag_metrics_dfs = {}  # Store metrics per lag for later scenario analysis
plt.figure(figsize=(10, 6))
matching_window_days = 3.0

for lag, residual_series in residuals_per_lag.items():
    abs_resid = residual_series.abs()

    # FULL RANGE sweep from min to max
    thresholds = np.linspace(
        abs_resid.min(),
        abs_resid.max(),
        150
    )

    pr_points = []
    metrics = []

    for threshold in thresholds:
        precision, recall, f1, TP, FP, FN = compute_prf_simple(
            abs_resid,
            ground_truth_timestamps,
            threshold,
            matching_window_days=matching_window_days
        )
        pr_points.append((recall, precision))
        metrics.append((threshold, precision, recall, f1, TP, FP, FN))

    # Convert to DataFrame to extract best row
    metrics_df = pd.DataFrame(metrics, columns=["Threshold", "Precision", "Recall", "F1", "TP", "FP", "FN"])
    best_idx = metrics_df["F1"].idxmax()
    best_row = metrics_df.loc[best_idx]

    # Compute AUC using trapezoidal rule
    pr_points_arr = np.array(pr_points)
    sorted_idx = np.argsort(pr_points_arr[:, 0])  # sort by recall
    auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall

    # Add to summary table
    summary_rows.append({
        "Lag": lag,
        "Best Threshold": best_row["Threshold"],
        "Precision": best_row["Precision"],
        "Recall": best_row["Recall"],
        "F1 Score": best_row["F1"],
        "TP": int(best_row["TP"]),
        "FP": int(best_row["FP"]),
        "FN": int(best_row["FN"]),
        "PR AUC": auc_pr
    })

    # Save full metrics for this lag
    lag_metrics_dfs[lag] = metrics_df.copy()

    # Plot PR curve
    plt.plot(pr_points_arr[:, 0], pr_points_arr[:, 1], label=f"Lag {lag}", linewidth=2)

# --- PR Curve Plot ---
plt.xlabel("Recall", fontsize=13)
plt.ylabel("Precision", fontsize=13)
plt.title("Precision–Recall Curves for Multiple Lags (Full Threshold Sweep)", fontsize=15)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title="Lag", fontsize=10)
plt.tight_layout()
plt.show()

# --- Summary Table ---
summary_df = pd.DataFrame(summary_rows)
summary_df = summary_df.sort_values("F1 Score", ascending=False).reset_index(drop=True)

from IPython.display import display
display(summary_df)
# Out:
# /tmp/ipython-input-2546430860.py:73: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall
# /tmp/ipython-input-2546430860.py:73: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall
# /tmp/ipython-input-2546430860.py:73: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall
# /tmp/ipython-input-2546430860.py:73: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall
#    Lag  Best Threshold  Precision    Recall  F1 Score  TP  FP  FN    PR AUC
# 0    5        0.139169        0.7  0.583333  0.636364   7   3   5  0.614972
# 1   10        0.139214        0.7  0.583333  0.636364   7   3   5  0.585483
# 2   15        0.139186        0.7  0.583333  0.636364   7   3   5  0.585397
# 3   20        0.139172        0.7  0.583333  0.636364   7   3   5  0.585372
