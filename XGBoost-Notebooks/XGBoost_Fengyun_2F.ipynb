# %% [markdown]
# **1. Checking for Assumptions**

# %% [markdown]
# Loading and preparing the dataset

# %%
# --- Imports ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

# --- Global Seed Setup (type this once!) ---
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)

# %%
# STEP 1: Load Libraries and Dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Brouwer Mean Motion from Fengyun-2F CSV
df = pd.read_csv('/content/Fengyun-2F.csv')
df['timestamp'] = pd.to_datetime(df['Unnamed: 0'])
df.set_index('timestamp', inplace=True)

# --- Load and parse ground truth maneuver timestamps ---
truth_df = pd.read_excel("/content/manFY2F_cleaned.xlsx")
ground_truth_timestamps = pd.to_datetime(
    truth_df["Start Date"].astype(str) + " " + truth_df["Start Time"].astype(str)
)

# Select relevant column
bmm_series = df['Brouwer mean motion']

# %% [markdown]
# 2. Checking Regualrity

# %%
# STEP 2: Resample to daily data
bmm_daily = bmm_series.resample('D').mean()

# Check missing values
missing_days = bmm_daily.isnull().sum()
print(f"Missing daily entries: {missing_days}")
# Out:
# Missing daily entries: 430

# %% [markdown]
# 3. Interpolating missing values

# %%
# STEP 3: Fill gaps using linear interpolation
bmm_filled = bmm_daily.interpolate(method='linear')

bmm_filled = bmm_filled * 1e6

# Confirm fill
print("Any missing after interpolation?", bmm_filled.isnull().any())
# Out:
# Any missing after interpolation? False

# %% [markdown]
# 4. Apply differencing

# %%
bmm_filled = bmm_filled.diff().dropna()
print("Differencing applied. First few values:")
print(bmm_filled.head())
# Out:
# Differencing applied. First few values:
# timestamp
# 2012-09-07   -0.023517
# 2012-09-08   -0.019459
# 2012-09-09   -0.021030
# 2012-09-10   -0.023255
# 2012-09-11    0.074955
# Freq: D, Name: Brouwer mean motion, dtype: float64

# %% [markdown]
# 5.Checking Stationarity

# %%
# STEP 6: Check stationarity using ADF test
from statsmodels.tsa.stattools import adfuller

adf_result = adfuller(bmm_filled.dropna())
print("ADF Statistic:", adf_result[0])
print("p-value:", adf_result[1])
if adf_result[1] < 0.05:
    print("✅ The series is stationary (p < 0.05)")
else:
    print("❌ The series is NOT stationary (p ≥ 0.05)")
# Out:
# ADF Statistic: -17.856710970093598
# p-value: 3.064509009371283e-30
# ✅ The series is stationary (p < 0.05)

# %% [markdown]
# 6. Checking Time gaps

# %%
# Ensure uniform time spacing
time_deltas = bmm_filled.index.to_series().diff().value_counts()
print("Time step distribution:")
print(time_deltas.head())
# Out:
# Time step distribution:
# timestamp
# 1 days    3413
# Name: count, dtype: int64

# %% [markdown]
# 7. Visualisation

# %%
# STEP 8: Plot raw (interpolated + optionally differenced) BMM
plt.figure(figsize=(12, 4))
plt.plot(bmm_filled.index, bmm_filled.values, color='green')
plt.title("Processed Brouwer Mean Motion")
plt.ylabel("BMM")
plt.xlabel("Date")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **2.Fitting of XGBoost**

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.4.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)

# %%
import pandas as pd
import numpy as np
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# --- Utility: Create lagged features ---
def make_lagged_features(series, lag=7):
    df_lagged = pd.DataFrame({'target': series})
    for i in range(1, lag + 1):
        df_lagged[f'lag_{i}'] = series.shift(i)
    df_lagged.dropna(inplace=True)
    return df_lagged

# Dictionary to store Optuna studies and histories for each lag
lag_study_results = {}

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from optuna.samplers import TPESampler

# --- Fix random seed for reproducibility ---
SEED = 42

# Store results for each lag
lag_study_results = {}

# Define lags to evaluate
lag_values = [5,10,15,20]

for LAG in lag_values:
    print(f"\n🚀 Running Optuna for LAG={LAG}")

    # --- Create lagged features ---
    lagged_df = make_lagged_features(bmm_filled, lag=LAG)

    # --- Train-test split ---
    train_size = int(len(lagged_df) * 0.8)
    train_df = lagged_df.iloc[:train_size]
    test_df = lagged_df.iloc[train_size:]

    X_train = train_df.drop('target', axis=1).values
    y_train = train_df['target'].values
    X_test = test_df.drop('target', axis=1).values
    y_test = test_df['target'].values

    # --- Define objective function for Optuna ---
    def objective(trial):
        params = {
            'n_estimators': trial.suggest_int('n_estimators', 50, 300),
            'max_depth': trial.suggest_int('max_depth', 3, 10),
            'learning_rate': trial.suggest_float('learning_rate', 1e-4, 0.3, log=True),
            'subsample': trial.suggest_float('subsample', 0.5, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
            'gamma': trial.suggest_float('gamma', 0, 5),
            'reg_alpha': trial.suggest_float('reg_alpha', 0, 1.0),
            'reg_lambda': trial.suggest_float('reg_lambda', 0, 1.0),
            'random_state': SEED,
            'objective': 'reg:squarederror'
        }
        model = XGBRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        mse = mean_squared_error(y_test, y_pred)
        return mse

    # --- Create and run Optuna study with seeded sampler ---
    sampler = TPESampler(seed=SEED)
    study = optuna.create_study(direction='minimize', sampler=sampler)
    study.optimize(objective, n_trials=50, show_progress_bar=True)

    # --- Store results ---
    lag_study_results[LAG] = {
        "study": study,
        "best_params": study.best_params,
        "best_value": study.best_value
    }
# Out:
# [I 2025-08-03 13:23:35,174] A new study created in memory with name: no-name-ec7ffe50-d086-4f5c-8f4a-86fd4b8f5632
# 🚀 Running Optuna for LAG=5
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-08-03 13:23:35,664] Trial 0 finished with value: 0.021486499010613083 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.035093904781414616, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132, 'reg_alpha': 0.05808361216819946, 'reg_lambda': 0.8661761457749352}. Best is trial 0 with value: 0.021486499010613083.
# [I 2025-08-03 13:23:35,715] Trial 1 finished with value: 0.022104171793907505 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.00011791655502618509, 'subsample': 0.9849549260809971, 'colsample_bytree': 0.9162213204002109, 'gamma': 1.0616955533913808, 'reg_alpha': 0.18182496720710062, 'reg_lambda': 0.18340450985343382}. Best is trial 0 with value: 0.021486499010613083.
# [I 2025-08-03 13:23:35,746] Trial 2 finished with value: 0.021776893734339272 and parameters: {'n_estimators': 126, 'max_depth': 7, 'learning_rate': 0.0031763269920199078, 'subsample': 0.645614570099021, 'colsample_bytree': 0.8059264473611898, 'gamma': 0.6974693032602092, 'reg_alpha': 0.29214464853521815, 'reg_lambda': 0.3663618432936917}. Best is trial 0 with value: 0.021486499010613083.
# [I 2025-08-03 13:23:35,799] Trial 3 finished with value: 0.022031424508258568 and parameters: {'n_estimators': 164, 'max_depth': 9, 'learning_rate': 0.0004946408182937843, 'subsample': 0.7571172192068059, 'colsample_bytree': 0.7962072844310213, 'gamma': 0.23225206359998862, 'reg_alpha': 0.6075448519014384, 'reg_lambda': 0.17052412368729153}. Best is trial 0 with value: 0.021486499010613083.
# [I 2025-08-03 13:23:35,825] Trial 4 finished with value: 0.02106593486008731 and parameters: {'n_estimators': 66, 'max_depth': 10, 'learning_rate': 0.22783459357466163, 'subsample': 0.9041986740582306, 'colsample_bytree': 0.6523068845866853, 'gamma': 0.48836057003191935, 'reg_alpha': 0.6842330265121569, 'reg_lambda': 0.4401524937396013}. Best is trial 4 with value: 0.02106593486008731.
# [I 2025-08-03 13:23:35,847] Trial 5 finished with value: 0.022130021937155155 and parameters: {'n_estimators': 80, 'max_depth': 6, 'learning_rate': 0.00013169614353741142, 'subsample': 0.954660201039391, 'colsample_bytree': 0.6293899908000085, 'gamma': 3.31261142176991, 'reg_alpha': 0.31171107608941095, 'reg_lambda': 0.5200680211778108}. Best is trial 4 with value: 0.02106593486008731.
# [I 2025-08-03 13:23:35,885] Trial 6 finished with value: 0.022131017288793575 and parameters: {'n_estimators': 187, 'max_depth': 4, 'learning_rate': 0.23515992740571925, 'subsample': 0.8875664116805573, 'colsample_bytree': 0.9697494707820946, 'gamma': 4.474136752138244, 'reg_alpha': 0.5978999788110851, 'reg_lambda': 0.9218742350231168}. Best is trial 4 with value: 0.02106593486008731.
# [I 2025-08-03 13:23:35,910] Trial 7 finished with value: 0.02212255031599872 and parameters: {'n_estimators': 72, 'max_depth': 4, 'learning_rate': 0.0001436351616738488, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'gamma': 1.3567451588694794, 'reg_alpha': 0.8287375091519293, 'reg_lambda': 0.3567533266935893}. Best is trial 4 with value: 0.02106593486008731.
# [I 2025-08-03 13:23:35,937] Trial 8 finished with value: 0.022130032233979163 and parameters: {'n_estimators': 120, 'max_depth': 7, 'learning_rate': 0.0003090370987350513, 'subsample': 0.9010984903770198, 'colsample_bytree': 0.5372753218398854, 'gamma': 4.9344346830025865, 'reg_alpha': 0.7722447692966574, 'reg_lambda': 0.1987156815341724}. Best is trial 4 with value: 0.02106593486008731.
# [I 2025-08-03 13:23:35,998] Trial 9 finished with value: 0.021142678938530987 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.02869648437859116, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'gamma': 0.3702232586704518, 'reg_alpha': 0.3584657285442726, 'reg_lambda': 0.11586905952512971}. Best is trial 4 with value: 0.02106593486008731.
# [I 2025-08-03 13:23:36,074] Trial 10 finished with value: 0.021774503405392574 and parameters: {'n_estimators': 287, 'max_depth': 10, 'learning_rate': 0.2350704805592213, 'subsample': 0.5089809378074097, 'colsample_bytree': 0.698604538182231, 'gamma': 2.28163786900188, 'reg_alpha': 0.9597707459454197, 'reg_lambda': 0.6765723797427796}. Best is trial 4 with value: 0.02106593486008731.
# [I 2025-08-03 13:23:36,124] Trial 11 finished with value: 0.021864974938599454 and parameters: {'n_estimators': 58, 'max_depth': 9, 'learning_rate': 0.031669849077126846, 'subsample': 0.8406708897311783, 'colsample_bytree': 0.8526967094075362, 'gamma': 2.0482246664498587, 'reg_alpha': 0.42829162619021155, 'reg_lambda': 0.01831277498471684}. Best is trial 4 with value: 0.02106593486008731.
# [I 2025-08-03 13:23:36,190] Trial 12 finished with value: 0.020927451290603954 and parameters: {'n_estimators': 52, 'max_depth': 10, 'learning_rate': 0.04284458147572911, 'subsample': 0.8875263785117047, 'colsample_bytree': 0.7256421272922706, 'gamma': 0.04270853218288917, 'reg_alpha': 0.48196008860966605, 'reg_lambda': 0.6139368918546553}. Best is trial 12 with value: 0.020927451290603954.
# [I 2025-08-03 13:23:36,267] Trial 13 finished with value: 0.02073451522436121 and parameters: {'n_estimators': 101, 'max_depth': 10, 'learning_rate': 0.08466120744365566, 'subsample': 0.9980082658737177, 'colsample_bytree': 0.6962996366595786, 'gamma': 0.014954772509218894, 'reg_alpha': 0.5643700126830633, 'reg_lambda': 0.6616514937418022}. Best is trial 13 with value: 0.02073451522436121.
# [I 2025-08-03 13:23:36,326] Trial 14 finished with value: 0.02177844261442687 and parameters: {'n_estimators': 104, 'max_depth': 6, 'learning_rate': 0.010935109789233885, 'subsample': 0.9994759208204097, 'colsample_bytree': 0.7218590176528398, 'gamma': 1.5172315044427895, 'reg_alpha': 0.5113924370327606, 'reg_lambda': 0.7015258158211763}. Best is trial 13 with value: 0.02073451522436121.
# [I 2025-08-03 13:23:36,390] Trial 15 finished with value: 0.02212978490577308 and parameters: {'n_estimators': 220, 'max_depth': 8, 'learning_rate': 0.07636785431248262, 'subsample': 0.9414784206182736, 'colsample_bytree': 0.795009538257401, 'gamma': 3.2951430240448687, 'reg_alpha': 0.527564446419378, 'reg_lambda': 0.6447801185575055}. Best is trial 13 with value: 0.02073451522436121.
# [I 2025-08-03 13:23:36,442] Trial 16 finished with value: 0.022122142753316375 and parameters: {'n_estimators': 103, 'max_depth': 5, 'learning_rate': 0.005490222002311203, 'subsample': 0.8099066613831163, 'colsample_bytree': 0.613952324895123, 'gamma': 2.997509191284598, 'reg_alpha': 0.7213244081669421, 'reg_lambda': 0.827787259457541}. Best is trial 13 with value: 0.02073451522436121.
# [I 2025-08-03 13:23:36,517] Trial 17 finished with value: 0.020860961562672274 and parameters: {'n_estimators': 243, 'max_depth': 8, 'learning_rate': 0.083685407404487, 'subsample': 0.7366527320227354, 'colsample_bytree': 0.5014670375203303, 'gamma': 0.136095131955984, 'reg_alpha': 0.9002148367830048, 'reg_lambda': 0.5359155049728891}. Best is trial 13 with value: 0.02073451522436121.
# [I 2025-08-03 13:23:36,597] Trial 18 finished with value: 0.021754915751875624 and parameters: {'n_estimators': 252, 'max_depth': 8, 'learning_rate': 0.09137538131035124, 'subsample': 0.6869565281607859, 'colsample_bytree': 0.5162948304782181, 'gamma': 1.6016986762895833, 'reg_alpha': 0.9981552146908241, 'reg_lambda': 0.9938897809082169}. Best is trial 13 with value: 0.02073451522436121.
# [I 2025-08-03 13:23:36,678] Trial 19 finished with value: 0.022130129930789416 and parameters: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.0014543323044061754, 'subsample': 0.5888746538292902, 'colsample_bytree': 0.5696888097378852, 'gamma': 4.134336554829187, 'reg_alpha': 0.8663225975832751, 'reg_lambda': 0.5174720435333903}. Best is trial 13 with value: 0.02073451522436121.
# [I 2025-08-03 13:23:36,754] Trial 20 finished with value: 0.021623089530635967 and parameters: {'n_estimators': 234, 'max_depth': 9, 'learning_rate': 0.01221945634008817, 'subsample': 0.7380394537486917, 'colsample_bytree': 0.9956385980717998, 'gamma': 1.0379925909333856, 'reg_alpha': 0.9217356889584432, 'reg_lambda': 0.7699689892417676}. Best is trial 13 with value: 0.02073451522436121.
# [I 2025-08-03 13:23:36,868] Trial 21 finished with value: 0.021015370852985018 and parameters: {'n_estimators': 270, 'max_depth': 10, 'learning_rate': 0.08124300026574241, 'subsample': 0.7346866215854039, 'colsample_bytree': 0.7462592273746469, 'gamma': 0.01929995887763397, 'reg_alpha': 0.44619181848677003, 'reg_lambda': 0.6075919890948812}. Best is trial 13 with value: 0.02073451522436121.
# [I 2025-08-03 13:23:36,934] Trial 22 finished with value: 0.020687346763831126 and parameters: {'n_estimators': 84, 'max_depth': 8, 'learning_rate': 0.10915610003614748, 'subsample': 0.934509695431901, 'colsample_bytree': 0.6584533293940609, 'gamma': 0.032150217657399525, 'reg_alpha': 0.6234891217527971, 'reg_lambda': 0.5708381300633601}. Best is trial 22 with value: 0.020687346763831126.
# [I 2025-08-03 13:23:36,994] Trial 23 finished with value: 0.021427246379215743 and parameters: {'n_estimators': 161, 'max_depth': 7, 'learning_rate': 0.12444508067963268, 'subsample': 0.9393135032915165, 'colsample_bytree': 0.6662082814499004, 'gamma': 0.6804436721280265, 'reg_alpha': 0.6484530541332456, 'reg_lambda': 0.42360849896282693}. Best is trial 22 with value: 0.020687346763831126.
# [I 2025-08-03 13:23:37,050] Trial 24 finished with value: 0.02175740459567711 and parameters: {'n_estimators': 89, 'max_depth': 8, 'learning_rate': 0.011341613341890934, 'subsample': 0.8106452018417596, 'colsample_bytree': 0.5875065166695066, 'gamma': 0.9937762011049018, 'reg_alpha': 0.7470875994109166, 'reg_lambda': 0.5687988517395846}. Best is trial 22 with value: 0.020687346763831126.
# [I 2025-08-03 13:23:37,116] Trial 25 finished with value: 0.02141077130292666 and parameters: {'n_estimators': 135, 'max_depth': 8, 'learning_rate': 0.01957274720127819, 'subsample': 0.6004321485879647, 'colsample_bytree': 0.5033586990728622, 'gamma': 0.3785361504963367, 'reg_alpha': 0.5927867931683303, 'reg_lambda': 0.7317541864866232}. Best is trial 22 with value: 0.020687346763831126.
# [I 2025-08-03 13:23:37,187] Trial 26 finished with value: 0.021785527133917022 and parameters: {'n_estimators': 210, 'max_depth': 9, 'learning_rate': 0.14008404871459124, 'subsample': 0.7669171841335273, 'colsample_bytree': 0.5482333575457197, 'gamma': 1.9068676165403426, 'reg_alpha': 0.8671398683608943, 'reg_lambda': 0.29689660984797733}. Best is trial 22 with value: 0.020687346763831126.
# [I 2025-08-03 13:23:37,252] Trial 27 finished with value: 0.020672473243736205 and parameters: {'n_estimators': 106, 'max_depth': 6, 'learning_rate': 0.052842031495689584, 'subsample': 0.9625632338704708, 'colsample_bytree': 0.6162972752420495, 'gamma': 0.06948779089508239, 'reg_alpha': 0.8224088552898043, 'reg_lambda': 0.48374541228636847}. Best is trial 27 with value: 0.020672473243736205.
# [I 2025-08-03 13:23:37,310] Trial 28 finished with value: 0.022061694259697028 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.05189012978870398, 'subsample': 0.9697197421306598, 'colsample_bytree': 0.6714974484579493, 'gamma': 2.7004720057958167, 'reg_alpha': 0.8200239017039891, 'reg_lambda': 0.4648962591469828}. Best is trial 27 with value: 0.020672473243736205.
# [I 2025-08-03 13:23:37,377] Trial 29 finished with value: 0.02154117865690419 and parameters: {'n_estimators': 147, 'max_depth': 6, 'learning_rate': 0.0214955692344567, 'subsample': 0.932275184634352, 'colsample_bytree': 0.6132335097315993, 'gamma': 0.777684561526653, 'reg_alpha': 0.16482620337310028, 'reg_lambda': 0.7951858697360339}. Best is trial 27 with value: 0.020672473243736205.
# [I 2025-08-03 13:23:37,439] Trial 30 finished with value: 0.021797980024310146 and parameters: {'n_estimators': 115, 'max_depth': 5, 'learning_rate': 0.005097900779200529, 'subsample': 0.8489645321244579, 'colsample_bytree': 0.6448687280148583, 'gamma': 1.176043763125779, 'reg_alpha': 0.042745180079641565, 'reg_lambda': 0.871529588825701}. Best is trial 27 with value: 0.020672473243736205.
# [I 2025-08-03 13:23:37,514] Trial 31 finished with value: 0.020611245205910594 and parameters: {'n_estimators': 144, 'max_depth': 7, 'learning_rate': 0.06660387777848599, 'subsample': 0.9977121054858006, 'colsample_bytree': 0.5970895723446366, 'gamma': 0.03534695153354229, 'reg_alpha': 0.66806815211721, 'reg_lambda': 0.5497806165139215}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:37,579] Trial 32 finished with value: 0.02146019057885697 and parameters: {'n_estimators': 145, 'max_depth': 7, 'learning_rate': 0.05438031491357159, 'subsample': 0.9993806502776064, 'colsample_bytree': 0.5886215029208642, 'gamma': 0.5157358438470985, 'reg_alpha': 0.6466156113164542, 'reg_lambda': 0.34604680231771623}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:37,632] Trial 33 finished with value: 0.021556899360555666 and parameters: {'n_estimators': 88, 'max_depth': 6, 'learning_rate': 0.15784177592396875, 'subsample': 0.9701445993103662, 'colsample_bytree': 0.6970830070345083, 'gamma': 0.8774747698680357, 'reg_alpha': 0.5424190214777809, 'reg_lambda': 0.5839446845382765}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:37,712] Trial 34 finished with value: 0.021454598460588656 and parameters: {'n_estimators': 130, 'max_depth': 7, 'learning_rate': 0.2959055260423502, 'subsample': 0.9255182189080515, 'colsample_bytree': 0.7768233151551531, 'gamma': 0.0060850772261753575, 'reg_alpha': 0.7839216523404532, 'reg_lambda': 0.45361710148602935}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:37,777] Trial 35 finished with value: 0.021256802628055033 and parameters: {'n_estimators': 175, 'max_depth': 7, 'learning_rate': 0.1418847921185193, 'subsample': 0.9747398867609127, 'colsample_bytree': 0.608766269125789, 'gamma': 0.5239889345417477, 'reg_alpha': 0.6653709960249918, 'reg_lambda': 0.681135515204698}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:37,844] Trial 36 finished with value: 0.021196244466635306 and parameters: {'n_estimators': 112, 'max_depth': 6, 'learning_rate': 0.020296546328313396, 'subsample': 0.923447801901729, 'colsample_bytree': 0.5652039029909297, 'gamma': 0.276416381711138, 'reg_alpha': 0.7184509284728272, 'reg_lambda': 0.27792741798709386}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:37,908] Trial 37 finished with value: 0.021305509207208043 and parameters: {'n_estimators': 160, 'max_depth': 9, 'learning_rate': 0.04656268140541958, 'subsample': 0.9716107625975475, 'colsample_bytree': 0.6498316676271537, 'gamma': 0.5353497956729782, 'reg_alpha': 0.5646729744088848, 'reg_lambda': 0.4083705464724973}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:37,974] Trial 38 finished with value: 0.021928626595630697 and parameters: {'n_estimators': 77, 'max_depth': 5, 'learning_rate': 0.0022996211610071707, 'subsample': 0.952774941495635, 'colsample_bytree': 0.6810998227457783, 'gamma': 0.2776365830263649, 'reg_alpha': 0.6248482451868849, 'reg_lambda': 0.49407944544830235}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:38,069] Trial 39 finished with value: 0.02160457487247078 and parameters: {'n_estimators': 90, 'max_depth': 7, 'learning_rate': 0.0629534584494114, 'subsample': 0.8765562648640627, 'colsample_bytree': 0.630378538045699, 'gamma': 1.2334357836374448, 'reg_alpha': 0.4078216808410913, 'reg_lambda': 0.567308766164668}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:38,132] Trial 40 finished with value: 0.021551223339032456 and parameters: {'n_estimators': 138, 'max_depth': 10, 'learning_rate': 0.11778217951643592, 'subsample': 0.9175451684093002, 'colsample_bytree': 0.7496770550488859, 'gamma': 0.7815397724873265, 'reg_alpha': 0.6934566072072368, 'reg_lambda': 0.7305775084815026}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:38,200] Trial 41 finished with value: 0.021006277361966846 and parameters: {'n_estimators': 191, 'max_depth': 7, 'learning_rate': 0.0948974036226215, 'subsample': 0.6935982223160906, 'colsample_bytree': 0.5336592766381899, 'gamma': 0.2192126682763939, 'reg_alpha': 0.8920568161505488, 'reg_lambda': 0.5314657482018219}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:38,257] Trial 42 finished with value: 0.020822734397446013 and parameters: {'n_estimators': 68, 'max_depth': 8, 'learning_rate': 0.20855766762172254, 'subsample': 0.7876221324771105, 'colsample_bytree': 0.59295436473328, 'gamma': 0.17754387143094758, 'reg_alpha': 0.8022878135492971, 'reg_lambda': 0.6329027519897013}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:38,309] Trial 43 finished with value: 0.02148229203485707 and parameters: {'n_estimators': 66, 'max_depth': 8, 'learning_rate': 0.179752804230706, 'subsample': 0.994797296129827, 'colsample_bytree': 0.6299681106332862, 'gamma': 0.6373755671029546, 'reg_alpha': 0.7934321876411454, 'reg_lambda': 0.6393562629254715}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:38,370] Trial 44 finished with value: 0.021159370219599755 and parameters: {'n_estimators': 80, 'max_depth': 9, 'learning_rate': 0.2930058381345054, 'subsample': 0.9610153063307721, 'colsample_bytree': 0.5892389351366848, 'gamma': 0.33491661106814197, 'reg_alpha': 0.7372776694307788, 'reg_lambda': 0.47986801667206624}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:38,441] Trial 45 finished with value: 0.020806319883133924 and parameters: {'n_estimators': 122, 'max_depth': 6, 'learning_rate': 0.03340796146401456, 'subsample': 0.7775352543850991, 'colsample_bytree': 0.5535911201313477, 'gamma': 0.07714418036687172, 'reg_alpha': 0.8383853010171183, 'reg_lambda': 0.6470872887336562}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:38,621] Trial 46 finished with value: 0.020754622115206418 and parameters: {'n_estimators': 125, 'max_depth': 6, 'learning_rate': 0.03540086017338503, 'subsample': 0.9089668015124203, 'colsample_bytree': 0.7151710043925341, 'gamma': 0.05936787324856692, 'reg_alpha': 0.486508483910008, 'reg_lambda': 0.4073309874537356}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:38,685] Trial 47 finished with value: 0.02213020444628185 and parameters: {'n_estimators': 151, 'max_depth': 4, 'learning_rate': 0.02641026807064425, 'subsample': 0.9056576503453906, 'colsample_bytree': 0.7275677221115916, 'gamma': 3.7882701125170697, 'reg_alpha': 0.35332877981695965, 'reg_lambda': 0.3733925359699485}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:38,756] Trial 48 finished with value: 0.021207586911323982 and parameters: {'n_estimators': 98, 'max_depth': 6, 'learning_rate': 0.013569182764747018, 'subsample': 0.8396660884436047, 'colsample_bytree': 0.8502915612405733, 'gamma': 0.41504802039226757, 'reg_alpha': 0.47483034927717926, 'reg_lambda': 0.303523936556748}. Best is trial 31 with value: 0.020611245205910594.
# [I 2025-08-03 13:23:38,815] Trial 49 finished with value: 0.021554525388524197 and parameters: {'n_estimators': 113, 'max_depth': 5, 'learning_rate': 0.037625087704842984, 'subsample': 0.8878108858578685, 'colsample_bytree': 0.7133595991388583, 'gamma': 0.9220135341848423, 'reg_alpha': 0.2734971551519777, 'reg_lambda': 0.2281800494293859}. Best is trial 31 with value: 0.020611245205910594.
#
# 🚀 Running Optuna for LAG=10
# [I 2025-08-03 13:23:38,827] A new study created in memory with name: no-name-6b44537b-b94d-49bd-b5b3-5e081fd2fbb4
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-08-03 13:23:38,869] Trial 0 finished with value: 0.02156297324674778 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.035093904781414616, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132, 'reg_alpha': 0.05808361216819946, 'reg_lambda': 0.8661761457749352}. Best is trial 0 with value: 0.02156297324674778.
# [I 2025-08-03 13:23:38,929] Trial 1 finished with value: 0.022132860134208312 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.00011791655502618509, 'subsample': 0.9849549260809971, 'colsample_bytree': 0.9162213204002109, 'gamma': 1.0616955533913808, 'reg_alpha': 0.18182496720710062, 'reg_lambda': 0.18340450985343382}. Best is trial 0 with value: 0.02156297324674778.
# [I 2025-08-03 13:23:38,974] Trial 2 finished with value: 0.021783071856855175 and parameters: {'n_estimators': 126, 'max_depth': 7, 'learning_rate': 0.0031763269920199078, 'subsample': 0.645614570099021, 'colsample_bytree': 0.8059264473611898, 'gamma': 0.6974693032602092, 'reg_alpha': 0.29214464853521815, 'reg_lambda': 0.3663618432936917}. Best is trial 0 with value: 0.02156297324674778.
# [I 2025-08-03 13:23:39,051] Trial 3 finished with value: 0.022020763897385845 and parameters: {'n_estimators': 164, 'max_depth': 9, 'learning_rate': 0.0004946408182937843, 'subsample': 0.7571172192068059, 'colsample_bytree': 0.7962072844310213, 'gamma': 0.23225206359998862, 'reg_alpha': 0.6075448519014384, 'reg_lambda': 0.17052412368729153}. Best is trial 0 with value: 0.02156297324674778.
# [I 2025-08-03 13:23:39,109] Trial 4 finished with value: 0.021295157830530664 and parameters: {'n_estimators': 66, 'max_depth': 10, 'learning_rate': 0.22783459357466163, 'subsample': 0.9041986740582306, 'colsample_bytree': 0.6523068845866853, 'gamma': 0.48836057003191935, 'reg_alpha': 0.6842330265121569, 'reg_lambda': 0.4401524937396013}. Best is trial 4 with value: 0.021295157830530664.
# [I 2025-08-03 13:23:39,128] Trial 5 finished with value: 0.02216319607025969 and parameters: {'n_estimators': 80, 'max_depth': 6, 'learning_rate': 0.00013169614353741142, 'subsample': 0.954660201039391, 'colsample_bytree': 0.6293899908000085, 'gamma': 3.31261142176991, 'reg_alpha': 0.31171107608941095, 'reg_lambda': 0.5200680211778108}. Best is trial 4 with value: 0.021295157830530664.
# [I 2025-08-03 13:23:39,164] Trial 6 finished with value: 0.022164264864332907 and parameters: {'n_estimators': 187, 'max_depth': 4, 'learning_rate': 0.23515992740571925, 'subsample': 0.8875664116805573, 'colsample_bytree': 0.9697494707820946, 'gamma': 4.474136752138244, 'reg_alpha': 0.5978999788110851, 'reg_lambda': 0.9218742350231168}. Best is trial 4 with value: 0.021295157830530664.
# [I 2025-08-03 13:23:39,188] Trial 7 finished with value: 0.022154921787107724 and parameters: {'n_estimators': 72, 'max_depth': 4, 'learning_rate': 0.0001436351616738488, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'gamma': 1.3567451588694794, 'reg_alpha': 0.8287375091519293, 'reg_lambda': 0.3567533266935893}. Best is trial 4 with value: 0.021295157830530664.
# [I 2025-08-03 13:23:39,212] Trial 8 finished with value: 0.022163203581937525 and parameters: {'n_estimators': 120, 'max_depth': 7, 'learning_rate': 0.0003090370987350513, 'subsample': 0.9010984903770198, 'colsample_bytree': 0.5372753218398854, 'gamma': 4.9344346830025865, 'reg_alpha': 0.7722447692966574, 'reg_lambda': 0.1987156815341724}. Best is trial 4 with value: 0.021295157830530664.
# [I 2025-08-03 13:23:39,239] Trial 9 finished with value: 0.02119019862961825 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.02869648437859116, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'gamma': 0.3702232586704518, 'reg_alpha': 0.3584657285442726, 'reg_lambda': 0.11586905952512971}. Best is trial 9 with value: 0.02119019862961825.
# [I 2025-08-03 13:23:39,316] Trial 10 finished with value: 0.0220534422670925 and parameters: {'n_estimators': 270, 'max_depth': 6, 'learning_rate': 0.016998787242493218, 'subsample': 0.5089809378074097, 'colsample_bytree': 0.8770690800880656, 'gamma': 2.0963905612410483, 'reg_alpha': 0.9597707459454197, 'reg_lambda': 0.011114384822711307}. Best is trial 9 with value: 0.02119019862961825.
# [I 2025-08-03 13:23:39,365] Trial 11 finished with value: 0.02184799986893079 and parameters: {'n_estimators': 58, 'max_depth': 10, 'learning_rate': 0.2698540583506237, 'subsample': 0.8406708897311783, 'colsample_bytree': 0.7065034325177559, 'gamma': 2.0482246664498587, 'reg_alpha': 0.42829162619021155, 'reg_lambda': 0.6195339431335992}. Best is trial 9 with value: 0.02119019862961825.
# [I 2025-08-03 13:23:39,446] Trial 12 finished with value: 0.02081319172124583 and parameters: {'n_estimators': 52, 'max_depth': 9, 'learning_rate': 0.05032216033455566, 'subsample': 0.8875263785117047, 'colsample_bytree': 0.8504769022050217, 'gamma': 0.04270853218288917, 'reg_alpha': 0.48196008860966605, 'reg_lambda': 0.719199831432569}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:39,589] Trial 13 finished with value: 0.02097005428103532 and parameters: {'n_estimators': 105, 'max_depth': 8, 'learning_rate': 0.041631203702173776, 'subsample': 0.6929722841849172, 'colsample_bytree': 0.8553002072218189, 'gamma': 0.01482767219699932, 'reg_alpha': 0.4381301674911343, 'reg_lambda': 0.7388723479770365}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:39,689] Trial 14 finished with value: 0.021025137091601892 and parameters: {'n_estimators': 104, 'max_depth': 8, 'learning_rate': 0.06531366650489707, 'subsample': 0.683813616290651, 'colsample_bytree': 0.8061578814677635, 'gamma': 0.03312264314708315, 'reg_alpha': 0.5113924370327606, 'reg_lambda': 0.7380983421262324}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:39,761] Trial 15 finished with value: 0.022163541100106193 and parameters: {'n_estimators': 245, 'max_depth': 8, 'learning_rate': 0.005567406174693454, 'subsample': 0.5827781406926889, 'colsample_bytree': 0.9384223782609153, 'gamma': 3.2951430240448687, 'reg_alpha': 0.4595228024162464, 'reg_lambda': 0.7519855389250322}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:39,824] Trial 16 finished with value: 0.021828769406877772 and parameters: {'n_estimators': 104, 'max_depth': 5, 'learning_rate': 0.005710223577172772, 'subsample': 0.7320832480224756, 'colsample_bytree': 0.9987760703916868, 'gamma': 1.50560967934853, 'reg_alpha': 0.00474011965308907, 'reg_lambda': 0.7012604427751764}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:39,879] Trial 17 finished with value: 0.02204636834245962 and parameters: {'n_estimators': 90, 'max_depth': 9, 'learning_rate': 0.083685407404487, 'subsample': 0.793063224352817, 'colsample_bytree': 0.8389308979684607, 'gamma': 2.987044029957818, 'reg_alpha': 0.15004044272720002, 'reg_lambda': 0.97263823942796}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:39,945] Trial 18 finished with value: 0.02185616335174702 and parameters: {'n_estimators': 157, 'max_depth': 3, 'learning_rate': 0.012293443195622063, 'subsample': 0.5852482777708781, 'colsample_bytree': 0.7476985607045912, 'gamma': 1.6016986762895833, 'reg_alpha': 0.5494323564836533, 'reg_lambda': 0.8211787696055182}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:40,015] Trial 19 finished with value: 0.022115205864346246 and parameters: {'n_estimators': 211, 'max_depth': 8, 'learning_rate': 0.0014543323044061754, 'subsample': 0.7163728055902456, 'colsample_bytree': 0.8543200188143997, 'gamma': 2.507285077111834, 'reg_alpha': 0.209793393871968, 'reg_lambda': 0.5997961892856538}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:40,077] Trial 20 finished with value: 0.02216379339535901 and parameters: {'n_estimators': 132, 'max_depth': 7, 'learning_rate': 0.10328582710435825, 'subsample': 0.8104153164927594, 'colsample_bytree': 0.7602245068458993, 'gamma': 4.131544247873544, 'reg_alpha': 0.3970793217006944, 'reg_lambda': 0.632630392762318}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:40,225] Trial 21 finished with value: 0.02098559251812184 and parameters: {'n_estimators': 101, 'max_depth': 8, 'learning_rate': 0.06903665118121842, 'subsample': 0.6853459371788324, 'colsample_bytree': 0.8056035664699478, 'gamma': 0.008319455585231554, 'reg_alpha': 0.5148735371530344, 'reg_lambda': 0.7773732842498771}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:40,346] Trial 22 finished with value: 0.020910955039508117 and parameters: {'n_estimators': 99, 'max_depth': 9, 'learning_rate': 0.045926489815532684, 'subsample': 0.6207056512173402, 'colsample_bytree': 0.9156725604557071, 'gamma': 0.032147000566554326, 'reg_alpha': 0.7362930879886083, 'reg_lambda': 0.8204735265914178}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:40,401] Trial 23 finished with value: 0.02172057736604156 and parameters: {'n_estimators': 89, 'max_depth': 9, 'learning_rate': 0.013356474644142248, 'subsample': 0.6173236742163661, 'colsample_bytree': 0.9123774334427459, 'gamma': 1.0030091995378925, 'reg_alpha': 0.6800928789146917, 'reg_lambda': 0.8907753352144429}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:40,454] Trial 24 finished with value: 0.02155471770421514 and parameters: {'n_estimators': 53, 'max_depth': 9, 'learning_rate': 0.029689091586264336, 'subsample': 0.5293286003447545, 'colsample_bytree': 0.9600679480799904, 'gamma': 0.5598063886894273, 'reg_alpha': 0.9827684441673251, 'reg_lambda': 0.9908441718479157}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:40,539] Trial 25 finished with value: 0.021632646062165584 and parameters: {'n_estimators': 300, 'max_depth': 10, 'learning_rate': 0.1084648004948301, 'subsample': 0.5666499227770507, 'colsample_bytree': 0.851755299027076, 'gamma': 1.0952553048451468, 'reg_alpha': 0.7969777324464022, 'reg_lambda': 0.6563839506697475}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:40,638] Trial 26 finished with value: 0.020845349800797868 and parameters: {'n_estimators': 114, 'max_depth': 9, 'learning_rate': 0.04198198067116997, 'subsample': 0.6296102793407281, 'colsample_bytree': 0.90049713123522, 'gamma': 0.06143050311283583, 'reg_alpha': 0.7068329287099645, 'reg_lambda': 0.5275766716233853}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:40,713] Trial 27 finished with value: 0.02144511008176571 and parameters: {'n_estimators': 143, 'max_depth': 9, 'learning_rate': 0.009549990109824151, 'subsample': 0.6193442314431238, 'colsample_bytree': 0.905156389856665, 'gamma': 0.41665078939015837, 'reg_alpha': 0.903856707923429, 'reg_lambda': 0.5389315587292947}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:40,770] Trial 28 finished with value: 0.022036466880586962 and parameters: {'n_estimators': 74, 'max_depth': 10, 'learning_rate': 0.0022255855086000583, 'subsample': 0.7585146855992808, 'colsample_bytree': 0.9392560093888682, 'gamma': 1.8555384384338023, 'reg_alpha': 0.6861529393055139, 'reg_lambda': 0.43292906250243435}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:40,835] Trial 29 finished with value: 0.021610319084125747 and parameters: {'n_estimators': 147, 'max_depth': 10, 'learning_rate': 0.02379584513640945, 'subsample': 0.5488545815255487, 'colsample_bytree': 0.7664140623720435, 'gamma': 0.777684561526653, 'reg_alpha': 0.736800514583827, 'reg_lambda': 0.8331398656586354}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:40,900] Trial 30 finished with value: 0.02163235668484049 and parameters: {'n_estimators': 115, 'max_depth': 7, 'learning_rate': 0.04868542639327465, 'subsample': 0.6196043497888137, 'colsample_bytree': 0.9977570610040403, 'gamma': 0.9062617232199127, 'reg_alpha': 0.6004062281125584, 'reg_lambda': 0.5619164364228436}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:40,972] Trial 31 finished with value: 0.0212396730344271 and parameters: {'n_estimators': 91, 'max_depth': 9, 'learning_rate': 0.1506507303782741, 'subsample': 0.6946998603138117, 'colsample_bytree': 0.8772171692500121, 'gamma': 0.03534684363929795, 'reg_alpha': 0.8823764185865718, 'reg_lambda': 0.7068119263852011}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:41,052] Trial 32 finished with value: 0.021306079396707672 and parameters: {'n_estimators': 178, 'max_depth': 8, 'learning_rate': 0.04218628019365097, 'subsample': 0.642158577723881, 'colsample_bytree': 0.849314715434224, 'gamma': 0.31098202459735397, 'reg_alpha': 0.44495762798308075, 'reg_lambda': 0.7975517934934786}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:41,120] Trial 33 finished with value: 0.02153075791721365 and parameters: {'n_estimators': 126, 'max_depth': 8, 'learning_rate': 0.020068931793252264, 'subsample': 0.78038473897107, 'colsample_bytree': 0.9327618942951383, 'gamma': 0.7195835361650234, 'reg_alpha': 0.6345419685203374, 'reg_lambda': 0.872221248605765}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:41,181] Trial 34 finished with value: 0.021699177037029335 and parameters: {'n_estimators': 112, 'max_depth': 9, 'learning_rate': 0.03834230787747637, 'subsample': 0.9992483437747104, 'colsample_bytree': 0.827318899966186, 'gamma': 1.1133709290967047, 'reg_alpha': 0.2477437543559573, 'reg_lambda': 0.6858355335798101}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:41,247] Trial 35 finished with value: 0.020998408528507508 and parameters: {'n_estimators': 141, 'max_depth': 8, 'learning_rate': 0.13778594740750383, 'subsample': 0.7182730201706293, 'colsample_bytree': 0.8951147319805989, 'gamma': 0.22772208165173674, 'reg_alpha': 0.35811197870136363, 'reg_lambda': 0.4554911925163194}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:41,306] Trial 36 finished with value: 0.021329450580594222 and parameters: {'n_estimators': 74, 'max_depth': 9, 'learning_rate': 0.04168494224793997, 'subsample': 0.9449744869633249, 'colsample_bytree': 0.9709323407732482, 'gamma': 0.5760678170668737, 'reg_alpha': 0.5378145993282774, 'reg_lambda': 0.9272525974258672}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:41,418] Trial 37 finished with value: 0.021166042775536714 and parameters: {'n_estimators': 202, 'max_depth': 10, 'learning_rate': 0.008428363721740455, 'subsample': 0.6508143658017066, 'colsample_bytree': 0.8730701224150422, 'gamma': 0.22951827453966717, 'reg_alpha': 0.7148854122763137, 'reg_lambda': 0.3748245639795639}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:41,488] Trial 38 finished with value: 0.02165006192467295 and parameters: {'n_estimators': 162, 'max_depth': 6, 'learning_rate': 0.17086623234590737, 'subsample': 0.5980244327471991, 'colsample_bytree': 0.7833003135765791, 'gamma': 1.2919189996082052, 'reg_alpha': 0.6417419258349144, 'reg_lambda': 0.5680727040869142}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:41,546] Trial 39 finished with value: 0.021550313709242947 and parameters: {'n_estimators': 86, 'max_depth': 7, 'learning_rate': 0.05683687437451811, 'subsample': 0.6691273658967296, 'colsample_bytree': 0.7346397807605509, 'gamma': 0.6148876661096636, 'reg_alpha': 0.8502627286868024, 'reg_lambda': 0.3228116065207707}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:41,684] Trial 40 finished with value: 0.02169687962260543 and parameters: {'n_estimators': 66, 'max_depth': 8, 'learning_rate': 0.0033221169154500994, 'subsample': 0.9516943256831643, 'colsample_bytree': 0.9209440198608887, 'gamma': 0.006151473511368355, 'reg_alpha': 0.5724945261716317, 'reg_lambda': 0.48400319787273166}. Best is trial 12 with value: 0.02081319172124583.
# [I 2025-08-03 13:23:41,773] Trial 41 finished with value: 0.020714310421946703 and parameters: {'n_estimators': 110, 'max_depth': 8, 'learning_rate': 0.0797935268763315, 'subsample': 0.6945710559675395, 'colsample_bytree': 0.8108130204825426, 'gamma': 0.03566377576849536, 'reg_alpha': 0.49149655286672705, 'reg_lambda': 0.7648575257482088}. Best is trial 41 with value: 0.020714310421946703.
# [I 2025-08-03 13:23:41,842] Trial 42 finished with value: 0.02119533389909038 and parameters: {'n_estimators': 128, 'max_depth': 9, 'learning_rate': 0.09879451616238448, 'subsample': 0.747780181690836, 'colsample_bytree': 0.8133661204034454, 'gamma': 0.32825689575435374, 'reg_alpha': 0.33750680287904194, 'reg_lambda': 0.8429927985142918}. Best is trial 41 with value: 0.020714310421946703.
# [I 2025-08-03 13:23:41,906] Trial 43 finished with value: 0.021543134617914933 and parameters: {'n_estimators': 107, 'max_depth': 7, 'learning_rate': 0.024994211939936162, 'subsample': 0.7055161149783251, 'colsample_bytree': 0.8277697278787735, 'gamma': 0.7683787386303595, 'reg_alpha': 0.46914736665745266, 'reg_lambda': 0.7603134995609515}. Best is trial 41 with value: 0.020714310421946703.
# [I 2025-08-03 13:23:41,960] Trial 44 finished with value: 0.021515322474812342 and parameters: {'n_estimators': 61, 'max_depth': 10, 'learning_rate': 0.19264321174300725, 'subsample': 0.6389357165196757, 'colsample_bytree': 0.5007250058963767, 'gamma': 0.43906013600641813, 'reg_alpha': 0.41364724106082185, 'reg_lambda': 0.6561063810698362}. Best is trial 41 with value: 0.020714310421946703.
# [I 2025-08-03 13:23:42,026] Trial 45 finished with value: 0.020935527366159522 and parameters: {'n_estimators': 99, 'max_depth': 9, 'learning_rate': 0.06883600857490638, 'subsample': 0.8296592409102227, 'colsample_bytree': 0.8636570085254396, 'gamma': 0.19966615545309266, 'reg_alpha': 0.48495674464335486, 'reg_lambda': 0.7202189632111028}. Best is trial 41 with value: 0.020714310421946703.
# [I 2025-08-03 13:23:42,091] Trial 46 finished with value: 0.021145795785206787 and parameters: {'n_estimators': 79, 'max_depth': 9, 'learning_rate': 0.29384946356746605, 'subsample': 0.837000826249826, 'colsample_bytree': 0.7764555111159469, 'gamma': 0.23390124433691278, 'reg_alpha': 0.49556910169498725, 'reg_lambda': 0.9092994863826828}. Best is trial 41 with value: 0.020714310421946703.
# [I 2025-08-03 13:23:42,304] A new study created in memory with name: no-name-a57f1eee-f4d5-46a9-a3b6-369ce91fdaf6
# [I 2025-08-03 13:23:42,163] Trial 47 finished with value: 0.021285807991360317 and parameters: {'n_estimators': 120, 'max_depth': 10, 'learning_rate': 0.0814243513971966, 'subsample': 0.8827511053116963, 'colsample_bytree': 0.8956364237676385, 'gamma': 0.5218084121375028, 'reg_alpha': 0.766167925264151, 'reg_lambda': 0.5873891233745434}. Best is trial 41 with value: 0.020714310421946703.
# [I 2025-08-03 13:23:42,227] Trial 48 finished with value: 0.022163370114405903 and parameters: {'n_estimators': 95, 'max_depth': 9, 'learning_rate': 0.016149642020549165, 'subsample': 0.917630509519303, 'colsample_bytree': 0.6234873022059475, 'gamma': 3.8316046365407663, 'reg_alpha': 0.5721319304895749, 'reg_lambda': 0.710835508697459}. Best is trial 41 with value: 0.020714310421946703.
# [I 2025-08-03 13:23:42,290] Trial 49 finished with value: 0.02158979257382095 and parameters: {'n_estimators': 136, 'max_depth': 9, 'learning_rate': 0.05680231294235673, 'subsample': 0.8529616636160795, 'colsample_bytree': 0.8686150388134555, 'gamma': 0.9374342721657178, 'reg_alpha': 0.27195948106937123, 'reg_lambda': 0.7980415235937338}. Best is trial 41 with value: 0.020714310421946703.
#
# 🚀 Running Optuna for LAG=15
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-08-03 13:23:42,355] Trial 0 finished with value: 0.021579147171286138 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.035093904781414616, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132, 'reg_alpha': 0.05808361216819946, 'reg_lambda': 0.8661761457749352}. Best is trial 0 with value: 0.021579147171286138.
# [I 2025-08-03 13:23:42,428] Trial 1 finished with value: 0.022166910745300424 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.00011791655502618509, 'subsample': 0.9849549260809971, 'colsample_bytree': 0.9162213204002109, 'gamma': 1.0616955533913808, 'reg_alpha': 0.18182496720710062, 'reg_lambda': 0.18340450985343382}. Best is trial 0 with value: 0.021579147171286138.
# [I 2025-08-03 13:23:42,473] Trial 2 finished with value: 0.021839988629825835 and parameters: {'n_estimators': 126, 'max_depth': 7, 'learning_rate': 0.0031763269920199078, 'subsample': 0.645614570099021, 'colsample_bytree': 0.8059264473611898, 'gamma': 0.6974693032602092, 'reg_alpha': 0.29214464853521815, 'reg_lambda': 0.3663618432936917}. Best is trial 0 with value: 0.021579147171286138.
# [I 2025-08-03 13:23:42,572] Trial 3 finished with value: 0.02205133124528103 and parameters: {'n_estimators': 164, 'max_depth': 9, 'learning_rate': 0.0004946408182937843, 'subsample': 0.7571172192068059, 'colsample_bytree': 0.7962072844310213, 'gamma': 0.23225206359998862, 'reg_alpha': 0.6075448519014384, 'reg_lambda': 0.17052412368729153}. Best is trial 0 with value: 0.021579147171286138.
# [I 2025-08-03 13:23:42,596] Trial 4 finished with value: 0.02136013163290872 and parameters: {'n_estimators': 66, 'max_depth': 10, 'learning_rate': 0.22783459357466163, 'subsample': 0.9041986740582306, 'colsample_bytree': 0.6523068845866853, 'gamma': 0.48836057003191935, 'reg_alpha': 0.6842330265121569, 'reg_lambda': 0.4401524937396013}. Best is trial 4 with value: 0.02136013163290872.
# [I 2025-08-03 13:23:42,617] Trial 5 finished with value: 0.022194997902496717 and parameters: {'n_estimators': 80, 'max_depth': 6, 'learning_rate': 0.00013169614353741142, 'subsample': 0.954660201039391, 'colsample_bytree': 0.6293899908000085, 'gamma': 3.31261142176991, 'reg_alpha': 0.31171107608941095, 'reg_lambda': 0.5200680211778108}. Best is trial 4 with value: 0.02136013163290872.
# [I 2025-08-03 13:23:42,662] Trial 6 finished with value: 0.022195402595191514 and parameters: {'n_estimators': 187, 'max_depth': 4, 'learning_rate': 0.23515992740571925, 'subsample': 0.8875664116805573, 'colsample_bytree': 0.9697494707820946, 'gamma': 4.474136752138244, 'reg_alpha': 0.5978999788110851, 'reg_lambda': 0.9218742350231168}. Best is trial 4 with value: 0.02136013163290872.
# [I 2025-08-03 13:23:42,686] Trial 7 finished with value: 0.02218604510967423 and parameters: {'n_estimators': 72, 'max_depth': 4, 'learning_rate': 0.0001436351616738488, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'gamma': 1.3567451588694794, 'reg_alpha': 0.8287375091519293, 'reg_lambda': 0.3567533266935893}. Best is trial 4 with value: 0.02136013163290872.
# [I 2025-08-03 13:23:42,719] Trial 8 finished with value: 0.02219499217176448 and parameters: {'n_estimators': 120, 'max_depth': 7, 'learning_rate': 0.0003090370987350513, 'subsample': 0.9010984903770198, 'colsample_bytree': 0.5372753218398854, 'gamma': 4.9344346830025865, 'reg_alpha': 0.7722447692966574, 'reg_lambda': 0.1987156815341724}. Best is trial 4 with value: 0.02136013163290872.
# [I 2025-08-03 13:23:42,746] Trial 9 finished with value: 0.021234945223726848 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.02869648437859116, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'gamma': 0.3702232586704518, 'reg_alpha': 0.3584657285442726, 'reg_lambda': 0.11586905952512971}. Best is trial 9 with value: 0.021234945223726848.
# [I 2025-08-03 13:23:42,829] Trial 10 finished with value: 0.02207422320336065 and parameters: {'n_estimators': 270, 'max_depth': 6, 'learning_rate': 0.016998787242493218, 'subsample': 0.5089809378074097, 'colsample_bytree': 0.8770690800880656, 'gamma': 2.0963905612410483, 'reg_alpha': 0.9597707459454197, 'reg_lambda': 0.011114384822711307}. Best is trial 9 with value: 0.021234945223726848.
# [I 2025-08-03 13:23:42,888] Trial 11 finished with value: 0.02190689069647746 and parameters: {'n_estimators': 58, 'max_depth': 10, 'learning_rate': 0.2698540583506237, 'subsample': 0.8406708897311783, 'colsample_bytree': 0.7065034325177559, 'gamma': 2.0482246664498587, 'reg_alpha': 0.42829162619021155, 'reg_lambda': 0.6195339431335992}. Best is trial 9 with value: 0.021234945223726848.
# [I 2025-08-03 13:23:42,980] Trial 12 finished with value: 0.02095563931738556 and parameters: {'n_estimators': 52, 'max_depth': 9, 'learning_rate': 0.05032216033455566, 'subsample': 0.8875263785117047, 'colsample_bytree': 0.8504769022050217, 'gamma': 0.04270853218288917, 'reg_alpha': 0.48196008860966605, 'reg_lambda': 0.719199831432569}. Best is trial 12 with value: 0.02095563931738556.
# [I 2025-08-03 13:23:43,146] Trial 13 finished with value: 0.02096524246475342 and parameters: {'n_estimators': 105, 'max_depth': 8, 'learning_rate': 0.041631203702173776, 'subsample': 0.6929722841849172, 'colsample_bytree': 0.8553002072218189, 'gamma': 0.01482767219699932, 'reg_alpha': 0.4381301674911343, 'reg_lambda': 0.7388723479770365}. Best is trial 12 with value: 0.02095563931738556.
# [I 2025-08-03 13:23:43,290] Trial 14 finished with value: 0.020947153651277778 and parameters: {'n_estimators': 104, 'max_depth': 8, 'learning_rate': 0.06531366650489707, 'subsample': 0.683813616290651, 'colsample_bytree': 0.8061578814677635, 'gamma': 0.03312264314708315, 'reg_alpha': 0.5113924370327606, 'reg_lambda': 0.7380983421262324}. Best is trial 14 with value: 0.020947153651277778.
# [I 2025-08-03 13:23:43,369] Trial 15 finished with value: 0.022194482799043076 and parameters: {'n_estimators': 218, 'max_depth': 8, 'learning_rate': 0.004869477890923847, 'subsample': 0.5827781406926889, 'colsample_bytree': 0.7548572093429927, 'gamma': 3.2951430240448687, 'reg_alpha': 0.5442138262378953, 'reg_lambda': 0.7514892999269548}. Best is trial 14 with value: 0.020947153651277778.
# [I 2025-08-03 13:23:43,428] Trial 16 finished with value: 0.021741863217581085 and parameters: {'n_estimators': 103, 'max_depth': 5, 'learning_rate': 0.08937939657948939, 'subsample': 0.7320832480224756, 'colsample_bytree': 0.9987760703916868, 'gamma': 1.50560967934853, 'reg_alpha': 0.4807099593747105, 'reg_lambda': 0.7007249074349088}. Best is trial 14 with value: 0.020947153651277778.
# [I 2025-08-03 13:23:43,481] Trial 17 finished with value: 0.02217551019133493 and parameters: {'n_estimators': 90, 'max_depth': 9, 'learning_rate': 0.010304741738287996, 'subsample': 0.5965772670814112, 'colsample_bytree': 0.810693617854353, 'gamma': 2.987044029957818, 'reg_alpha': 0.15004044272720002, 'reg_lambda': 0.9725371615694804}. Best is trial 14 with value: 0.020947153651277778.
# [I 2025-08-03 13:23:43,547] Trial 18 finished with value: 0.021783405510248374 and parameters: {'n_estimators': 145, 'max_depth': 3, 'learning_rate': 0.08408326876865087, 'subsample': 0.8132394567758081, 'colsample_bytree': 0.9478668969549889, 'gamma': 1.6016986762895833, 'reg_alpha': 0.7054537062738465, 'reg_lambda': 0.8211787696055182}. Best is trial 14 with value: 0.020947153651277778.
# [I 2025-08-03 13:23:43,636] Trial 19 finished with value: 0.02215041689776718 and parameters: {'n_estimators': 287, 'max_depth': 8, 'learning_rate': 0.002045788358293527, 'subsample': 0.7544175409906753, 'colsample_bytree': 0.7292524739231765, 'gamma': 2.507285077111834, 'reg_alpha': 0.9265817875897115, 'reg_lambda': 0.5997961892856538}. Best is trial 14 with value: 0.020947153651277778.
# [I 2025-08-03 13:23:43,713] Trial 20 finished with value: 0.02219449799985548 and parameters: {'n_estimators': 232, 'max_depth': 7, 'learning_rate': 0.07367942682468255, 'subsample': 0.9426468000574798, 'colsample_bytree': 0.8380549877235325, 'gamma': 4.131544247873544, 'reg_alpha': 0.20822120744146577, 'reg_lambda': 0.632630392762318}. Best is trial 14 with value: 0.020947153651277778.
# ...
# [I 2025-08-03 13:23:48,845] Trial 10 finished with value: 0.021751241506484276 and parameters: {'n_estimators': 270, 'max_depth': 6, 'learning_rate': 0.016998787242493218, 'subsample': 0.5089809378074097, 'colsample_bytree': 0.8770690800880656, 'gamma': 2.0963905612410483, 'reg_alpha': 0.9597707459454197, 'reg_lambda': 0.011114384822711307}. Best is trial 9 with value: 0.020884324047913943.
# [I 2025-08-03 13:23:48,899] Trial 11 finished with value: 0.021582774924498567 and parameters: {'n_estimators': 58, 'max_depth': 10, 'learning_rate': 0.2698540583506237, 'subsample': 0.8406708897311783, 'colsample_bytree': 0.7065034325177559, 'gamma': 2.0482246664498587, 'reg_alpha': 0.42829162619021155, 'reg_lambda': 0.6195339431335992}. Best is trial 9 with value: 0.020884324047913943.
# [I 2025-08-03 13:23:49,012] Trial 12 finished with value: 0.020912652975410336 and parameters: {'n_estimators': 52, 'max_depth': 9, 'learning_rate': 0.05032216033455566, 'subsample': 0.8875263785117047, 'colsample_bytree': 0.8504769022050217, 'gamma': 0.04270853218288917, 'reg_alpha': 0.48196008860966605, 'reg_lambda': 0.719199831432569}. Best is trial 9 with value: 0.020884324047913943.
# [I 2025-08-03 13:23:49,211] Trial 13 finished with value: 0.021247176996896006 and parameters: {'n_estimators': 105, 'max_depth': 8, 'learning_rate': 0.041631203702173776, 'subsample': 0.6929722841849172, 'colsample_bytree': 0.8553002072218189, 'gamma': 0.01482767219699932, 'reg_alpha': 0.4381301674911343, 'reg_lambda': 0.7388723479770365}. Best is trial 9 with value: 0.020884324047913943.
# [I 2025-08-03 13:23:49,307] Trial 14 finished with value: 0.021505922212404594 and parameters: {'n_estimators': 254, 'max_depth': 9, 'learning_rate': 0.0053508920255900694, 'subsample': 0.8223368426340427, 'colsample_bytree': 0.9908943974613671, 'gamma': 1.5172315044427895, 'reg_alpha': 0.326907454752793, 'reg_lambda': 0.7083538457275693}. Best is trial 9 with value: 0.020884324047913943.
# [I 2025-08-03 13:23:49,363] Trial 15 finished with value: 0.021889856233040607 and parameters: {'n_estimators': 98, 'max_depth': 8, 'learning_rate': 0.06302147017281824, 'subsample': 0.7485575853833997, 'colsample_bytree': 0.7792860049248278, 'gamma': 3.1822910653688945, 'reg_alpha': 0.49723743263401377, 'reg_lambda': 0.0033680681309551513}. Best is trial 9 with value: 0.020884324047913943.
# [I 2025-08-03 13:23:49,485] Trial 16 finished with value: 0.021801320861338538 and parameters: {'n_estimators': 216, 'max_depth': 9, 'learning_rate': 0.012844662117393626, 'subsample': 0.9340643413603817, 'colsample_bytree': 0.918999729914576, 'gamma': 2.912554411220166, 'reg_alpha': 0.00474011965308907, 'reg_lambda': 0.7959534552601089}. Best is trial 9 with value: 0.020884324047913943.
# [I 2025-08-03 13:23:49,539] Trial 17 finished with value: 0.02181783743097194 and parameters: {'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.0013817985496687782, 'subsample': 0.8675044221947924, 'colsample_bytree': 0.8364878807566659, 'gamma': 1.7077504746774612, 'reg_alpha': 0.2542795462208405, 'reg_lambda': 0.5996408444196237}. Best is trial 9 with value: 0.020884324047913943.
# [I 2025-08-03 13:23:49,606] Trial 18 finished with value: 0.021890183813922857 and parameters: {'n_estimators': 156, 'max_depth': 3, 'learning_rate': 0.09137538131035124, 'subsample': 0.7696363894573159, 'colsample_bytree': 0.7437433874649324, 'gamma': 4.069968527889158, 'reg_alpha': 0.11295591081191048, 'reg_lambda': 0.9795661442849323}. Best is trial 9 with value: 0.020884324047913943.
# [I 2025-08-03 13:23:49,700] Trial 19 finished with value: 0.021842216021254062 and parameters: {'n_estimators': 297, 'max_depth': 9, 'learning_rate': 0.01394211234371456, 'subsample': 0.5215579462336457, 'colsample_bytree': 0.9102879966145797, 'gamma': 2.507285077111834, 'reg_alpha': 0.3890306724178436, 'reg_lambda': 0.6109090827403003}. Best is trial 9 with value: 0.020884324047913943.
# [I 2025-08-03 13:23:49,757] Trial 20 finished with value: 0.02127369051570544 and parameters: {'n_estimators': 91, 'max_depth': 8, 'learning_rate': 0.11230452795161823, 'subsample': 0.6006818104614413, 'colsample_bytree': 0.96213728163943, 'gamma': 0.8743583682661649, 'reg_alpha': 0.5492564049495443, 'reg_lambda': 0.27581810589061206}. Best is trial 9 with value: 0.020884324047913943.
# [I 2025-08-03 13:23:49,808] Trial 21 finished with value: 0.020974810489226746 and parameters: {'n_estimators': 53, 'max_depth': 10, 'learning_rate': 0.1389506314507589, 'subsample': 0.996596609748154, 'colsample_bytree': 0.641494523347917, 'gamma': 0.37977808008230896, 'reg_alpha': 0.70051357090922, 'reg_lambda': 0.4616941106162234}. Best is trial 9 with value: 0.020884324047913943.
# [I 2025-08-03 13:23:49,941] Trial 22 finished with value: 0.020871877508451736 and parameters: {'n_estimators': 53, 'max_depth': 10, 'learning_rate': 0.030026327683812953, 'subsample': 0.9786615784528268, 'colsample_bytree': 0.7381307267334054, 'gamma': 0.032864835036815525, 'reg_alpha': 0.6937600940673735, 'reg_lambda': 0.5126739476405506}. Best is trial 22 with value: 0.020871877508451736.
# [I 2025-08-03 13:23:50,057] Trial 23 finished with value: 0.02064107361865938 and parameters: {'n_estimators': 79, 'max_depth': 9, 'learning_rate': 0.025826110292152378, 'subsample': 0.942924589399254, 'colsample_bytree': 0.7492002381217268, 'gamma': 0.0707921042505188, 'reg_alpha': 0.8908257169631039, 'reg_lambda': 0.5420414199764683}. Best is trial 23 with value: 0.02064107361865938.
# [I 2025-08-03 13:23:50,123] Trial 24 finished with value: 0.021427082499723554 and parameters: {'n_estimators': 120, 'max_depth': 10, 'learning_rate': 0.02505972999931893, 'subsample': 0.9419474477439927, 'colsample_bytree': 0.7260213548223178, 'gamma': 1.1473087242199085, 'reg_alpha': 0.9827684441673251, 'reg_lambda': 0.5429185351452368}. Best is trial 23 with value: 0.02064107361865938.
# [I 2025-08-03 13:23:50,195] Trial 25 finished with value: 0.02124863028730403 and parameters: {'n_estimators': 81, 'max_depth': 7, 'learning_rate': 0.007029351183097676, 'subsample': 0.965922794192163, 'colsample_bytree': 0.7681098247676401, 'gamma': 0.47777827360020075, 'reg_alpha': 0.8146049568032232, 'reg_lambda': 0.36682754086610125}. Best is trial 23 with value: 0.02064107361865938.
# [I 2025-08-03 13:23:50,360] Trial 26 finished with value: 0.02111729364102976 and parameters: {'n_estimators': 103, 'max_depth': 9, 'learning_rate': 0.007155274374353855, 'subsample': 0.8499910360159533, 'colsample_bytree': 0.6817335473360224, 'gamma': 0.06332374611919012, 'reg_alpha': 0.9119886906306442, 'reg_lambda': 0.09284507604477055}. Best is trial 23 with value: 0.02064107361865938.
# [I 2025-08-03 13:23:50,424] Trial 27 finished with value: 0.021216050327889823 and parameters: {'n_estimators': 76, 'max_depth': 8, 'learning_rate': 0.022998501770808626, 'subsample': 0.924846322558455, 'colsample_bytree': 0.5987809766678114, 'gamma': 0.5839020311853238, 'reg_alpha': 0.8627770749136473, 'reg_lambda': 0.27003445426356454}. Best is trial 23 with value: 0.02064107361865938.
# [I 2025-08-03 13:23:50,522] Trial 28 finished with value: 0.02170808636584834 and parameters: {'n_estimators': 88, 'max_depth': 10, 'learning_rate': 0.0022255855086000583, 'subsample': 0.991543017749585, 'colsample_bytree': 0.8169014910762515, 'gamma': 1.7846170256065996, 'reg_alpha': 0.7314447428796006, 'reg_lambda': 0.43292906250243435}. Best is trial 23 with value: 0.02064107361865938.
# [I 2025-08-03 13:23:50,595] Trial 29 finished with value: 0.021334370403215615 and parameters: {'n_estimators': 139, 'max_depth': 10, 'learning_rate': 0.010648061803863946, 'subsample': 0.8168361928475245, 'colsample_bytree': 0.7500949942496841, 'gamma': 0.838161147928161, 'reg_alpha': 0.6622261204343322, 'reg_lambda': 0.663307664496384}. Best is trial 23 with value: 0.02064107361865938.
# [I 2025-08-03 13:23:50,669] Trial 30 finished with value: 0.02137292365914021 and parameters: {'n_estimators': 134, 'max_depth': 9, 'learning_rate': 0.029958113611432673, 'subsample': 0.7912848556278718, 'colsample_bytree': 0.527132429478923, 'gamma': 1.006714553846742, 'reg_alpha': 0.9084921665189445, 'reg_lambda': 0.826839025726088}. Best is trial 23 with value: 0.02064107361865938.
# [I 2025-08-03 13:23:50,788] Trial 31 finished with value: 0.021034543385369812 and parameters: {'n_estimators': 52, 'max_depth': 9, 'learning_rate': 0.049972741547361, 'subsample': 0.8704919588432463, 'colsample_bytree': 0.8787391112470286, 'gamma': 0.03537093083384166, 'reg_alpha': 0.4982717411694328, 'reg_lambda': 0.7434862040624634}. Best is trial 23 with value: 0.02064107361865938.
# [I 2025-08-03 13:23:50,854] Trial 32 finished with value: 0.020592010767733683 and parameters: {'n_estimators': 63, 'max_depth': 9, 'learning_rate': 0.06968030411362963, 'subsample': 0.9602935072008227, 'colsample_bytree': 0.8392353790686576, 'gamma': 0.3111568489626351, 'reg_alpha': 0.17909782284982662, 'reg_lambda': 0.5448317787374128}. Best is trial 32 with value: 0.020592010767733683.
# [I 2025-08-03 13:23:50,912] Trial 33 finished with value: 0.021118582879841252 and parameters: {'n_estimators': 72, 'max_depth': 8, 'learning_rate': 0.07595323510691517, 'subsample': 0.9667179831794079, 'colsample_bytree': 0.8249385601396848, 'gamma': 0.6368953178354728, 'reg_alpha': 0.16513359358624508, 'reg_lambda': 0.5204472188516862}. Best is trial 32 with value: 0.020592010767733683.
# [I 2025-08-03 13:23:50,990] Trial 34 finished with value: 0.020798221439309834 and parameters: {'n_estimators': 112, 'max_depth': 10, 'learning_rate': 0.03195658570485185, 'subsample': 0.9210645213573693, 'colsample_bytree': 0.7887519885964649, 'gamma': 0.39681444367541996, 'reg_alpha': 0.15653814658720921, 'reg_lambda': 0.5613975714423032}. Best is trial 32 with value: 0.020592010767733683.
# [I 2025-08-03 13:23:51,056] Trial 35 finished with value: 0.02055106540246781 and parameters: {'n_estimators': 109, 'max_depth': 10, 'learning_rate': 0.1279951306663549, 'subsample': 0.9299421276977342, 'colsample_bytree': 0.786943680802772, 'gamma': 0.2943851808953406, 'reg_alpha': 0.09186002402443909, 'reg_lambda': 0.5812363410953111}. Best is trial 35 with value: 0.02055106540246781.
# [I 2025-08-03 13:23:51,124] Trial 36 finished with value: 0.021356567071322906 and parameters: {'n_estimators': 112, 'max_depth': 10, 'learning_rate': 0.15836066564754905, 'subsample': 0.9254544670183085, 'colsample_bytree': 0.7908410235908371, 'gamma': 1.0197311308470387, 'reg_alpha': 0.2214410876957118, 'reg_lambda': 0.5933559931759902}. Best is trial 35 with value: 0.02055106540246781.
# [I 2025-08-03 13:23:51,191] Trial 37 finished with value: 0.02137114968760498 and parameters: {'n_estimators': 146, 'max_depth': 10, 'learning_rate': 0.1336361156625739, 'subsample': 0.9105037757865602, 'colsample_bytree': 0.7679942441424057, 'gamma': 1.377060191443721, 'reg_alpha': 0.10482157655015295, 'reg_lambda': 0.39880195128017587}. Best is trial 35 with value: 0.02055106540246781.
# [I 2025-08-03 13:23:51,270] Trial 38 finished with value: 0.02115388867351441 and parameters: {'n_estimators': 177, 'max_depth': 8, 'learning_rate': 0.07170587621616796, 'subsample': 0.951286157926729, 'colsample_bytree': 0.8026950723423509, 'gamma': 0.6825482584867189, 'reg_alpha': 0.017101988665644385, 'reg_lambda': 0.558351270354467}. Best is trial 35 with value: 0.02055106540246781.
# [I 2025-08-03 13:23:51,358] Trial 39 finished with value: 0.020749845276995006 and parameters: {'n_estimators': 209, 'max_depth': 7, 'learning_rate': 0.15928035196191462, 'subsample': 0.9009266235328555, 'colsample_bytree': 0.7178586448322042, 'gamma': 0.29416180866011304, 'reg_alpha': 0.0832678535050505, 'reg_lambda': 0.47281166449718526}. Best is trial 35 with value: 0.02055106540246781.
# [I 2025-08-03 13:23:51,443] Trial 40 finished with value: 0.021401663827885227 and parameters: {'n_estimators': 203, 'max_depth': 6, 'learning_rate': 0.17169406229898998, 'subsample': 0.9994786669261622, 'colsample_bytree': 0.6838384094939254, 'gamma': 1.1960230173190047, 'reg_alpha': 0.05917180405107797, 'reg_lambda': 0.4727960659458496}. Best is trial 35 with value: 0.02055106540246781.
# [I 2025-08-03 13:23:51,569] Trial 41 finished with value: 0.020674237691103593 and parameters: {'n_estimators': 226, 'max_depth': 7, 'learning_rate': 0.08579101844760229, 'subsample': 0.8986547483879858, 'colsample_bytree': 0.6631799046567, 'gamma': 0.28381236008483157, 'reg_alpha': 0.13181693949242526, 'reg_lambda': 0.6642852018018263}. Best is trial 35 with value: 0.02055106540246781.
# [I 2025-08-03 13:23:51,664] Trial 42 finished with value: 0.02060429784028726 and parameters: {'n_estimators': 237, 'max_depth': 7, 'learning_rate': 0.28485268115938384, 'subsample': 0.8882958113228805, 'colsample_bytree': 0.6670746163814412, 'gamma': 0.29871613178998263, 'reg_alpha': 0.09826338945957452, 'reg_lambda': 0.6616325587279935}. Best is trial 35 with value: 0.02055106540246781.
# [I 2025-08-03 13:23:51,747] Trial 43 finished with value: 0.021278231219905307 and parameters: {'n_estimators': 250, 'max_depth': 5, 'learning_rate': 0.2646954677508447, 'subsample': 0.9511814980688699, 'colsample_bytree': 0.5968844110767413, 'gamma': 0.7624320420380664, 'reg_alpha': 0.22571924120959422, 'reg_lambda': 0.6732970663640193}. Best is trial 35 with value: 0.02055106540246781.
# [I 2025-08-03 13:23:51,837] Trial 44 finished with value: 0.020275933600755778 and parameters: {'n_estimators': 234, 'max_depth': 7, 'learning_rate': 0.29652196566427413, 'subsample': 0.8912875220924008, 'colsample_bytree': 0.649860171220549, 'gamma': 0.22128582524098034, 'reg_alpha': 0.13275143875443612, 'reg_lambda': 0.6514104112152276}. Best is trial 44 with value: 0.020275933600755778.
# [I 2025-08-03 13:23:51,921] Trial 45 finished with value: 0.02123079014213701 and parameters: {'n_estimators': 235, 'max_depth': 5, 'learning_rate': 0.28671546722353436, 'subsample': 0.8471387457837923, 'colsample_bytree': 0.5659308677187872, 'gamma': 0.5824039482660692, 'reg_alpha': 0.274245391735172, 'reg_lambda': 0.790234814710492}. Best is trial 44 with value: 0.020275933600755778.
# [I 2025-08-03 13:23:52,018] Trial 46 finished with value: 0.02072497939234537 and parameters: {'n_estimators': 278, 'max_depth': 6, 'learning_rate': 0.20483368892750534, 'subsample': 0.8829075104390484, 'colsample_bytree': 0.6307752963789851, 'gamma': 0.33419810354178503, 'reg_alpha': 0.1917458810978273, 'reg_lambda': 0.6458107072364314}. Best is trial 44 with value: 0.020275933600755778.
# [I 2025-08-03 13:23:52,097] Trial 47 finished with value: 0.02189010115055902 and parameters: {'n_estimators': 190, 'max_depth': 7, 'learning_rate': 0.10760721489501227, 'subsample': 0.9708708304499906, 'colsample_bytree': 0.6539438235109013, 'gamma': 3.6931198599113157, 'reg_alpha': 0.05819742392460177, 'reg_lambda': 0.8773094736217578}. Best is trial 44 with value: 0.020275933600755778.
# [I 2025-08-03 13:23:52,179] Trial 48 finished with value: 0.020616316454011255 and parameters: {'n_estimators': 66, 'max_depth': 8, 'learning_rate': 0.05646810651252966, 'subsample': 0.8155254387745213, 'colsample_bytree': 0.6106614142961434, 'gamma': 0.18429747029321852, 'reg_alpha': 0.03590786559669268, 'reg_lambda': 0.5749060533931318}. Best is trial 44 with value: 0.020275933600755778.
# [I 2025-08-03 13:23:52,264] Trial 49 finished with value: 0.021280499416648852 and parameters: {'n_estimators': 241, 'max_depth': 7, 'learning_rate': 0.05512809719855836, 'subsample': 0.8227181162829955, 'colsample_bytree': 0.6117381015030809, 'gamma': 0.8522453675520569, 'reg_alpha': 0.014819473887236898, 'reg_lambda': 0.6941625389508886}. Best is trial 44 with value: 0.020275933600755778.

# %%
print("\n📘 Summary of Optuna Results by Lag:\n")

for lag_val, result in lag_study_results.items():
    print(f"\n🌀 LAG = {lag_val}")
    print(f"Best MSE: {result['best_value']:.6f}")
    print("Best Parameters:")
    for k, v in result['best_params'].items():
        print(f"  {k}: {v}")
# Out:
# 📘 Summary of Optuna Results by Lag:
#
#
# 🌀 LAG = 5
# Best MSE: 0.020611
# Best Parameters:
#   n_estimators: 144
#   max_depth: 7
#   learning_rate: 0.06660387777848599
#   subsample: 0.9977121054858006
#   colsample_bytree: 0.5970895723446366
#   gamma: 0.03534695153354229
#   reg_alpha: 0.66806815211721
#   reg_lambda: 0.5497806165139215
#
# 🌀 LAG = 10
# Best MSE: 0.020714
# Best Parameters:
#   n_estimators: 110
#   max_depth: 8
#   learning_rate: 0.0797935268763315
#   subsample: 0.6945710559675395
#   colsample_bytree: 0.8108130204825426
#   gamma: 0.03566377576849536
#   reg_alpha: 0.49149655286672705
#   reg_lambda: 0.7648575257482088
#
# 🌀 LAG = 15
# Best MSE: 0.020922
# Best Parameters:
#   n_estimators: 108
#   max_depth: 8
#   learning_rate: 0.047333624497498526
#   subsample: 0.6934233036770566
#   colsample_bytree: 0.8487699201744954
#   gamma: 0.035379587852154296
#   reg_alpha: 0.4451563061521754
#   reg_lambda: 0.7522427035473951
#
# 🌀 LAG = 20
# Best MSE: 0.020276
# Best Parameters:
#   n_estimators: 234
#   max_depth: 7
#   learning_rate: 0.29652196566427413
#   subsample: 0.8912875220924008
#   colsample_bytree: 0.649860171220549
#   gamma: 0.22128582524098034
#   reg_alpha: 0.13275143875443612
#   reg_lambda: 0.6514104112152276

# %%
from xgboost import XGBRegressor

# --- Storage for final models and residuals ---
final_models = {}
residuals_per_lag = {}

# --- Loop over each lag from tuning history ---
for LAG, result in lag_study_results.items():
    print(f"\n📦 Retraining model on full data for LAG = {LAG}...")

    # Step 1: Recreate lagged dataframe
    lagged_df = pd.DataFrame({'target': bmm_filled})
    for i in range(1, LAG + 1):
        lagged_df[f'lag_{i}'] = bmm_filled.shift(i)
    lagged_df.dropna(inplace=True)

    # Step 2: Prepare full dataset
    X_full = lagged_df.drop("target", axis=1).values
    y_full = lagged_df["target"].values

    # Step 3: Load best parameters and create model
    best_params = result["best_params"].copy()
    best_params.update({
        "objective": "reg:squarederror",
        "random_state": SEED
    })

    model = XGBRegressor(**best_params)
    model.fit(X_full, y_full)

    # Step 4: Store model and residuals
    final_models[LAG] = model
    y_pred = model.predict(X_full)
    residuals = y_full - y_pred
    residuals_per_lag[LAG] = pd.Series(residuals, index=lagged_df.index)

    print(f"✅ Model trained and residuals saved for LAG = {LAG}")
# Out:
# 📦 Retraining model on full data for LAG = 5...
# ✅ Model trained and residuals saved for LAG = 5
#
# 📦 Retraining model on full data for LAG = 10...
# ✅ Model trained and residuals saved for LAG = 10
#
# 📦 Retraining model on full data for LAG = 15...
# ✅ Model trained and residuals saved for LAG = 15
#
# 📦 Retraining model on full data for LAG = 20...
# ✅ Model trained and residuals saved for LAG = 20

# %% [markdown]
# **3.Qualitative Analysis**

# %%
import matplotlib.pyplot as plt

def plot_residuals_for_lag(lag):
    """
    Plots residuals for a given lag using a fixed time window.

    Parameters:
        lag (int): The lag value whose residuals you want to visualize.
    """
    if lag not in residuals_per_lag:
        print(f"❌ Lag {lag} not found in residuals_per_lag.")
        return

    # Fixed time window
    start_date = "2019-01-01"
    end_date = "2019-06-01"

    # Get residuals and slice to window
    residual_series = residuals_per_lag[lag]
    residual_window = residual_series.loc[start_date:end_date]

    # Plot
    plt.figure(figsize=(12, 4))
    plt.plot(residual_window.index, residual_window.values, color="red")
    plt.axhline(0, color="black", linestyle="--", linewidth=1)
    plt.title(f"Residuals for LAG = {lag} ({start_date} to {end_date})")
    plt.xlabel("Date")
    plt.ylabel("Residual")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
plot_residuals_for_lag(10)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# --- Load and parse ground truth maneuver timestamps ---
truth_df = pd.read_excel("/content/manFY2F_cleaned.xlsx")
ground_truth_timestamps = pd.to_datetime(
    truth_df["Start Date"].astype(str) + " " + truth_df["Start Time"].astype(str)
)

# --- Define plot function for a given lag ---
def plot_residuals_with_gt_for_lag(lag):
    """
    Plot residuals with ground truth maneuver overlay for a given lag.
    Uses fixed time window from 2013-01-01 to 2013-03-01.
    """
    if lag not in residuals_per_lag:
        print(f"❌ Residuals not found for lag {lag}")
        return

    # Fixed time window
    start_date = "2019-01-01"
    end_date = "2022-06-01"

    # Get residuals for the specified lag
    residual_series = residuals_per_lag[lag]
    residual_window = residual_series.loc[start_date:end_date]

    # Filter ground truth maneuvers to the window
    gt_in_window = ground_truth_timestamps[
        (ground_truth_timestamps >= pd.to_datetime(start_date)) &
        (ground_truth_timestamps <= pd.to_datetime(end_date))
    ]

    # Plot
    plt.figure(figsize=(14, 5))
    plt.plot(residual_window.index, residual_window.values, color='red', label='Residuals')
    plt.axhline(0, color='black', linestyle='--', linewidth=1)

    for ts in gt_in_window:
        plt.axvline(ts, color='blue', linestyle='--', alpha=0.7)

    plt.title(f"Residuals with Ground Truth Maneuvers (Lag={lag})\n{start_date} to {end_date}")
    plt.xlabel("Date")
    plt.ylabel("Residual")
    plt.grid(True)
    plt.legend(["Residuals", "Ground Truth Maneuvers"])
    plt.tight_layout()
    plt.show()

# --- Example usage ---
plot_residuals_with_gt_for_lag(10)

# %% [markdown]
# **4. Quantitative Analysis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- Precision / Recall / F1 Computation ---
def compute_prf_simple(
    residual_series: pd.Series,
    ground_truth_timestamps: pd.Series,
    threshold: float,
    matching_window_days: float = 3.0
):
    detections = residual_series[residual_series > threshold]
    detection_times = detections.index.sort_values()

    TP, FP, matched_gt = 0, 0, set()
    for det_time in detection_times:
        for i, gt_time in enumerate(ground_truth_timestamps):
            if i in matched_gt:
                continue
            if abs(det_time - gt_time) <= pd.Timedelta(days=matching_window_days):
                TP += 1
                matched_gt.add(i)
                break
        else:
            FP += 1

    FN = len(ground_truth_timestamps) - len(matched_gt)

    precision = TP / (TP + FP) if (TP + FP) else 0
    recall = TP / (TP + FN) if (TP + FN) else 0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) else 0

    return precision, recall, f1, TP, FP, FN


# --- Evaluation and PR Plot ---
summary_rows = []
lag_metrics_dfs = {}  # Store metrics per lag for later scenario analysis
plt.figure(figsize=(10, 6))
matching_window_days = 3.0

for lag, residual_series in residuals_per_lag.items():
    abs_resid = residual_series.abs()

    # FULL RANGE sweep from min to max
    thresholds = np.linspace(
        abs_resid.min(),
        abs_resid.max(),
        150
    )

    pr_points = []
    metrics = []

    for threshold in thresholds:
        precision, recall, f1, TP, FP, FN = compute_prf_simple(
            abs_resid,
            ground_truth_timestamps,
            threshold,
            matching_window_days=matching_window_days
        )
        pr_points.append((recall, precision))
        metrics.append((threshold, precision, recall, f1, TP, FP, FN))

    # Convert to DataFrame to extract best row
    metrics_df = pd.DataFrame(metrics, columns=["Threshold", "Precision", "Recall", "F1", "TP", "FP", "FN"])
    best_idx = metrics_df["F1"].idxmax()
    best_row = metrics_df.loc[best_idx]

    # Compute AUC using trapezoidal rule
    pr_points_arr = np.array(pr_points)
    sorted_idx = np.argsort(pr_points_arr[:, 0])  # sort by recall
    auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall

    # Add to summary table
    summary_rows.append({
        "Lag": lag,
        "Best Threshold": best_row["Threshold"],
        "Precision": best_row["Precision"],
        "Recall": best_row["Recall"],
        "F1 Score": best_row["F1"],
        "TP": int(best_row["TP"]),
        "FP": int(best_row["FP"]),
        "FN": int(best_row["FN"]),
        "PR AUC": auc_pr
    })

    # Save full metrics for this lag
    lag_metrics_dfs[lag] = metrics_df.copy()

    # Plot PR curve
    plt.plot(pr_points_arr[:, 0], pr_points_arr[:, 1], label=f"Lag {lag}", linewidth=2)

# --- PR Curve Plot ---
plt.xlabel("Recall", fontsize=13)
plt.ylabel("Precision", fontsize=13)
plt.title("Precision–Recall Curves for Multiple Lags (Full Threshold Sweep)", fontsize=15)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title="Lag", fontsize=10)
plt.tight_layout()
plt.show()

# --- Summary Table ---
summary_df = pd.DataFrame(summary_rows)
summary_df = summary_df.sort_values("F1 Score", ascending=False).reset_index(drop=True)

from IPython.display import display
display(summary_df)
# Out:
# /tmp/ipython-input-2546430860.py:73: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall
# /tmp/ipython-input-2546430860.py:73: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall
# /tmp/ipython-input-2546430860.py:73: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall
# /tmp/ipython-input-2546430860.py:73: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   auc_pr = np.trapz(pr_points_arr[sorted_idx, 1], pr_points_arr[sorted_idx, 0])  # precision vs recall
#    Lag  Best Threshold  Precision    Recall  F1 Score  TP  FP  FN    PR AUC
# 0   10        0.223201   0.800000  0.882353  0.839161  60  15   8  0.801165
# 1   15        0.212053   0.789474  0.882353  0.833333  60  16   8  0.809686
# 2    5        0.257313   0.786667  0.867647  0.825175  59  16   9  0.793327
# 3   20        0.309809   0.788732  0.823529  0.805755  56  15  12  0.793644
